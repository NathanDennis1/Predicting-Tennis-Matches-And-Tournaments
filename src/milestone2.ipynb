# %% [markdown]
# # Testing tournament code, to be moved into tournament.py

# %%
import pandas as pd
import requests
from io import StringIO

# %%
import requests
import pandas as pd
from io import StringIO
import sys

class GetTennisData():
    """
    Class to create dataframe from a dataset on github.
    """
    def __init__(self):
        """
        Initialize the GetTennisData class
        """
        self.base_url = "https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_matches_{}.csv"

    def get_data(self, year_lower = 2000, year_upper = 2025):
        """
        Reads data from github url and creates dataframe for each url.

        Args:
            year_lower (int): The lower bound for the years you want data for. Default set to 2000
            year_upper (int): The upper bound (Exclusive) for the years you want data for. Default set to 2025

        Returns:
            Final dataframe across every github url for given years.

        Raises:
            Exception: Years must be integers
            ValueError: Year must be in specified range of possible data.
        """

        if (type(year_lower) != int or type(year_upper) != int):
            raise Exception("This is not of type int (integer), you must input an int for years")

        try:
            if not (1968 <= year_lower <= 2024) or not (1969 <= year_upper <= 2025):
                raise ValueError("Year must be between 1968 and 2024 for the lower year, and between 1969 and 2025 for the upper year")
        except ValueError as e:
            print(e)
            sys.exit(1)

        df_list = []
        for year in range(year_lower, year_upper):  

            url = self.base_url.format(year)

            response = requests.get(url)

            df = pd.read_csv(StringIO(response.text))

            df['Year'] = year

            df_list.append(df)

        final_df = pd.concat(df_list)

        # Saved only columns we deemed relevant for analysis.
        final_df = final_df[['tourney_name', 'surface', 'draw_size', 'tourney_level', 'best_of', 
                   'winner_name', 'winner_age', 'loser_name', 'loser_age', 'Year']]
        
        final_df = final_df[final_df['surface'] != 'Carpet']
        
        final_df = final_df.dropna()

        file_path = f'../data/tennis_data.csv'

        final_df.to_csv(file_path, index=0)

# %%
tennis_data = GetTennisData()
tennis_data.get_data(year_lower = 2000, year_upper = 2024)

# %%
# Find rows with missing winner_ht or loser_ht
missing_ht = data[data['winner_ht'].isnull() | data['loser_ht'].isnull()]

missing_ht[missing_ht['tourney_name'] == 'Roland Garros']
# Out:
# Empty DataFrame
# Columns: [tourney_name, surface, draw_size, tourney_level, best_of, winner_name, winner_age, winner_ht, loser_name, loser_age, loser_ht, Year]
# Index: []

# %%
data = pd.read_csv('../data/tennis_data.csv')

# %%
rg01 = pd.read_csv('../data/tournament_results_Roland_Garros_head_to_head_0.1.csv', index_col=0)

# %%
rg01['Champion'].sort_values()
# Out:
# Thiago Seyboth Wild    0.00
# Constant Lestienne     0.00
# David Goffin           0.00
# Pedro Martinez         0.00
# Juncheng Shang         0.00
#                        ...
# Casper Ruud            0.08
# Stefanos Tsitsipas     0.08
# Alexander Zverev       0.12
# Carlos Alcaraz         0.14
# Novak Djokovic         0.36
# Name: Champion, Length: 128, dtype: float64

# %%
win_per = pd.read_csv('../data/win_percentage.csv', index_col='Player_Name')
games_played = pd.read_csv('../data/games_played_opponents.csv', index_col='Player_Name')

# %%
odds = pd.read_csv('../data/2023_Australian_Open_Prob.csv', index_col=0)

model = pd.read_csv('../data/tournament_results_Australian_Open.csv', index_col = 0)

# %%
k_list = [0.05, 0.1, 0.5]

# %%
import numpy as np
def RMSE(true, pred):
    return np.sqrt(np.mean(np.square(true-pred)))

def Linf(true, pred):
    return np.max(np.abs(true-pred))

def L1(true, pred):
    return np.mean(np.absolute(true-pred))

# %%
csv_dict_k = {}
csv_dict_k['original'] = model
if k_list is not None:
    for k in k_list:
        csv_dict_k[k] = pd.read_csv(f'../data/tournament_results_Australian_Open_head_to_head_{k}.csv', index_col=0)

# %%
csv_dict_k[0.05]
# Out:
#                       Round_64  Round_32  Round_16  Round_8  Round_4  Round_2  \
# Rafael Nadal            0.9228    0.7334    0.6594   0.5278   0.3784   0.2702
# Mackenzie Mcdonald      0.4910    0.0766    0.0356   0.0046   0.0010   0.0000
# Dalibor Svrcina         0.6836    0.1654    0.0276   0.0064   0.0012   0.0004
# Yoshihito Nishioka      0.6476    0.5168    0.0996   0.0186   0.0044   0.0010
# Karen Khachanov         0.9326    0.8610    0.5814   0.2116   0.0936   0.0346
# ...                        ...       ...       ...      ...      ...      ...
# Joao Sousa              0.1972    0.0682    0.0114   0.0008   0.0000   0.0000
# Alexander Bublik        0.5798    0.1602    0.0382   0.0202   0.0084   0.0002
# Jan Lennard Struff      0.1086    0.0332    0.0078   0.0004   0.0000   0.0000
# Christopher Oconnell    0.2690    0.0386    0.0048   0.0014   0.0002   0.0000
# Tomas Machac            0.0576    0.0200    0.0060   0.0010   0.0000   0.0000
#
#                       Runner_up  Champion
# Rafael Nadal             0.0982    0.0982
# Mackenzie Mcdonald       0.0000    0.0000
# Dalibor Svrcina          0.0000    0.0000
# Yoshihito Nishioka       0.0002    0.0002
# Karen Khachanov          0.0066    0.0066
# ...                         ...       ...
# Joao Sousa               0.0000    0.0000
# Alexander Bublik         0.0000    0.0000
# Jan Lennard Struff       0.0000    0.0000
# Christopher Oconnell     0.0000    0.0000
# Tomas Machac             0.0000    0.0000
#
# [128 rows x 8 columns]

# %%
odds_comparison = odds[['normalized_winning_probability']]
odds_comparison = odds_comparison.dropna()

# %%
csv_dict_k.items()
# Out:
# dict_items([('original',                       Round_64  Round_32  Round_16  Round_8  Round_4  Round_2  \
# Rafael Nadal            0.7886    0.6150    0.5264   0.3664   0.2432   0.1558
# Mackenzie Mcdonald      0.3216    0.0606    0.0264   0.0060   0.0024   0.0006
# Dalibor Svrcina         0.5082    0.1740    0.0290   0.0062   0.0016   0.0000
# Yoshihito Nishioka      0.4470    0.2822    0.0686   0.0232   0.0076   0.0024
# Karen Khachanov         0.8290    0.6750    0.3742   0.1890   0.0966   0.0474
# ...                        ...       ...       ...      ...      ...      ...
# Joao Sousa              0.2300    0.0820    0.0152   0.0026   0.0006   0.0000
# Alexander Bublik        0.5834    0.2710    0.1112   0.0548   0.0192   0.0040
# Jan Lennard Struff      0.1858    0.0528    0.0100   0.0020   0.0004   0.0000
# Christopher Oconnell    0.2722    0.0402    0.0114   0.0040   0.0002   0.0000
# Tomas Machac            0.1622    0.0700    0.0204   0.0064   0.0010   0.0000
#
#                       Runner_up  Champion
# Rafael Nadal             0.0694    0.0694
# Mackenzie Mcdonald       0.0000    0.0000
# Dalibor Svrcina          0.0000    0.0000
# Yoshihito Nishioka       0.0000    0.0000
# Karen Khachanov          0.0172    0.0172
# ...                         ...       ...
# Joao Sousa               0.0000    0.0000
# Alexander Bublik         0.0016    0.0016
# Jan Lennard Struff       0.0000    0.0000
# Christopher Oconnell     0.0000    0.0000
# Tomas Machac             0.0000    0.0000
#
# [128 rows x 8 columns]), (0.05,                       Round_64  Round_32  Round_16  Round_8  Round_4  Round_2  \
# Rafael Nadal            0.9228    0.7334    0.6594   0.5278   0.3784   0.2702
# Mackenzie Mcdonald      0.4910    0.0766    0.0356   0.0046   0.0010   0.0000
# Dalibor Svrcina         0.6836    0.1654    0.0276   0.0064   0.0012   0.0004
# Yoshihito Nishioka      0.6476    0.5168    0.0996   0.0186   0.0044   0.0010
# Karen Khachanov         0.9326    0.8610    0.5814   0.2116   0.0936   0.0346
# ...                        ...       ...       ...      ...      ...      ...
# Joao Sousa              0.1972    0.0682    0.0114   0.0008   0.0000   0.0000
# Alexander Bublik        0.5798    0.1602    0.0382   0.0202   0.0084   0.0002
# Jan Lennard Struff      0.1086    0.0332    0.0078   0.0004   0.0000   0.0000
# Christopher Oconnell    0.2690    0.0386    0.0048   0.0014   0.0002   0.0000
# Tomas Machac            0.0576    0.0200    0.0060   0.0010   0.0000   0.0000
#
#                       Runner_up  Champion
# Rafael Nadal             0.0982    0.0982
# Mackenzie Mcdonald       0.0000    0.0000
# Dalibor Svrcina          0.0000    0.0000
# Yoshihito Nishioka       0.0002    0.0002
# Karen Khachanov          0.0066    0.0066
# ...                         ...       ...
# Joao Sousa               0.0000    0.0000
# Alexander Bublik         0.0000    0.0000
# Jan Lennard Struff       0.0000    0.0000
# Christopher Oconnell     0.0000    0.0000
# Tomas Machac             0.0000    0.0000
#
# [128 rows x 8 columns]), (0.1,                       Round_64  Round_32  Round_16  Round_8  Round_4  Round_2  \
# Rafael Nadal            0.8980    0.7218    0.6376   0.5052   0.3594   0.2480
# Mackenzie Mcdonald      0.4648    0.0714    0.0322   0.0052   0.0010   0.0000
# Dalibor Svrcina         0.6492    0.1896    0.0332   0.0070   0.0014   0.0002
# Yoshihito Nishioka      0.6004    0.4462    0.0924   0.0162   0.0044   0.0020
# Karen Khachanov         0.9212    0.8260    0.5444   0.2010   0.0892   0.0362
# ...                        ...       ...       ...      ...      ...      ...
# Joao Sousa              0.2070    0.0724    0.0112   0.0012   0.0000   0.0000
# Alexander Bublik        0.5714    0.1814    0.0452   0.0238   0.0080   0.0008
# Jan Lennard Struff      0.1144    0.0374    0.0078   0.0012   0.0000   0.0000
# Christopher Oconnell    0.2702    0.0434    0.0068   0.0018   0.0000   0.0000
# Tomas Machac            0.0872    0.0344    0.0102   0.0026   0.0006   0.0002
#
#                       Runner_up  Champion
# Rafael Nadal             0.0832    0.0832
# Mackenzie Mcdonald       0.0000    0.0000
# Dalibor Svrcina          0.0000    0.0000
# Yoshihito Nishioka       0.0002    0.0002
# Karen Khachanov          0.0056    0.0056
# ...                         ...       ...
# Joao Sousa               0.0000    0.0000
# Alexander Bublik         0.0000    0.0000
# Jan Lennard Struff       0.0000    0.0000
# Christopher Oconnell     0.0000    0.0000
# Tomas Machac             0.0000    0.0000
#
# [128 rows x 8 columns]), (0.5,                       Round_64  Round_32  Round_16  Round_8  Round_4  Round_2  \
# Rafael Nadal            0.8016    0.6226    0.5316   0.3976   0.2660   0.1766
# Mackenzie Mcdonald      0.3150    0.0594    0.0280   0.0074   0.0022   0.0006
# Dalibor Svrcina         0.5200    0.1844    0.0340   0.0082   0.0016   0.0004
# Yoshihito Nishioka      0.4866    0.3096    0.0798   0.0236   0.0086   0.0012
# Karen Khachanov         0.8388    0.6794    0.3904   0.1706   0.0802   0.0354
# ...                        ...       ...       ...      ...      ...      ...
# Joao Sousa              0.2040    0.0712    0.0126   0.0018   0.0000   0.0000
# Alexander Bublik        0.5800    0.2676    0.1050   0.0522   0.0176   0.0036
# Jan Lennard Struff      0.1756    0.0544    0.0104   0.0038   0.0012   0.0002
# Christopher Oconnell    0.2882    0.0538    0.0118   0.0034   0.0002   0.0002
# Tomas Machac            0.1702    0.0680    0.0204   0.0062   0.0018   0.0002
#
#                       Runner_up  Champion
# Rafael Nadal             0.0622    0.0622
# Mackenzie Mcdonald       0.0002    0.0002
# Dalibor Svrcina          0.0000    0.0000
# Yoshihito Nishioka       0.0004    0.0004
# Karen Khachanov          0.0088    0.0088
# ...                         ...       ...
# Joao Sousa               0.0000    0.0000
# Alexander Bublik         0.0014    0.0014
# Jan Lennard Struff       0.0002    0.0002
# Christopher Oconnell     0.0000    0.0000
# Tomas Machac             0.0000    0.0000
#
# [128 rows x 8 columns])])

# %%
odds_comparison
# Out:
#                     normalized_winning_probability  Champion_original  \
# Player
# Novak Djokovic                            0.348616             0.3798
# Stefanos Tsitsipas                        0.042609             0.0428
# Karen Khachanov                           0.006328             0.0172
# Tommy Paul                                0.002123             0.0038
# Sebastian Korda                           0.018798             0.0050
# ...                                            ...                ...
# Tomas Machac                              0.001276             0.0000
# Vasek Pospisil                            0.001276             0.0000
# Yannick Hanfmann                          0.001276             0.0000
# Yu Hsiou Hsu                              0.001276             0.0000
# Zhizhen Zhang                             0.001276             0.0000
#
#                     Champion_0.05  Champion_0.1  Champion_0.5
# Player
# Novak Djokovic             0.5792        0.5624        0.4950
# Stefanos Tsitsipas         0.0272        0.0314        0.0294
# Karen Khachanov            0.0066        0.0056        0.0088
# Tommy Paul                 0.0020        0.0026        0.0060
# Sebastian Korda            0.0012        0.0020        0.0042
# ...                           ...           ...           ...
# Tomas Machac               0.0000        0.0000        0.0000
# Vasek Pospisil             0.0000        0.0000        0.0000
# Yannick Hanfmann           0.0000        0.0000        0.0000
# Yu Hsiou Hsu               0.0000        0.0000        0.0000
# Zhizhen Zhang              0.0000        0.0000        0.0000
#
# [130 rows x 5 columns]

# %%
actual = odds_comparison['normalized_winning_probability']
for model_name, model_df in csv_dict_k.items():
    # Extract the 'Champion' column corresponding to the current model.
    champion_column = model_df[f'Champion']
    
    # Ensure the indices match and join the 'Champion' column to the 'odds_comparison' DataFrame
    odds_comparison[f'Champion_{model_name}'] = champion_column

# %%
# Loop over models in csv_dict_k and compute the metrics
for model_name, model_df in csv_dict_k.items():
    # Get the champion column for the model
    champion_column = odds_comparison[f'Champion_{model_name}']
        
    # Compute metrics
    rmse_value = RMSE(actual, champion_column)
    linf_value = Linf(actual, champion_column)
    l1_value = L1(actual, champion_column)

    # Print results for the current model
    print(f"Model: {model_name}")
    print(f"  RMSE: {rmse_value}")
    print(f"  Linf: {linf_value}")
    print(f"  L1: {l1_value}")
    print('-' * 40)  # Separator for better readability
# Out:
# Model: original
#   RMSE: 0.00943225887634533
#   Linf: 0.08026803556018709
#   L1: 0.00358643232111009
# ----------------------------------------
# Model: 0.05
#   RMSE: 0.02316381059986612
#   Linf: 0.23058353467429493
#   L1: 0.005617728717089069
# ----------------------------------------
# Model: 0.1
#   RMSE: 0.021480354305378653
#   Linf: 0.2137835346742949
#   L1: 0.0053055298670316746
# ----------------------------------------
# Model: 0.5
#   RMSE: 0.015172168753552128
#   Linf: 0.14638353467429488
#   L1: 0.0042610974837843565
# ----------------------------------------

# %%
odds_comparison
# Out:
#                          normalized_winning_probability  Champion  \
# Carlos Alcaraz                                 0.146204    0.1122
# Novak Djokovic                                 0.418675    0.3912
# Daniil Medvedev                                0.031329    0.0464
# Jannik Sinner                                  0.034627    0.0370
# Holger Rune                                    0.016047    0.0322
# ...                                                 ...       ...
# Tomas Martin Etcheverry                        0.001313    0.0000
# Yannick Hanfmann                               0.001313    0.0000
# Yibing Wu                                      0.001313    0.0000
# Yosuke Watanuki                                0.001313    0.0002
# Zhizhen Zhang                                  0.001313    0.0002
#
#                          Champion_original  Champion_0.05  Champion_0.1  \
# Carlos Alcaraz                      0.1122         0.1260        0.1258
# Novak Djokovic                      0.3912         0.5560        0.5372
# Daniil Medvedev                     0.0464         0.0634        0.0574
# Jannik Sinner                       0.0370         0.0494        0.0444
# Holger Rune                         0.0322         0.0264        0.0250
# ...                                    ...            ...           ...
# Tomas Martin Etcheverry             0.0000         0.0000        0.0000
# Yannick Hanfmann                    0.0000         0.0000        0.0000
# Yibing Wu                           0.0000         0.0000        0.0002
# Yosuke Watanuki                     0.0002         0.0000        0.0000
# Zhizhen Zhang                       0.0002         0.0000        0.0000
#
#                          Champion_0.5
# Carlos Alcaraz                 0.1120
# Novak Djokovic                 0.4646
# Daniil Medvedev                0.0450
# Jannik Sinner                  0.0304
# Holger Rune                    0.0290
# ...                               ...
# Tomas Martin Etcheverry        0.0000
# Yannick Hanfmann               0.0000
# Yibing Wu                      0.0004
# Yosuke Watanuki                0.0000
# Zhizhen Zhang                  0.0000
#
# [115 rows x 6 columns]

# %%
odds_comparison = odds[['normalized_winning_probability']].join(model['Champion'], how='inner')
odds_comparison = odds_comparison.dropna()

actual = odds_comparison['normalized_winning_probability']

preds = odds_comparison['Champion']

# %%
odds_comparison
# Out:
#                          normalized_winning_probability  Champion
# Carlos Alcaraz                                 0.146204    0.1122
# Novak Djokovic                                 0.418675    0.3912
# Daniil Medvedev                                0.031329    0.0464
# Jannik Sinner                                  0.034627    0.0370
# Holger Rune                                    0.016047    0.0322
# ...                                                 ...       ...
# Tomas Martin Etcheverry                        0.001313    0.0000
# Yannick Hanfmann                               0.001313    0.0000
# Yibing Wu                                      0.001313    0.0000
# Yosuke Watanuki                                0.001313    0.0002
# Zhizhen Zhang                                  0.001313    0.0002
#
# [115 rows x 2 columns]

# %%
games_played_per_player = games_played.sum(axis=1)

# Step 3: Calculate the average number of games played across all players
average_games_played = games_played_per_player.mean()
average_games_played
# Out:
# 47.33678756476684

# %%
games_played['Roger Federer'].sum()
# Out:
# 396.0

# %%
win_per['Roger Federer']['Novak Djokovic']
# Out:
# 0.35

# %%
import math
math.exp(-0.015 * (30-25))**5
# Out:
# 0.6872892787909721

# %%
import math

# Sigmoid function to calculate the adjustment factor based on games played
def sigmoid(x, x_0=10, k=0.3):
    """
    Sigmoid function to adjust weight based on the number of games played.
    x_0 is the point where the sigmoid function reaches 0.5 (midpoint).
    k controls the steepness of the sigmoid curve.
    """
    return 1 / (1 + math.exp(-k * (x - x_0)))

# Function to calculate adjusted win probability
def adjusted_win_probability(P_A, P_head_to_head, games_played, x_0=10, k=0.3):
    """
    Calculate the adjusted win probability for Player A based on the sigmoid-weighted head-to-head record.
    
    Parameters:
    - P_A: Base win probability of Player A (e.g., from ELO ratings)
    - P_head_to_head: Historical head-to-head win percentage of Player A
    - games_played: Number of games played between Player A and Player B
    - x_0: Point where sigmoid reaches 0.5 (default = 20 games)
    - k: Steepness factor for the sigmoid function (default = 0.2)
    
    Returns:
    - Adjusted win probability for Player A
    """
    # Calculate the sigmoid adjustment factor based on games played
    adjustment_factor = 0.5 / (1 + math.exp(-k * (games_played - 10)))
    print(adjustment_factor) 

        # Calculate the adjusted win probability
    P_A_adjusted = P_A + adjustment_factor * (P_head_to_head - 0.5)
        
        # Ensure the adjusted probability stays within the valid range [0, 1]
    P_A_adjusted = max(0, min(1, P_A_adjusted))

    return P_A_adjusted

# Example usage
P_A = 0.76  # Base win probability for Player A (e.g., from ELO)
P_head_to_head = 0.8  # Hist
games_played = 20  # Number of games played between Player A and Player B

# Calculate adjusted win probability for Player A
adjusted_prob = adjusted_win_probability(P_A, P_head_to_head, games_played, k = 0.5)

print(f"Adjusted win probability for Player A: {adjusted_prob:.4f}")
# Out:
# 0.49665357453785763
# Adjusted win probability for Player A: 0.9090

# %%
    def adjusted_win_probability_by_games(self, P_A, games_A, games_B, rate=0.1):
        """
        Calculates the adjusted win probability based on specificially game played experience

        Args:
            P_A (float): Probability player A beats player B
            games_A (int): Number of games played by player A
            games_B (int): Number of games played by player B
            rate (float): Rate parameter to adjust winning probability.

        Returns:
            Adjusted winning probability for player A
        """
        total_games = games_A + games_B

        if total_games == 0:
            return P_A  # If no games have been played, just return the base probability
        
        proportion = games_A / total_games
        
        # Calculate the adjustment based on the proportion of games played
        adjustment = rate * (proportion - 0.5)
        
        # Adjust the win probability
        adjusted_P_A = P_A + adjustment
        
        # Ensure the adjusted probability stays within the valid range [0, 1]
        adjusted_P_A = max(0, min(1, adjusted_P_A))
        
        return adjusted_P_A

# %%
import math

def adjusted_win_probability(P_A, P_head_to_head, games_played, k=0.1):
    """
    Calculate the adjusted win probability for Player A based on head-to-head win percentage
    and the number of games played between the two players.
    
    Parameters:
    - P_A: Base win probability of Player A (e.g., from ELO ratings)
    - P_head_to_head: Historical win percentage of Player A against Player B
    - games_played: Number of games played between Player A and Player B
    - k: The scaling factor for the number of games played (default = 0.1)
    
    Returns:
    - Adjusted win probability for Player A
    """

    adjustment_factor = 0.5 / (1 + math.exp(-k * (games_played - 10))) 

    # Calculate the adjusted win probability
    P_A_adjusted = P_A + adjustment_factor * (P_head_to_head - 0.5)
    
    # Ensure the adjusted probability stays within the valid range [0, 1]
    P_A_adjusted = max(0, min(1, P_A_adjusted))
    
    return P_A_adjusted

# Example usage
P_A = 0.76  # Base win probability for Player A (e.g., from ELO)
P_head_to_head = 0.9  # Historical win percentage of Player A against Player B
games_played = 30  # Number of games played between Player A and Player B

# Calculate adjusted win probability for Player A
adjusted_prob = adjusted_win_probability(P_A, P_head_to_head, games_played)

print(f"Adjusted win probability for Player A: {adjusted_prob:.4f}")
# Out:
# Adjusted win probability for Player A: 0.9362

# %%
1 / (1 + math.exp(-0.6 * (20 - 20)))
# Out:
# 0.5

# %%
games_played_A = 50
games_played_B = 20

# %%
def adjusted_win_probability_by_games(P_A, games_A, games_B, rate=0.1):
    """
    Calculate the adjusted win probability for Player A based on the number of games played by both players.
    
    Parameters:
    - P_A: Base win probability of Player A (e.g., from ELO ratings)
    - games_A: Number of games played by Player A
    - games_B: Number of games played by Player B
    - r: The small adjustment rate factor (default = 0.01)
    
    Returns:
    - Adjusted win probability for Player A
    """
    # Calculate the relative experience factor
    total_games = games_A + games_B
    if total_games == 0:
        return P_A  # If no games have been played, just return the base probability
    
    proportion = games_A / total_games
    print(proportion)
    
    # Calculate the adjustment based on the relative factor
    adjustment = rate * (proportion - 0.5)
    print(adjustment)
    
    # Adjust the win probability
    adjusted_P_A = P_A + adjustment
    
    # Ensure the adjusted probability stays within the valid range [0, 1]
    adjusted_P_A = max(0, min(1, adjusted_P_A))
    
    return adjusted_P_A

# Example usage
P_A = 0.76  # Base win probability for Player A (e.g., from ELO)
games_A = 50  # Number of games Player A has played
games_B = 10  # Number of games Player B has played

# Calculate adjusted win probability for Player A
adjusted_prob = adjusted_win_probability_by_games(P_A, games_A, games_B)

print(f"Adjusted win probability for Player A: {adjusted_prob:.4f}")
# Out:
# 0.8333333333333334
# 0.03333333333333334
# Adjusted win probability for Player A: 0.7933

# %% [markdown]
# $P(A_adjusted} = P(A) \cdot$

# %%
P_A
# Out:
# 0.76

# %%
P_A * (1+0.002)**games_played
# Out:
# 1.1333339497295256

# %%
games_played
# Out:
# 20

# %%
sigmoid(100, games_played.sum(axis=1).mean(), 0.001)
# Out:
# 0.7216504560280248

# %%
win_per
# Out:
#                            James Duckworth  Roger Federer  Blaz Kavcic  \
# Player_Name
# Jarkko Nieminen                        0.5            0.0          0.0
# James Duckworth                        0.0            0.0          1.0
# Marinko Matosevic                      0.0            0.0          0.0
# Julien Benneteau                       0.0            0.0          0.0
# Sam Querrey                            0.5            0.0          0.0
# ...                                    ...            ...          ...
# Daniel Azar                            0.0            0.0          0.0
# Fajing Sun                             0.0            0.0          0.0
# Alvaro Guillen Meza                    0.0            0.0          0.0
# Chris Rodesch                          0.0            0.0          0.0
# Joaquin  Aguilar Cardozo               0.0            0.0          0.0
#
#                            Dudi Sela  Fabio Fognini  Alexandar Lazov  \
# Player_Name
# Jarkko Nieminen                 1.00            0.0              1.0
# James Duckworth                 1.00            0.0              0.0
# Marinko Matosevic               0.00            0.0              0.0
# Julien Benneteau                0.00            0.0              0.0
# Sam Querrey                     0.75            0.0              0.0
# ...                              ...            ...              ...
# Daniel Azar                     0.00            0.0              0.0
# Fajing Sun                      0.00            0.0              0.0
# Alvaro Guillen Meza             0.00            0.0              0.0
# Chris Rodesch                   0.00            0.0              0.0
# Joaquin  Aguilar Cardozo        0.00            0.0              0.0
#
#                            Dimitar Kutrovsky  Aleksandr Nedovyesov  \
# Player_Name
# Jarkko Nieminen                          1.0                   1.0
# James Duckworth                          0.0                   0.0
# Marinko Matosevic                        0.0                   0.0
# Julien Benneteau                         0.0                   0.0
# Sam Querrey                              0.0                   0.0
# ...                                      ...                   ...
# Daniel Azar                              0.0                   0.0
# Fajing Sun                               0.0                   0.0
# Alvaro Guillen Meza                      0.0                   0.0
# Chris Rodesch                            0.0                   0.0
# Joaquin  Aguilar Cardozo                 0.0                   0.0
#
#                            Pierre Hugues Herbert  Marc Gicquel  ...  \
# Player_Name                                                     ...
# Jarkko Nieminen                         1.000000           1.0  ...
# James Duckworth                         0.000000           0.0  ...
# Marinko Matosevic                       0.000000           0.0  ...
# Julien Benneteau                        1.000000           0.0  ...
# Sam Querrey                             0.666667           0.0  ...
# ...                                          ...           ...  ...
# Daniel Azar                             0.000000           0.0  ...
# Fajing Sun                              0.000000           0.0  ...
# Alvaro Guillen Meza                     0.000000           0.0  ...
# Chris Rodesch                           0.000000           0.0  ...
# Joaquin  Aguilar Cardozo                0.000000           0.0  ...
#
#                            Conor Gannon  Alvaro Guillen Meza  \
# Player_Name
# Jarkko Nieminen                     0.0                  0.0
# James Duckworth                     0.0                  0.0
# Marinko Matosevic                   0.0                  0.0
# Julien Benneteau                    0.0                  0.0
# Sam Querrey                         0.0                  0.0
# ...                                 ...                  ...
# Daniel Azar                         0.0                  0.0
# Fajing Sun                          0.0                  0.0
# Alvaro Guillen Meza                 0.0                  0.0
# Chris Rodesch                       0.0                  0.0
# Joaquin  Aguilar Cardozo            0.0                  0.0
#
#                            Lucky Candra Kurniawan  Ignacio Buse  Jose  Flores  \
# Player_Name
# Jarkko Nieminen                               0.0           0.0           0.0
# James Duckworth                               0.0           0.0           0.0
# Marinko Matosevic                             0.0           0.0           0.0
# Julien Benneteau                              0.0           0.0           0.0
# Sam Querrey                                   0.0           0.0           0.0
# ...                                           ...           ...           ...
# Daniel Azar                                   0.0           0.0           0.0
# Fajing Sun                                    0.0           0.0           0.0
# Alvaro Guillen Meza                           0.0           0.0           0.0
# Chris Rodesch                                 0.0           0.0           0.0
# Joaquin  Aguilar Cardozo                      0.0           0.0           0.0
#
#                            Freddy Murray  Walid Ahouda  Digvijaypratap Singh  \
# Player_Name
# Jarkko Nieminen                      0.0           0.0                   0.0
# James Duckworth                      0.0           0.0                   0.0
# Marinko Matosevic                    0.0           0.0                   0.0
# Julien Benneteau                     0.0           0.0                   0.0
# Sam Querrey                          0.0           0.0                   0.0
# ...                                  ...           ...                   ...
# Daniel Azar                          0.0           0.0                   0.0
# Fajing Sun                           0.0           0.0                   0.0
# Alvaro Guillen Meza                  0.0           0.0                   0.0
# Chris Rodesch                        0.0           0.0                   0.0
# Joaquin  Aguilar Cardozo             0.0           0.0                   0.0
#
#                            Daniel Azar  Mustapha El Natour
# Player_Name
# Jarkko Nieminen                    0.0                 0.0
# James Duckworth                    0.0                 0.0
# Marinko Matosevic                  0.0                 0.0
# Julien Benneteau                   0.0                 0.0
# Sam Querrey                        0.0                 0.0
# ...                                ...                 ...
# Daniel Azar                        0.0                 0.0
# Fajing Sun                         0.0                 0.0
# Alvaro Guillen Meza                0.0                 0.0
# Chris Rodesch                      0.0                 0.0
# Joaquin  Aguilar Cardozo           0.0                 0.0
#
# [1158 rows x 1158 columns]

# %%
games_played
# Out:
# 20

# %%
data[(data['winner_name'] == 'Roger Federer') & (data['loser_name'] == 'Novak Djokovic')]
# Out:
#               tourney_name surface  draw_size tourney_level  best_of  \
# 703                  Dubai    Hard         32             A        3
# 1129   Monte Carlo Masters    Clay         56             M        3
# 2683      Shanghai Masters    Hard         56             M        3
# 3503                 Dubai    Hard         32             A        3
# 5156    Cincinnati Masters    Hard         56             M        3
# 5824           Tour Finals    Hard          8             F        3
# 17171          Tour Finals    Hard          8             F        3
#
#          winner_name  winner_age      loser_name  loser_age  Year
# 703    Roger Federer        32.5  Novak Djokovic       26.7  2014
# 1129   Roger Federer        32.6  Novak Djokovic       26.8  2014
# 2683   Roger Federer        33.1  Novak Djokovic       27.3  2014
# 3503   Roger Federer        33.5  Novak Djokovic       27.7  2015
# 5156   Roger Federer        34.0  Novak Djokovic       28.2  2015
# 5824   Roger Federer        34.2  Novak Djokovic       28.4  2015
# 17171  Roger Federer        38.2  Novak Djokovic       32.4  2019

# %%
data[(data['winner_name'] == 'Novak Djokovic') & (data['loser_name'] == 'Roger Federer')]
# Out:
#                tourney_name surface  draw_size tourney_level  best_of  \
# 827    Indian Wells Masters    Hard         96             M        3
# 1820              Wimbledon   Grass        128             G        5
# 2890            Tour Finals    Hard          8             F        3
# 3729   Indian Wells Masters    Hard         96             M        3
# 4198           Rome Masters    Clay         56             M        3
# 4669              Wimbledon   Grass        128             G        5
# 5330                US Open    Hard        128             G        5
# 5833            Tour Finals    Hard          8             F        3
# 6100        Australian Open    Hard        128             G        5
# 13886    Cincinnati Masters    Hard         64             M        3
# 14522         Paris Masters    Hard         64             M        3
# 16195             Wimbledon   Grass        128             G        5
# 17664       Australian Open    Hard        128             G        5
#
#           winner_name  winner_age     loser_name  loser_age  Year
# 827    Novak Djokovic        26.7  Roger Federer       32.5  2014
# 1820   Novak Djokovic        27.0  Roger Federer       32.8  2014
# 2890   Novak Djokovic        27.4  Roger Federer       33.2  2014
# 3729   Novak Djokovic        27.7  Roger Federer       33.5  2015
# 4198   Novak Djokovic        27.9  Roger Federer       33.7  2015
# 4669   Novak Djokovic        28.1  Roger Federer       33.8  2015
# 5330   Novak Djokovic        28.2  Roger Federer       34.0  2015
# 5833   Novak Djokovic        28.4  Roger Federer       34.2  2015
# 6100   Novak Djokovic        28.6  Roger Federer       34.4  2016
# 13886  Novak Djokovic        31.2  Roger Federer       37.0  2018
# 14522  Novak Djokovic        31.4  Roger Federer       37.2  2018
# 16195  Novak Djokovic        32.1  Roger Federer       37.8  2019
# 17664  Novak Djokovic        32.6  Roger Federer       38.4  2020

# %%
win_per.loc['Roger Federer']['Novak Djokovic']
# Out:
# 0.35

# %%
win_per.loc['Andy Murray'].sum()
# Out:
# 438.0

# %%
df = data

age_bins = range(19, 40, 1)  # Create bins from 22 to 35
age_labels = [f'{i}-{i+1}' for i in age_bins[:-1]]

df['winner_age_group'] = pd.cut(df['winner_age'], bins=age_bins, labels=age_labels, right=False)
df['loser_age_group'] = pd.cut(df['loser_age'], bins=age_bins, labels=age_labels, right=False)

# Step 3: Calculate the winning percentage by age group
# Count the number of wins per age group
win_counts = df['winner_age_group'].value_counts().sort_index()

# Count the total number of matches per age group (winners + losers)
total_counts = pd.concat([
    df['winner_age_group'].value_counts(),
    df['loser_age_group'].value_counts()
], axis=1, keys=['wins', 'losses']).fillna(0)

# Step 4: Calculate winning percentages
total_counts['total'] = total_counts['wins'] + total_counts['losses']
total_counts['win_percentage'] = (total_counts['wins'] / total_counts['total']) * 100

# Step 5: Output the result
print(total_counts[['win_percentage']].sort_index())
# Out:
#        win_percentage
# 19-20       48.528302
# 20-21       50.904393
# 21-22       50.699588
# 22-23       51.664402
# 23-24       50.459770
# 24-25       51.008493
# 25-26       51.703455
# 26-27       49.275980
# 27-28       49.293528
# 28-29       49.651163
# 29-30       50.698324
# 30-31       48.869518
# 31-32       49.188157
# 32-33       50.981845
# 33-34       50.373832
# 34-35       50.644028
# 35-36       50.039841
# 36-37       48.421053
# 37-38       51.168224
# 38-39       47.023810

# %%
data
# Out:
#                        tourney_name surface  draw_size tourney_level  best_of  \
# 0                          Brisbane    Hard         28             A        3
# 1                          Brisbane    Hard         28             A        3
# 2                          Brisbane    Hard         28             A        3
# 3                          Brisbane    Hard         28             A        3
# 4                          Brisbane    Hard         28             A        3
# ...                             ...     ...        ...           ...      ...
# 27403  Davis Cup WG2 R1: SLO vs LUX    Clay          4             D        3
# 27404  Davis Cup WG2 R1: SLO vs LUX    Clay          4             D        3
# 27405  Davis Cup WG2 R1: URU vs EGY    Clay          4             D        3
# 27406  Davis Cup WG2 R1: URU vs EGY    Clay          4             D        3
# 27407  Davis Cup WG2 R1: URU vs EGY    Clay          4             D        3
#
#                      winner_name  winner_age                       loser_name  \
# 0                Jarkko Nieminen        32.4                  James Duckworth
# 1              Marinko Matosevic        28.3                 Julien Benneteau
# 2                    Sam Querrey        26.2                  Dmitry Tursunov
# 3                      Sam Groth        26.1                    Ryan Harrison
# 4                  Nicolas Mahut        31.9                    Igor Sijsling
# ...                          ...         ...                              ...
# 27403                  Blaz Rola        32.9                       Alex Knaff
# 27404              Chris Rodesch        22.1                       Bor Artnak
# 27405             Mohamed Safwat        32.9                    Ignacio Carou
# 27406      Karim Mohamed Maamoun        32.4                Franco Roncadelli
# 27407  Joaquin  Aguilar Cardozo         18.4  Amr Elsayed Abdou Ahmed Mohamed
#
#        loser_age  Year
# 0           21.9  2014
# 1           32.0  2014
# 2           31.0  2014
# 3           21.6  2014
# 4           26.3  2014
# ...          ...   ...
# 27403       25.7  2023
# 27404       19.2  2023
# 27405       24.1  2023
# 27406       23.5  2023
# 27407       24.5  2023
#
# [27408 rows x 10 columns]

# %%
games_played_df
# Out:
#                            Peter Luczak  Carsten Ball  Richard Gasquet  \
# Andy Roddick                        1.0           1.0              2.0
# Peter Luczak                        0.0           0.0              0.0
# Carsten Ball                        0.0           0.0              0.0
# Mischa Zverev                       0.0           1.0              4.0
# Richard Gasquet                     0.0           0.0              0.0
# ...                                 ...           ...              ...
# Daniel Azar                         0.0           0.0              0.0
# Fajing Sun                          0.0           0.0              0.0
# Alvaro Guillen Meza                 0.0           0.0              0.0
# Chris Rodesch                       0.0           0.0              0.0
# Joaquin  Aguilar Cardozo            0.0           0.0              0.0
#
#                            Tomas Berdych  Radek Stepanek  Thiemo De Bakker  \
# Andy Roddick                         6.0             2.0               3.0
# Peter Luczak                         1.0             0.0               0.0
# Carsten Ball                         1.0             0.0               0.0
# Mischa Zverev                        3.0             0.0               0.0
# Richard Gasquet                     15.0             2.0               2.0
# ...                                  ...             ...               ...
# Daniel Azar                          0.0             0.0               0.0
# Fajing Sun                           0.0             0.0               0.0
# Alvaro Guillen Meza                  0.0             0.0               0.0
# Chris Rodesch                        0.0             0.0               0.0
# Joaquin  Aguilar Cardozo             0.0             0.0               0.0
#
#                            Thomaz Bellucci  Feliciano Lopez  \
# Andy Roddick                           1.0              3.0
# Peter Luczak                           0.0              0.0
# Carsten Ball                           0.0              0.0
# Mischa Zverev                          1.0              3.0
# Richard Gasquet                        4.0              4.0
# ...                                    ...              ...
# Daniel Azar                            0.0              0.0
# Fajing Sun                             0.0              0.0
# Alvaro Guillen Meza                    0.0              0.0
# Chris Rodesch                          0.0              0.0
# Joaquin  Aguilar Cardozo               0.0              0.0
#
#                            Fernando Gonzalez  Marin Cilic  ...  Conor Gannon  \
# Andy Roddick                             1.0          1.0  ...           0.0
# Peter Luczak                             0.0          0.0  ...           0.0
# Carsten Ball                             0.0          0.0  ...           0.0
# Mischa Zverev                            0.0          3.0  ...           0.0
# Richard Gasquet                          0.0          4.0  ...           0.0
# ...                                      ...          ...  ...           ...
# Daniel Azar                              0.0          0.0  ...           0.0
# Fajing Sun                               0.0          0.0  ...           0.0
# Alvaro Guillen Meza                      0.0          0.0  ...           0.0
# Chris Rodesch                            0.0          0.0  ...           0.0
# Joaquin  Aguilar Cardozo                 0.0          0.0  ...           0.0
#
#                            Alvaro Guillen Meza  Lucky Candra Kurniawan  \
# Andy Roddick                               0.0                     0.0
# Peter Luczak                               0.0                     0.0
# Carsten Ball                               0.0                     0.0
# Mischa Zverev                              0.0                     0.0
# Richard Gasquet                            0.0                     0.0
# ...                                        ...                     ...
# Daniel Azar                                0.0                     0.0
# Fajing Sun                                 0.0                     0.0
# Alvaro Guillen Meza                        0.0                     0.0
# Chris Rodesch                              0.0                     0.0
# Joaquin  Aguilar Cardozo                   0.0                     0.0
#
#                            Ignacio Buse  Jose  Flores  Freddy Murray  \
# Andy Roddick                        0.0           0.0            0.0
# Peter Luczak                        0.0           0.0            0.0
# Carsten Ball                        0.0           0.0            0.0
# Mischa Zverev                       0.0           0.0            0.0
# Richard Gasquet                     0.0           0.0            0.0
# ...                                 ...           ...            ...
# Daniel Azar                         0.0           0.0            0.0
# Fajing Sun                          0.0           0.0            0.0
# Alvaro Guillen Meza                 0.0           0.0            0.0
# Chris Rodesch                       0.0           0.0            0.0
# Joaquin  Aguilar Cardozo            0.0           0.0            0.0
#
#                            Walid Ahouda  Digvijaypratap Singh  Daniel Azar  \
# Andy Roddick                        0.0                   0.0          0.0
# Peter Luczak                        0.0                   0.0          0.0
# Carsten Ball                        0.0                   0.0          0.0
# Mischa Zverev                       0.0                   0.0          0.0
# Richard Gasquet                     0.0                   0.0          0.0
# ...                                 ...                   ...          ...
# Daniel Azar                         0.0                   0.0          0.0
# Fajing Sun                          0.0                   0.0          0.0
# Alvaro Guillen Meza                 0.0                   0.0          0.0
# Chris Rodesch                       0.0                   0.0          0.0
# Joaquin  Aguilar Cardozo            0.0                   0.0          0.0
#
#                            Mustapha El Natour
# Andy Roddick                              0.0
# Peter Luczak                              0.0
# Carsten Ball                              0.0
# Mischa Zverev                             0.0
# Richard Gasquet                           0.0
# ...                                       ...
# Daniel Azar                               1.0
# Fajing Sun                                0.0
# Alvaro Guillen Meza                       0.0
# Chris Rodesch                             0.0
# Joaquin  Aguilar Cardozo                  0.0
#
# [1533 rows x 1533 columns]

# %%
matches_data
# Out:
#                            Peter Luczak  Carsten Ball  Richard Gasquet  \
# Andy Roddick                        1.0           1.0              2.0
# Peter Luczak                        0.0           0.0              0.0
# Carsten Ball                        0.0           0.0              0.0
# Mischa Zverev                       0.0           1.0              4.0
# Richard Gasquet                     0.0           0.0              0.0
# ...                                 ...           ...              ...
# Daniel Azar                         0.0           0.0              0.0
# Fajing Sun                          0.0           0.0              0.0
# Alvaro Guillen Meza                 0.0           0.0              0.0
# Chris Rodesch                       0.0           0.0              0.0
# Joaquin  Aguilar Cardozo            0.0           0.0              0.0
#
#                            Tomas Berdych  Radek Stepanek  Thiemo De Bakker  \
# Andy Roddick                         6.0             2.0               3.0
# Peter Luczak                         1.0             0.0               0.0
# Carsten Ball                         1.0             0.0               0.0
# Mischa Zverev                        3.0             0.0               0.0
# Richard Gasquet                     15.0             2.0               2.0
# ...                                  ...             ...               ...
# Daniel Azar                          0.0             0.0               0.0
# Fajing Sun                           0.0             0.0               0.0
# Alvaro Guillen Meza                  0.0             0.0               0.0
# Chris Rodesch                        0.0             0.0               0.0
# Joaquin  Aguilar Cardozo             0.0             0.0               0.0
#
#                            Thomaz Bellucci  Feliciano Lopez  \
# Andy Roddick                           1.0              3.0
# Peter Luczak                           0.0              0.0
# Carsten Ball                           0.0              0.0
# Mischa Zverev                          1.0              3.0
# Richard Gasquet                        4.0              4.0
# ...                                    ...              ...
# Daniel Azar                            0.0              0.0
# Fajing Sun                             0.0              0.0
# Alvaro Guillen Meza                    0.0              0.0
# Chris Rodesch                          0.0              0.0
# Joaquin  Aguilar Cardozo               0.0              0.0
#
#                            Fernando Gonzalez  Marin Cilic  ...  Conor Gannon  \
# Andy Roddick                             1.0          1.0  ...           0.0
# Peter Luczak                             0.0          0.0  ...           0.0
# Carsten Ball                             0.0          0.0  ...           0.0
# Mischa Zverev                            0.0          3.0  ...           0.0
# Richard Gasquet                          0.0          4.0  ...           0.0
# ...                                      ...          ...  ...           ...
# Daniel Azar                              0.0          0.0  ...           0.0
# Fajing Sun                               0.0          0.0  ...           0.0
# Alvaro Guillen Meza                      0.0          0.0  ...           0.0
# Chris Rodesch                            0.0          0.0  ...           0.0
# Joaquin  Aguilar Cardozo                 0.0          0.0  ...           0.0
#
#                            Alvaro Guillen Meza  Lucky Candra Kurniawan  \
# Andy Roddick                               0.0                     0.0
# Peter Luczak                               0.0                     0.0
# Carsten Ball                               0.0                     0.0
# Mischa Zverev                              0.0                     0.0
# Richard Gasquet                            0.0                     0.0
# ...                                        ...                     ...
# Daniel Azar                                0.0                     0.0
# Fajing Sun                                 0.0                     0.0
# Alvaro Guillen Meza                        0.0                     0.0
# Chris Rodesch                              0.0                     0.0
# Joaquin  Aguilar Cardozo                   0.0                     0.0
#
#                            Ignacio Buse  Jose  Flores  Freddy Murray  \
# Andy Roddick                        0.0           0.0            0.0
# Peter Luczak                        0.0           0.0            0.0
# Carsten Ball                        0.0           0.0            0.0
# Mischa Zverev                       0.0           0.0            0.0
# Richard Gasquet                     0.0           0.0            0.0
# ...                                 ...           ...            ...
# Daniel Azar                         0.0           0.0            0.0
# Fajing Sun                          0.0           0.0            0.0
# Alvaro Guillen Meza                 0.0           0.0            0.0
# Chris Rodesch                       0.0           0.0            0.0
# Joaquin  Aguilar Cardozo            0.0           0.0            0.0
#
#                            Walid Ahouda  Digvijaypratap Singh  Daniel Azar  \
# Andy Roddick                        0.0                   0.0          0.0
# Peter Luczak                        0.0                   0.0          0.0
# Carsten Ball                        0.0                   0.0          0.0
# Mischa Zverev                       0.0                   0.0          0.0
# Richard Gasquet                     0.0                   0.0          0.0
# ...                                 ...                   ...          ...
# Daniel Azar                         0.0                   0.0          0.0
# Fajing Sun                          0.0                   0.0          0.0
# Alvaro Guillen Meza                 0.0                   0.0          0.0
# Chris Rodesch                       0.0                   0.0          0.0
# Joaquin  Aguilar Cardozo            0.0                   0.0          0.0
#
#                            Mustapha El Natour
# Andy Roddick                              0.0
# Peter Luczak                              0.0
# Carsten Ball                              0.0
# Mischa Zverev                             0.0
# Richard Gasquet                           0.0
# ...                                       ...
# Daniel Azar                               1.0
# Fajing Sun                                0.0
# Alvaro Guillen Meza                       0.0
# Chris Rodesch                             0.0
# Joaquin  Aguilar Cardozo                  0.0
#
# [1533 rows x 1533 columns]

# %%
data
# Out:
#                        tourney_name surface  draw_size tourney_level  best_of  \
# 0                          Brisbane    Hard         28             A        3
# 1                          Brisbane    Hard         28             A        3
# 2                          Brisbane    Hard         28             A        3
# 3                          Brisbane    Hard         28             A        3
# 4                          Brisbane    Hard         28             A        3
# ...                             ...     ...        ...           ...      ...
# 27403  Davis Cup WG2 R1: SLO vs LUX    Clay          4             D        3
# 27404  Davis Cup WG2 R1: SLO vs LUX    Clay          4             D        3
# 27405  Davis Cup WG2 R1: URU vs EGY    Clay          4             D        3
# 27406  Davis Cup WG2 R1: URU vs EGY    Clay          4             D        3
# 27407  Davis Cup WG2 R1: URU vs EGY    Clay          4             D        3
#
#                      winner_name  winner_age                       loser_name  \
# 0                Jarkko Nieminen        32.4                  James Duckworth
# 1              Marinko Matosevic        28.3                 Julien Benneteau
# 2                    Sam Querrey        26.2                  Dmitry Tursunov
# 3                      Sam Groth        26.1                    Ryan Harrison
# 4                  Nicolas Mahut        31.9                    Igor Sijsling
# ...                          ...         ...                              ...
# 27403                  Blaz Rola        32.9                       Alex Knaff
# 27404              Chris Rodesch        22.1                       Bor Artnak
# 27405             Mohamed Safwat        32.9                    Ignacio Carou
# 27406      Karim Mohamed Maamoun        32.4                Franco Roncadelli
# 27407  Joaquin  Aguilar Cardozo         18.4  Amr Elsayed Abdou Ahmed Mohamed
#
#        loser_age  Year
# 0           21.9  2014
# 1           32.0  2014
# 2           31.0  2014
# 3           21.6  2014
# 4           26.3  2014
# ...          ...   ...
# 27403       25.7  2023
# 27404       19.2  2023
# 27405       24.1  2023
# 27406       23.5  2023
# 27407       24.5  2023
#
# [27408 rows x 10 columns]

# %% [markdown]
# $f(t) = e^{-\lambda \times t}$

# %%
import math

# %%
[0.95 * math.exp(-0.0075 * (37-25)) ** i for i in range(5)]
# Out:
# [0.95,
#  0.8682346260076668,
#  0.7935067008407084,
#  0.7252105196200105,
#  0.6627925097674795]

# %%
import math

def decay_factor(year_difference, decay_rate=0.3):
    """
    Calculate the decay factor based on the year difference from the present.
    
    :param year_difference: The difference in years from the present.
    :param decay_rate: The rate at which the weight decays (higher value means faster decay).
    :return: The decay factor for the given year difference.
    """
    #weight = 1 - decay_rate * abs(year_difference)
    return math.exp(-decay_rate * abs(year_difference))

# Example usage
current_year = 2023
match_year = 2014

# Calculate the year difference from the current year
year_difference = match_year - current_year

# Get the decay factor for this match
weight = decay_factor(year_difference)

print(f"Decay weight for match in {match_year}: {weight:.4f}")
# Out:
# Decay weight for match in 2014: 0.0672

# %%
data
# Out:
#                        tourney_name surface  draw_size tourney_level  best_of  \
# 0                          Brisbane    Hard         32             A        3
# 1                          Brisbane    Hard         32             A        3
# 2                          Brisbane    Hard         32             A        3
# 3                          Brisbane    Hard         32             A        3
# 4                          Brisbane    Hard         32             A        3
# ...                             ...     ...        ...           ...      ...
# 39361  Davis Cup WG2 R1: SLO vs LUX    Clay          4             D        3
# 39362  Davis Cup WG2 R1: SLO vs LUX    Clay          4             D        3
# 39363  Davis Cup WG2 R1: URU vs EGY    Clay          4             D        3
# 39364  Davis Cup WG2 R1: URU vs EGY    Clay          4             D        3
# 39365  Davis Cup WG2 R1: URU vs EGY    Clay          4             D        3
#
#                      winner_name  winner_age                       loser_name  \
# 0                   Andy Roddick        27.3                     Peter Luczak
# 1                   Carsten Ball        22.5                    Mischa Zverev
# 2                Richard Gasquet        23.5                  Jarkko Nieminen
# 3                  Matthew Ebden        22.1                    Jurgen Melzer
# 4                  Tomas Berdych        24.2                     Nick Lindahl
# ...                          ...         ...                              ...
# 39361                  Blaz Rola        32.9                       Alex Knaff
# 39362              Chris Rodesch        22.1                       Bor Artnak
# 39363             Mohamed Safwat        32.9                    Ignacio Carou
# 39364      Karim Mohamed Maamoun        32.4                Franco Roncadelli
# 39365  Joaquin  Aguilar Cardozo         18.4  Amr Elsayed Abdou Ahmed Mohamed
#
#        loser_age  Year
# 0           30.3  2010
# 1           22.3  2010
# 2           28.4  2010
# 3           28.6  2010
# 4           21.4  2010
# ...          ...   ...
# 39361       25.7  2023
# 39362       19.2  2023
# 39363       24.1  2023
# 39364       23.5  2023
# 39365       24.5  2023
#
# [39366 rows x 10 columns]

# %%
import pandas as pd
import itertools


games_played = {}
wins = {}

    # Iterate through the matches to populate the games_played and wins dictionaries
for _, row in data.iterrows():
    winner = row['winner_name']
    loser = row['loser_name']
    
        # Initialize game count for winner and loser if not already in the dictionary
    if winner not in games_played:
        games_played[winner] = {}
        wins[winner] = {}
            
    if loser not in games_played:
        games_played[loser] = {}
        wins[loser] = {}
            
        # Update games played and wins for both winner and loser against each other
    if loser not in games_played[winner]:
        games_played[winner][loser] = 0
        wins[winner][loser] = 0
    if winner not in games_played[loser]:
        games_played[loser][winner] = 0
        wins[loser][winner] = 0
    
    games_played[winner][loser] += 1
    games_played[loser][winner] += 1
    wins[winner][loser] += 1

    # Calculate win percentages
win_percentages = {}
for player in games_played:
    win_percentages[player] = {}
    for opponent in games_played[player]:
        total_games = games_played[player][opponent]
        total_wins = wins[player][opponent]
        win_percentage = total_wins / total_games if total_games > 0 else 0
        win_percentages[player][opponent] = win_percentage

win_percentage_df = pd.DataFrame(win_percentages).T.fillna(0)

    # Create a DataFrame for games played
games_played_df = pd.DataFrame(games_played).T.fillna(0)

# %%
games_played_df.index.name = 'Player_Name'

# %%
win_percentages['Roger Federer']['Novak Djokovic']
# Out:
# 0.35

# %%
pd.DataFrame(win_percentages).fillna(0)['Roger Federer']['Novak Djokovic']
# Out:
# 0.35

# %%
games_played_df.loc['Andy Murray'].sum()
# Out:
# 438.0

# %%
data[(data['winner_name'] == 'Andy Murray') | (data['loser_name'] == 'Andy Murray')]
# Out:
#                           tourney_name surface  draw_size tourney_level  \
# 65                                Doha    Hard         32             A
# 75                                Doha    Hard         32             A
# 155                    Australian Open    Hard        128             G
# 211                    Australian Open    Hard        128             G
# 239                    Australian Open    Hard        128             G
# ...                                ...     ...        ...           ...
# 26954                 Shanghai Masters    Hard        128             M
# 27051                            Basel    Hard         32             A
# 27060                            Basel    Hard         32             A
# 27145                    Paris Masters    Hard         64             M
# 27267  Davis Cup Finals RR: GBR vs SUI    Hard          2             D
#
#        best_of              winner_name  winner_age          loser_name  \
# 65           3              Andy Murray        26.6  Mousa Shanan Zayed
# 75           3            Florian Mayer        30.2         Andy Murray
# 155          5              Andy Murray        26.6            Go Soeda
# 211          5              Andy Murray        26.6      Vincent Millot
# 239          5              Andy Murray        26.6     Feliciano Lopez
# ...        ...                      ...         ...                 ...
# 26954        3          Roman Safiullin        26.1         Andy Murray
# 27051        3  Tomas Martin Etcheverry        24.2         Andy Murray
# 27060        3              Andy Murray        36.4    Yannick Hanfmann
# 27145        3           Alex De Minaur        24.6         Andy Murray
# 27267        3              Andy Murray        36.3       Leandro Riedi
#
#        loser_age  Year winner_age_group loser_age_group
# 65          19.8  2014            26-27           19-20
# 75          26.6  2014            30-31           26-27
# 155         29.3  2014            26-27           29-30
# 211         27.9  2014            26-27           27-28
# 239         32.3  2014            26-27           32-33
# ...          ...   ...              ...             ...
# 26954       36.3  2023            26-27           36-37
# 27051       36.4  2023            24-25           36-37
# 27060       31.9  2023            36-37           31-32
# 27145       36.4  2023            24-25           36-37
# 27267       21.6  2023            36-37           21-22
#
# [438 rows x 12 columns]

# %%
wins
# Out:
# {'Andy Roddick': {'Peter Luczak': 1,
#   'Carsten Ball': 1,
#   'Richard Gasquet': 1,
#   'Tomas Berdych': 3,
#   'Radek Stepanek': 2,
#   'Thiemo De Bakker': 3,
#   'Thomaz Bellucci': 1,
#   'Feliciano Lopez': 2,
#   'Fernando Gonzalez': 1,
#   'Marin Cilic': 0,
#   'Ryler Deheart': 1,
#   'Leonardo Mayer': 1,
#   'Sam Querrey': 3,
#   'Fernando Verdasco': 1,
#   'James Blake': 3,
#   'Yen Hsun Lu': 3,
#   'Jurgen Melzer': 1,
#   'Tommy Robredo': 1,
#   'Robin Soderling': 2,
#   'Ivan Ljubicic': 0,
#   'Igor Andreev': 1,
#   'Sergiy Stakhovsky': 2,
#   'Benjamin Becker': 1,
#   'Nicolas Almagro': 2,
#   'Rafael Nadal': 1,
#   'Jarkko Nieminen': 2,
#   'Blaz Kavcic': 1,
#   'Teymuraz Gabashvili': 0,
#   'Igor Kunitsyn': 2,
#   'Dudi Sela': 0,
#   'Rajeev Ram': 2,
#   'Michael Llodra': 1,
#   'Philipp Kohlschreiber': 2,
#   'Xavier Malisse': 1,
#   'Mardy Fish': 0,
#   'Grega Zemlja': 1,
#   'Gilles Simon': 0,
#   'Novak Djokovic': 1,
#   'Stephane Robert': 1,
#   'Janko Tipsarevic': 1,
#   'Tatsuma Ito': 1,
#   'Jeremy Chardy': 2,
#   'Gael Monfils': 0,
#   'Guillermo Garcia Lopez': 0,
#   'Andrey Golubev': 1,
#   'David Nalbandian': 1,
#   'Roger Federer': 1,
#   'Ernests Gulbis': 1,
#   'Marinko Matosevic': 1,
#   'Alexandr Dolgopolov': 1,
#   'Marcos Baghdatis': 1,
#   'Kevin Anderson': 2,
#   'Jan Hajek': 1,
#   'Robin Haase': 2,
#   'Stan Wawrinka': 0,
#   'Ricardas Berankis': 1,
#   'Lleyton Hewitt': 1,
#   'Juan Martin del Potro': 1,
#   'Milos Raonic': 1,
#   'Nicolas Massu': 1,
#   'Paul Capdeville': 1,
#   'John Isner': 2,
#   'Pablo Cuevas': 0,
#   'Flavio Cipolla': 0,
#   'Andy Murray': 0,
#   'Andreas Beck': 1,
#   'Victor Hanescu': 1,
#   'David Ferrer': 1,
#   'Edouard Roger Vasselin': 1,
#   'Santiago Giraldo': 1,
#   'Juan Monaco': 1,
#   'Michael Russell': 2,
#   'Jack Sock': 1,
#   'Julien Benneteau': 2,
#   'Grigor Dimitrov': 1,
#   'Tommy Haas': 1,
#   'Denis Kudla': 1,
#   'Denis Istomin': 1,
#   'Philipp Petzschner': 1,
#   'Lukasz Kubot': 1,
#   'Gilles Muller': 2,
#   'Go Soeda': 0,
#   'Carlos Berlocq': 0,
#   'Nicolas Mahut': 1,
#   'Fabio Fognini': 2,
#   'Steve Darcis': 1,
#   'Andreas Seppi': 1,
#   'Jamie Baker': 1,
#   'Bjorn Phau': 1,
#   'Martin Klizan': 1,
#   'Rhyne Williams': 1,
#   'Bernard Tomic': 1},
#  'Peter Luczak': {'Andy Roddick': 0,
#   'Jose Acasuso': 1,
#   'Tomas Berdych': 1,
#   'Mardy Fish': 0,
#   'Rafael Nadal': 0,
#   'Potito Starace': 1,
#   'David Marrero': 1,
#   'Juan Monaco': 0,
#   'Juan Ignacio Chela': 0,
#   'Frederico Gil': 0,
#   'Chu Huan Yi': 1,
#   'Tsung Hua Yang': 1,
#   'Arnaud Clement': 0,
#   'Oscar Hernandez': 1,
#   'Robin Soderling': 0,
#   'David Ferrer': 0,
#   'Ernests Gulbis': 0,
#   'Filippo Volandri': 0,
#   'Sam Querrey': 0,
#   'Jan Hajek': 0,
#   'Daniel Gimeno Traver': 0,
#   'Roger Federer': 0,
#   'Lleyton Hewitt': 0,
#   'Michael Russell': 1,
#   'Marcos Baghdatis': 1,
#   'Janko Tipsarevic': 0,
#   'Tommy Robredo': 1,
#   'Pere Riba': 0,
#   'Daniel Brands': 0,
#   'Leonardo Mayer': 1,
#   'Sergiy Stakhovsky': 0,
#   'Olivier Rochus': 0,
#   'Kevin Anderson': 0,
#   'Ivan Ljubicic': 0,
#   'Pablo Andujar': 0,
#   'Alexander Sadecky': 1,
#   'Stan Wawrinka': 0},
#  'Carsten Ball': {'Mischa Zverev': 1,
#   'Andy Roddick': 0,
#   'Mardy Fish': 0,
#   'Fernando Verdasco': 0,
#   'Yuichi Sugita': 1,
#   'Tatsuma Ito': 1,
#   'Tomas Berdych': 0,
#   'Philipp Petzschner': 1,
#   'Viktor Troicki': 0,
#   'Ricardas Berankis': 0,
#   'Brian Dabul': 0,
#   'Milos Raonic': 1,
#   'Albert Montanes': 0,
#   'Olivier Rochus': 0,
#   'Steve Darcis': 0,
#   'Pere Riba': 0},
#  'Mischa Zverev': {'Carsten Ball': 0,
#   'Lukasz Kubot': 0,
#   'Mikhail Kukushkin': 3,
#   'Igor Sijsling': 0,
#   'David Guez': 1,
#   'Tommy Robredo': 1,
#   'Guillaume Rufin': 1,
#   'Michael Llodra': 0,
#   'Michael Russell': 1,
#   'Mardy Fish': 0,
#   'Nicolas Almagro': 1,
#   'Nicolas Massu': 0,
#   'Sergiy Stakhovsky': 3,
#   'Kevin Anderson': 0,
#   'Nicolas Mahut': 1,
#   'Florent Serra': 1,
#   'Jurgen Melzer': 2,
#   'Benjamin Becker': 0,
#   'Andrey Golubev': 0,
#   'Horacio Zeballos': 2,
#   'Jarkko Nieminen': 1,
#   'Richard Gasquet': 1,
#   'Gilles Simon': 0,
#   'Nikolay Davydenko': 1,
#   'Juan Monaco': 0,
#   'Robin Haase': 2,
#   'Illya Marchenko': 0,
#   'Janko Tipsarevic': 0,
#   'Blaz Kavcic': 1,
#   'Marin Cilic': 0,
#   'Matthew Ebden': 1,
#   'Andreas Seppi': 1,
#   'Igor Kunitsyn': 0,
#   'Juan Carlos Ferrero': 0,
#   'Dudi Sela': 1,
#   'Philipp Petzschner': 0,
#   'Viktor Troicki': 1,
#   'Xavier Malisse': 0,
#   'Alex Bogomolov Jr': 0,
#   'Pavol Cervenak': 0,
#   'Igor Andreev': 0,
#   'Ryan Harrison': 1,
#   'Julien Benneteau': 0,
#   'Marcel Granollers': 1,
#   'Tomas Berdych': 0,
#   'David Goffin': 1,
#   'Mirza Basic': 1,
#   'Roger Federer': 0,
#   'Ricardas Berankis': 0,
#   'Albano Olivetti': 0,
#   'Adrian Mannarino': 1,
#   'Jan Lennard Struff': 2,
#   'Andy Murray': 1,
#   'Dominic Thiem': 1,
#   'Sam Groth': 0,
#   'Pablo Carreno Busta': 1,
#   'Jo-Wilfried Tsonga': 0,
#   'Rajeev Ram': 1,
#   'Feliciano Lopez': 0,
#   'Gilles Muller': 0,
#   'Thomaz Bellucci': 1,
#   'Fabio Fognini': 2,
#   'Roberto Bautista Agut': 0,
#   'Ramkumar Ramanathan': 1,
#   'Denis Kudla': 0,
#   'Santiago Giraldo': 0,
#   'Thiago Monteiro': 0,
#   'Facundo Bagnis': 1,
#   'Dusan Lajovic': 0,
#   'Ivo Karlovic': 0,
#   'Pierre Hugues Herbert': 2,
#   'Jack Sock': 0,
#   'Paolo Lorenzi': 1,
#   'Zhe Li': 1,
#   'Ze Zhang': 1,
#   'Nick Kyrgios': 1,
#   'Novak Djokovic': 0,
#   'Taylor Fritz': 1,
#   'Guido Pella': 1,
#   'Stan Wawrinka': 1,
#   'John Isner': 3,
#   'Alex De Minaur': 1,
#   'Rafael Nadal': 0,
#   'Guillermo Garcia Lopez': 1,
#   'Malek Jaziri': 2,
#   'Ruben Bemelmans': 0,
#   'Kenny De Schepper': 1,
#   'Grigor Dimitrov': 0,
#   'Joao Sousa': 1,
#   'Jared Donaldson': 0,
#   'Jiri Vesely': 0,
#   'Daniel Evans': 0,
#   'Dustin Brown': 1,
#   'Martin Klizan': 0,
#   'Borna Coric': 0,
#   'Steve Johnson': 2,
#   'Kei Nishikori': 1,
#   'Stefano Napolitano': 0,
#   'Yannick Hanfmann': 1,
#   'Tommy Haas': 1,
#   'Lukas Lacko': 2,
#   'Bernard Tomic': 1,
#   'Norbert Gombos': 1,
#   'Fernando Verdasco': 1,
#   'Thai Son Kwiatkowski': 1,
#   'Benoit Paire': 1,
#   'Sam Querrey': 0,
#   'Henri Laaksonen': 1,
#   'Peter Gojowczyk': 0,
#   'Mikael Ymer': 1,
#   'Leonardo Mayer': 0,
#   'Hyeon Chung': 0,
#   'John Patrick Smith': 1,
#   'Michael Mmoh': 0,
#   'Karen Khachanov': 0,
#   'Juan Martin del Potro': 0,
#   'Felix Auger Aliassime': 1,
#   'Lucas Pouille': 1,
#   'Andreas Haider Maurer': 1,
#   'Philipp Kohlschreiber': 0,
#   'Federico Delbonis': 0,
#   'Florian Mayer': 1,
#   'Mikhail Youzhny': 2,
#   'Nicolas Jarry': 1,
#   'Denis Shapovalov': 1,
#   'Vasek Pospisil': 0,
#   'Tim Smyczek': 3,
#   'Alexander Zverev': 0,
#   'Damir Dzumhur': 1,
#   'Yannick Maden': 0,
#   'Filip Krajinovic': 0,
#   'Alexei Popyrin': 0,
#   'Nikoloz Basilashvili': 0,
#   'Nicola Kuhn': 1,
#   'Taro Daniel': 0,
#   'David Ferrer': 0,
#   'Juan Ignacio Londero': 0,
#   'Steve Darcis': 0,
#   'Guido Andreozzi': 1,
#   'Hubert Hurkacz': 0,
#   'John Millman': 1,
#   'James Duckworth': 0},
#  'Richard Gasquet': {'Jarkko Nieminen': 3,
#   'Matthew Ebden': 3,
#   'Andy Roddick': 1,
#   'Feliciano Lopez': 3,
#   'Benjamin Becker': 1,
#   'Potito Starace': 2,
#   'Julien Benneteau': 3,
#   'Marcos Baghdatis': 1,
#   'Mikhail Youzhny': 5,
#   'Juan Ignacio Chela': 1,
#   'Carlos Moya': 1,
#   'Nicolas Almagro': 4,
#   'Simon Greul': 1,
#   'Olivier Rochus': 5,
#   'Andrey Golubev': 2,
#   'Victor Hanescu': 0,
#   'Daniel Gimeno Traver': 1,
#   'Tomas Berdych': 6,
#   'Igor Andreev': 2,
#   'Fernando Verdasco': 3,
#   'Andreas Seppi': 6,
#   'John Isner': 2,
#   'Lukas Lacko': 3,
#   'Alexandr Dolgopolov': 3,
#   'Andy Murray': 2,
#   'Kei Nishikori': 7,
#   'Rajeev Ram': 1,
#   'Rainer Schuettler': 0,
#   'Farrukh Dustov': 1,
#   'Daniel Brands': 2,
#   'Albert Montanes': 4,
#   'Yuri Schukin': 1,
#   'Kristof Vliegen': 0,
#   'Sergiy Stakhovsky': 2,
#   'Michael Berrer': 1,
#   'Mardy Fish': 1,
#   'Nikolay Davydenko': 5,
#   'Kevin Anderson': 7,
#   'Gael Monfils': 5,
#   'Paul Henri Mathieu': 3,
#   'Tommy Robredo': 1,
#   'Mischa Zverev': 3,
#   'Thiemo De Bakker': 2,
#   'Dmitry Tursunov': 1,
#   'Ernests Gulbis': 3,
#   'Novak Djokovic': 0,
#   'Julian Reister': 1,
#   'Yen Hsun Lu': 2,
#   'Tobias Kamke': 2,
#   'Viktor Troicki': 3,
#   'Nicolas Mahut': 2,
#   'Roger Federer': 1,
#   'Edouard Roger Vasselin': 1,
#   'Bjorn Phau': 0,
#   'Frank Dancevic': 1,
#   'Adrian Mannarino': 2,
#   'Arnaud Clement': 1,
#   'Grigor Dimitrov': 5,
#   'Sergei Bubka': 1,
#   'Gilles Simon': 5,
#   'Pablo Cuevas': 1,
#   'Jurgen Melzer': 3,
#   'Paolo Lorenzi': 4,
#   'Denis Istomin': 5,
#   'Guillermo Garcia Lopez': 3,
#   'Rafael Nadal': 0,
#   'Blaz Kavcic': 3,
#   'Radek Stepanek': 1,
#   'Marcel Granollers': 4,
#   'Thomaz Bellucci': 4,
#   'Santiago Giraldo': 1,
#   'Igor Kunitsyn': 2,
#   'Simone Bolelli': 3,
#   'Florian Mayer': 4,
#   'Ivo Karlovic': 5,
#   'Gilles Muller': 3,
#   'Fabio Fognini': 1,
#   'Janko Tipsarevic': 2,
#   'David Ferrer': 2,
#   'Philipp Kohlschreiber': 0,
#   'Flavio Cipolla': 1,
#   'Alex Bogomolov Jr': 1,
#   'Go Soeda': 2,
#   'Juan Martin del Potro': 0,
#   'Albert Ramos': 4,
#   'Cedrik Marcel Stebe': 1,
#   'Daniel Munoz de la Nava': 1,
#   'Jurgen Zopp': 1,
#   'Tommy Haas': 1,
#   'Marinko Matosevic': 1,
#   'Ruben Bemelmans': 1,
#   'Robin Haase': 7,
#   'Mikhail Kukushkin': 3,
#   'Milos Raonic': 1,
#   'Bradley Klahn': 1,
#   'Steve Johnson': 3,
#   'Bernard Tomic': 8,
#   'Ze Zhang': 0,
#   'Brian Baker': 1,
#   'Marco Chiudinelli': 1,
#   'Jan Hernych': 1,
#   'Grega Zemlja': 1,
#   'Alejandro Falla': 1,
#   'Ivan Dodig': 2,
#   'Jo-Wilfried Tsonga': 0,
#   'Dudi Sela': 2,
#   'Amir Weintraub': 1,
#   'Benoit Paire': 8,
#   'Jerzy Janowicz': 3,
#   'Marin Cilic': 2,
#   'Sam Querrey': 3,
#   'Michal Przysiezny': 1,
#   'Stan Wawrinka': 2,
#   'Martin Klizan': 2,
#   'Michael Russell': 1,
#   'Stephane Robert': 2,
#   'Vasek Pospisil': 2,
#   'Evgeny Donskoy': 2,
#   'Teymuraz Gabashvili': 2,
#   'Michael Llodra': 0,
#   'Karim Hossam': 1,
#   'David Guez': 1,
#   'Nick Kyrgios': 6,
#   'Albano Olivetti': 1,
#   'Alejandro Gonzalez': 1,
#   'Carlos Berlocq': 5,
#   'James Duckworth': 2,
#   'Sam Groth': 1,
#   'Victor Estrella': 2,
#   'Tim Smyczek': 1,
#   'Juan Monaco': 0,
#   'Jeremy Chardy': 4,
#   'Roberto Bautista Agut': 2,
#   'Pablo Andujar': 1,
#   'Lucas Pouille': 1,
#   'Kenny De Schepper': 3,
#   'Thomas Fabbiano': 2,
#   'Germain Gigounon': 1,
#   'Luke Saville': 1,
#   'Jack Sock': 0,
#   'Thanasi Kokkinakis': 2,
#   'Steve Darcis': 1,
#   'Jiri Vesely': 2,
#   'Dominic Thiem': 2,
#   'Leonardo Mayer': 2,
#   'Dustin Brown': 1,
#   'Philip Bester': 1,
#   'Roberto Carballes Baena': 3,
#   'Bjorn Fratangelo': 1,
#   'Aljaz Bedene': 2,
#   'Daniel Evans': 2,
#   'John Millman': 1,
#   'Kyle Edmund': 1,
#   'Borna Coric': 1,
#   'Andrew Whittington': 1,
#   'Pablo Carreno Busta': 1,
#   'Inigo Cervantes Huegun': 1,
#   'Jan Lennard Struff': 2,
#   'Diego Schwartzman': 4,
#   'Guido Pella': 0,
#   'Blake Mott': 1,
#   'Taro Daniel': 2,
#   'Malek Jaziri': 2,
#   'Alexander Zverev': 0,
#   'Yuichi Sugita': 2,
#   'Arthur De Greef': 1,
#   'Frances Tiafoe': 1,
#   'Brayden Schnur': 1,
#   'John Patrick Smith': 1,
#   'David Goffin': 3,
#   'Hyeon Chung': 1,
#   'Stefanos Tsitsipas': 2,
#   'Lorenzo Sonego': 1,
#   'Daniil Medvedev': 2,
#   'Pierre Hugues Herbert': 1,
#   'Damir Dzumhur': 2,
#   'Dusan Lajovic': 0,
#   'Gerald Melzer': 1,
#   'Casper Ruud': 1,
#   'Henri Laaksonen': 2,
#   'Nicolas Jarry': 1,
#   'Laslo Djere': 1,
#   'Constant Lestienne': 2,
#   'Denis Kudla': 1,
#   'Denis Shapovalov': 1,
#   'Alejandro Davidovich Fokina': 1,
#   'Taylor Fritz': 1,
#   'Maxime Janvier': 1,
#   'Juan Ignacio Londero': 2,
#   'Jordan Thompson': 0,
#   'Peter Gojowczyk': 1,
#   'Dennis Novak': 1,
#   'Sumit Nagal': 1,
#   'Federico Delbonis': 1,
#   'Matteo Berrettini': 0,
#   'Soon Woo Kwon': 1,
#   'Mikael Ymer': 1,
#   'Lloyd Harris': 2,
#   'J J Wolf': 1,
#   'Alex De Minaur': 0,
#   'Salvatore Caruso': 1,
#   'Jonas Forejtek': 1,
#   'Marco Cecchinato': 1,
#   'Reilly Opelka': 0,
#   'Alessandro Giannessi': 1,
#   'Daniel Altmaier': 2,
#   'Carlos Alcaraz': 0,
#   'Blaz Rola': 1,
#   'Andrey Rublev': 0,
#   'Hubert Hurkacz': 0,
#   'Hugo Gaston': 1,
#   'Egor Gerasimov': 1,
#   'Emil Ruusuvuori': 0,
#   'Cristian Garin': 0,
#   'Gregoire Barrere': 1,
#   'Karen Khachanov': 0,
#   'Mackenzie Mcdonald': 1,
#   'Pedro Martinez': 1,
#   'Jaume Munar': 0,
#   'Tomas Machac': 0,
#   'Ugo Humbert': 2,
#   'Botic Van De Zandschulp': 0,
#   'Oscar Otte': 0,
#   'Federico Coria': 0,
#   'Pavel Kotov': 1,
#   'Miomir Kecmanovic': 1,
#   'Sebastian Baez': 0,
#   'Hugo Dellien': 1,
#   'Tommy Paul': 1,
#   'Joao Sousa': 2,
#   'Kamil Majchrzak': 2,
#   'Sebastian Korda': 0,
#   'Sebastian Ofner': 0,
#   'Lorenzo Musetti': 1,
#   'Brandon Nakashima': 1,
#   'Felix Auger Aliassime': 0,
#   'Dominic Stricker': 1,
#   'Alex Molcan': 1,
#   'Jason Kubler': 1,
#   'Michael Geerts': 1,
#   'Marcos Giron': 0,
#   'Cameron Norrie': 1,
#   'Kiranpal Pannu': 1,
#   'Arthur Fils': 0,
#   'Laurent Lokoli': 1,
#   'Jannik Sinner': 0,
#   'Borna Gojo': 1,
#   'Christopher Oconnell': 1,
#   'Alexandre Muller': 0,
#   'Dino Prizmic': 1,
#   'Martin Landaluce': 1,
#   'Yibing Wu': 0,
#   'Arthur Rinderknech': 0,
#   'Christopher Eubanks': 1,
#   'Corentin Moutet': 0,
#   'Marc Andrea Huesler': 1,
#   'Fabian Marozsan': 0,
#   'Zhizhen Zhang': 0,
#   'Maximilian Marterer': 0},
#  'Jarkko Nieminen': {'Richard Gasquet': 1,
#   'Nick Lindahl': 1,
#   'Florent Serra': 2,
#   'Yen Hsun Lu': 0,
#   'Lars Poerschke': 1,
#   'Tomas Berdych': 1,
#   'Dudi Sela': 2,
#   'John Isner': 0,
#   'Paolo Lorenzi': 1,
#   'Evgeny Korolev': 1,
#   'Benjamin Becker': 6,
#   'Ernests Gulbis': 0,
#   'Michal Przysiezny': 4,
#   'Lukasz Kubot': 3,
#   'Mehdi Ziadi': 1,
#   'Victor Hanescu': 1,
#   'Juan Monaco': 1,
#   'Thomaz Bellucci': 1,
#   'Rik De Voest': 0,
#   'Sergiy Stakhovsky': 3,
#   'Andy Roddick': 0,
#   'Roger Federer': 0,
#   'Stefan Koubek': 1,
#   'Andy Murray': 0,
#   'Christian Lindell': 1,
#   'Nicolas Almagro': 0,
#   'Christophe Rochus': 1,
#   'Gilles Simon': 1,
#   'Juan Carlos Ferrero': 0,
#   'Thiago Alves': 1,
#   'Jeremy Chardy': 0,
#   'Tommy Robredo': 0,
#   'Andreas Seppi': 1,
#   'Viktor Troicki': 2,
#   'Daniel Gimeno Traver': 1,
#   'Kristof Vliegen': 1,
#   'Mischa Zverev': 0,
#   'Danai Udomchoke': 1,
#   'Jurgen Melzer': 1,
#   'Guillermo Garcia Lopez': 0,
#   'Jo-Wilfried Tsonga': 1,
#   'Radek Stepanek': 2,
#   'Michael Berrer': 1,
#   'James Blake': 2,
#   'Florian Mayer': 1,
#   'Ivan Ljubicic': 0,
#   'Daniel Brands': 2,
#   'Novak Djokovic': 0,
#   'Xavier Malisse': 1,
#   'Nikolay Davydenko': 1,
#   'Frederico Gil': 0,
#   'David Ferrer': 1,
#   'Grega Zemlja': 1,
#   'Blaz Kavcic': 1,
#   'Denis Istomin': 3,
#   'Albert Montanes': 0,
#   'Mikhail Kukushkin': 1,
#   'Julien Benneteau': 3,
#   'Rafael Nadal': 0,
#   'Carlos Berlocq': 0,
#   'Adrian Mannarino': 1,
#   'Maximo Gonzalez': 1,
#   'Denis Gremelmayr': 0,
#   'Santiago Giraldo': 2,
#   'Alexandr Dolgopolov': 1,
#   'Igor Kunitsyn': 1,
#   'Juan Martin del Potro': 1,
#   'Fernando Verdasco': 1,
#   'Grzegorz Panfil': 1,
#   'Dominic Thiem': 1,
#   'Robin Haase': 3,
#   'Gael Monfils': 0,
#   'Alex Bogomolov Jr': 0,
#   'Marius Copil': 2,
#   'Stan Wawrinka': 1,
#   'Tobias Kamke': 2,
#   'Jesse Levine': 1,
#   'James Duckworth': 2,
#   'Bobby Reynolds': 1,
#   'David Nalbandian': 1,
#   'Maxime Teixeira': 1,
#   'Paul Henri Mathieu': 2,
#   'Igor Sijsling': 4,
#   'Edouard Roger Vasselin': 1,
#   'Marin Cilic': 1,
#   'Tommy Haas': 2,
#   'Javier Marti': 1,
#   'Eduardo Schwank': 1,
#   'Feliciano Lopez': 1,
#   'Antonio Veic': 1,
#   'Benoit Paire': 2,
#   'Sam Querrey': 0,
#   'Igor Andreev': 1,
#   'Brian Baker': 0,
#   'Jan Hajek': 0,
#   'Somdev Devvarman': 1,
#   'Victor Crivoi': 1,
#   'Yuichi Sugita': 1,
#   'Philipp Petzschner': 1,
#   'Milos Raonic': 2,
#   'Kevin Anderson': 0,
#   'Lleyton Hewitt': 1,
#   'Bjorn Phau': 1,
#   'Ivo Klec': 1,
#   'Bernard Tomic': 1,
#   'Ivan Dodig': 0,
#   'David Goffin': 1,
#   'Matthias Bachinger': 2,
#   'Martin Klizan': 1,
#   'Colin Obrien': 1,
#   'Evgeny Donskoy': 1,
#   'Lukas Lacko': 1,
#   'Roberto Bautista Agut': 1,
#   'Ryan Harrison': 1,
#   'Daniel Evans': 0,
#   'Michael Llodra': 0,
#   'Filip Peliwo': 0,
#   'Mardy Fish': 1,
#   'Joao Sousa': 0,
#   'Alejandro Falla': 1,
#   'Mikhail Youzhny': 0,
#   'Fabio Fognini': 0,
#   'Alexandar Lazov': 1,
#   'Dimitar Kutrovsky': 1,
#   'Aleksandr Nedovyesov': 1,
#   'Pierre Hugues Herbert': 1,
#   'Marc Gicquel': 1,
#   'Donald Young': 0,
#   'Mirza Basic': 0,
#   'Damir Dzumhur': 1,
#   'Albert Ramos': 1,
#   'Leonardo Mayer': 2,
#   'Lukas Rosol': 0,
#   'Jerzy Janowicz': 0,
#   'Dmitry Tursunov': 1,
#   'Federico Delbonis': 1,
#   'Teymuraz Gabashvili': 1,
#   'Ivo Karlovic': 0,
#   'Philipp Oswald': 1,
#   'Pablo Andujar': 1,
#   'Kei Nishikori': 0,
#   'Vasek Pospisil': 0,
#   'Denis Kudla': 1,
#   'Andrey Golubev': 1,
#   'Jan Lennard Struff': 1,
#   'Steve Darcis': 0,
#   'Marco Cecchinato': 1,
#   'Renzo Olivo': 0,
#   'Romain Arneodo': 1,
#   'Benjamin Balleret': 1,
#   'Thiemo De Bakker': 1,
#   'Pablo Cuevas': 0,
#   'Marinko Matosevic': 1,
#   'Marsel Ilhan': 1,
#   'Andrey Rublev': 0,
#   'Alexander Zverev': 0,
#   'Rui Machado': 1,
#   'Tatsuma Ito': 0,
#   'Courtney John Lock': 1},
#  'Matthew Ebden': {'Jurgen Melzer': 1,
#   'Richard Gasquet': 0,
#   'Gael Monfils': 0,
#   'John Millman': 2,
#   'Denis Istomin': 1,
#   'Robin Soderling': 0,
#   'Michael Russell': 0,
#   'Mischa Zverev': 0,
#   'Somdev Devvarman': 1,
#   'Rafael Nadal': 0,
#   'Ryan Sweeting': 1,
#   'Matthias Bachinger': 2,
#   'Olivier Rochus': 0,
#   'Rajeev Ram': 2,
#   'Nikolay Davydenko': 0,
#   'David Goffin': 1,
#   'Pablo Andujar': 2,
#   'David Ferrer': 0,
#   'Ryan Harrison': 1,
#   'Gilles Simon': 2,
#   'Andy Murray': 0,
#   'Radek Stepanek': 0,
#   'Marcel Granollers': 1,
#   'Marcos Baghdatis': 1,
#   'Joao Souza': 1,
#   'Kei Nishikori': 0,
#   'Ya Nan Ma': 1,
#   'Dudi Sela': 1,
#   'Kevin Anderson': 0,
#   'Igor Kunitsyn': 1,
#   'Julien Benneteau': 1,
#   'Mardy Fish': 1,
#   'John Isner': 1,
#   'Sam Querrey': 1,
#   'Suk Young Jeong': 1,
#   'Albert Montanes': 0,
#   'Philipp Kohlschreiber': 1,
#   'Marin Cilic': 0,
#   'Steve Darcis': 0,
#   'Benoit Paire': 0,
#   'Milos Raonic': 0,
#   'Sergei Bubka': 1,
#   'James Blake': 1,
#   'Gilles Muller': 1,
#   'Michael Berrer': 1,
#   'Xavier Malisse': 0,
#   'Ruben Ramirez Hidalgo': 0,
#   'Peter Polansky': 2,
#   'Tatsuma Ito': 1,
#   'Jeremy Chardy': 0,
#   'Philip Davydenko': 1,
#   'Filippo Volandri': 1,
#   'Grega Zemlja': 0,
#   'Victor Hanescu': 1,
#   'Mikhail Youzhny': 0,
#   'Ti Chen': 1,
#   'Tsung Hua Yang': 1,
#   'Rik De Voest': 1,
#   'Jack Sock': 0,
#   'Andrey Kuznetsov': 1,
#   'Grigor Dimitrov': 0,
#   'Lleyton Hewitt': 0,
#   'Jimmy Wang': 1,
#   'Alejandro Falla': 0,
#   'Ivo Karlovic': 2,
#   'Alex Kuznetsov': 1,
#   'Nicolas Mahut': 1,
#   'Vasek Pospisil': 0,
#   'Teymuraz Gabashvili': 0,
#   'Lukasz Kubot': 1,
#   'Santiago Giraldo': 0,
#   'Robin Haase': 0,
#   'Pablo Cuevas': 0,
#   'Lukas Lacko': 1,
#   'Adrian Mannarino': 1,
#   'Roberto Bautista Agut': 0,
#   'James Ward': 0,
#   'Benjamin Becker': 0,
#   'Tobias Kamke': 2,
#   'Leonardo Mayer': 0,
#   'Simone Bolelli': 0,
#   'Blaz Rola': 1,
#   'Victor Estrella': 0,
#   'Austin Krajicek': 0,
#   'Thiemo De Bakker': 0,
#   'Henri Laaksonen': 0,
#   'Agustin Velotti': 1,
#   'Paolo Lorenzi': 0,
#   'Taylor Fritz': 1,
#   'Nikoloz Basilashvili': 0,
#   'Yuichi Sugita': 0,
#   'Peter Gojowczyk': 2,
#   'Dennis Novikov': 1,
#   'Feliciano Lopez': 0,
#   'Frances Tiafoe': 2,
#   'Nick Kyrgios': 0,
#   'Alexandr Dolgopolov': 0,
#   'Jared Donaldson': 0,
#   'Hyeon Chung': 0,
#   'Thomas Fabbiano': 0,
#   'Tim Smyczek': 1,
#   'Marius Copil': 1,
#   'Malek Jaziri': 1,
#   'Roger Federer': 0,
#   'Stephane Robert': 1,
#   'Donald Young': 1,
#   'Filip Krajinovic': 1,
#   'Evgeny Donskoy': 1,
#   'Matteo Berrettini': 1,
#   'Fabio Fognini': 0,
#   'Dominic Thiem': 1,
#   'Borna Coric': 0,
#   'Fernando Verdasco': 0,
#   'Alexei Popyrin': 0,
#   'Karen Khachanov': 1,
#   'Guido Andreozzi': 0,
#   'Jan Lennard Struff': 1,
#   'Adrian Andreev': 1,
#   'Stefanos Tsitsipas': 0,
#   'Radu Albot': 0,
#   'Nicolas Jarry': 0,
#   'Gregoire Barrere': 0,
#   'Pierre Hugues Herbert': 0,
#   'Damir Dzumhur': 0,
#   'Diego Schwartzman': 0,
#   'Denis Kudla': 1,
#   'Brayden Schnur': 1,
#   'Bernard Tomic': 0,
#   'Kamil Majchrzak': 1,
#   'Benjamin Bonzi': 1,
#   'Emil Ruusuvuori': 1,
#   'Daniil Medvedev': 0,
#   'Elias Ymer': 0,
#   'Federico Delbonis': 1,
#   'Thiago Monteiro': 0,
#   'Yuki Bhambri': 1,
#   'Tim Van Rijthoven': 0},
#  'Jurgen Melzer': {'Matthew Ebden': 0,
#   'Fabio Fognini': 3,
#   'Sebastien Grosjean': 1,
#   'Arnaud Clement': 0,
#   'Florent Serra': 0,
#   'Daniel Brands': 1,
#   'Olivier Rochus': 2,
#   'Illya Marchenko': 2,
#   'Marin Cilic': 2,
#   'Viktor Troicki': 2,
#   'Andreas Seppi': 4,
#   'Nikolay Davydenko': 0,
#   'Simone Bolelli': 1,
#   'Tommy Robredo': 1,
#   'Mikhail Youzhny': 0,
#   'Martin Klizan': 1,
#   'Lukas Lacko': 2,
#   'David Nalbandian': 1,
#   'Simon Greul': 1,
#   'Andy Roddick': 0,
#   'Alejandro Falla': 3,
#   'Fernando Verdasco': 2,
#   'Paul Henri Mathieu': 1,
#   'Philipp Petzschner': 1,
#   'Nicolas Lapentti': 1,
#   'Oscar Hernandez': 1,
#   'Stan Wawrinka': 1,
#   'Kevin Anderson': 1,
#   'Mardy Fish': 1,
#   'Nicolas Almagro': 3,
#   'Dudi Sela': 3,
#   'Nicolas Mahut': 1,
#   'David Ferrer': 2,
#   'Teymuraz Gabashvili': 1,
#   'Novak Djokovic': 1,
#   'Rafael Nadal': 1,
#   'Alexander Kudryavtsev': 1,
#   'Mischa Zverev': 2,
#   'Dustin Brown': 1,
#   'Feliciano Lopez': 2,
#   'Roger Federer': 1,
#   'Albert Montanes': 1,
#   'Eduardo Schwank': 1,
#   'Jeremy Chardy': 1,
#   'Potito Starace': 1,
#   'Andrey Golubev': 0,
#   'Jan Hajek': 1,
#   'Peter Polansky': 0,
#   'Santiago Giraldo': 2,
#   'Ernests Gulbis': 0,
#   'Dmitry Tursunov': 3,
#   'Ricardas Berankis': 2,
#   'Juan Carlos Ferrero': 1,
#   'Harel Levy': 1,
#   'Jarkko Nieminen': 0,
#   'Juan Monaco': 1,
#   'Tsung Hua Yang': 1,
#   'Daniel Gimeno Traver': 3,
#   'Lukasz Kubot': 2,
#   'Philipp Kohlschreiber': 1,
#   'Andreas Haider Maurer': 1,
#   'Vincent Millot': 1,
#   'Pere Riba': 1,
#   'Marcos Baghdatis': 1,
#   'Andy Murray': 0,
#   'Jesse Huta Galung': 2,
#   'Gilles Simon': 1,
#   'Julien Benneteau': 1,
#   'Richard Gasquet': 0,
#   'Robin Haase': 3,
#   'Marcel Granollers': 2,
#   'Florian Mayer': 0,
#   'Andreas Beck': 1,
#   'Lukas Rosol': 1,
#   'Xavier Malisse': 1,
#   'Donald Young': 0,
#   'Igor Andreev': 0,
#   'Eric Prodon': 1,
#   'Igor Kunitsyn': 2,
#   'Steve Darcis': 1,
#   'Rik De Voest': 1,
#   'Tomas Berdych': 0,
#   'Ivan Ljubicic': 1,
#   'Guillermo Garcia Lopez': 2,
#   'Ivo Karlovic': 0,
#   'Michael Berrer': 0,
#   'Alex Bogomolov Jr': 1,
#   'Denis Istomin': 1,
#   'Ivan Dodig': 2,
#   'John Isner': 2,
#   'Radek Stepanek': 1,
#   'Milos Raonic': 2,
#   'Tim Smyczek': 0,
#   'Thomaz Bellucci': 0,
#   'Tatsuma Ito': 0,
#   'Sam Querrey': 1,
#   'Michael Mcclune': 1,
#   'Bradley Klahn': 0,
#   'Vasek Pospisil': 0,
#   'Pablo Andujar': 1,
#   'Alexandr Dolgopolov': 1,
#   'Gilles Muller': 0,
#   'Carlos Berlocq': 1,
#   'David Goffin': 3,
#   'Grigor Dimitrov': 0,
#   'Denis Kudla': 2,
#   'Greg Jones': 0,
#   'Mikhail Kukushkin': 2,
#   'Roberto Bautista Agut': 2,
#   'Evgeny Korolev': 0,
#   'Somdev Devvarman': 1,
#   'Igor Sijsling': 0,
#   'Joao Sousa': 1,
#   'Tobias Kamke': 1,
#   'Albert Ramos': 1,
#   'Jo-Wilfried Tsonga': 0,
#   'Gael Monfils': 1,
#   'Kei Nishikori': 0,
#   'Riccardo Ghedin': 1,
#   'Julian Reister': 1,
#   'Sergiy Stakhovsky': 1,
#   'Jerzy Janowicz': 1,
#   'Dominic Thiem': 1,
#   'Thiemo De Bakker': 1,
#   'Benoit Paire': 1,
#   'Evgeny Donskoy': 1,
#   'Federico Delbonis': 1,
#   'Alexander Zverev': 1,
#   'Pablo Carreno Busta': 1,
#   'Jiri Vesely': 0,
#   'Daniel Evans': 0,
#   'Jack Sock': 0,
#   'Lleyton Hewitt': 0,
#   'Janis Podzus': 1,
#   'Mikelis Libietis': 1,
#   'Pablo Cuevas': 0,
#   'Edouard Roger Vasselin': 1,
#   'Norbert Gombos': 1,
#   'Victor Estrella': 1,
#   'Elias Ymer': 0,
#   'Dennis Novikov': 1,
#   'Ryan Harrison': 1,
#   'Diego Schwartzman': 0,
#   'Damir Dzumhur': 1,
#   'Adrian Mannarino': 1,
#   'Andrey Kuznetsov': 0,
#   'Kenny De Schepper': 1,
#   'Taro Daniel': 1,
#   'Gerald Melzer': 0,
#   'Ilya Ivashka': 0},
#  'Tomas Berdych': {'Nick Lindahl': 1,
#   'Marcos Baghdatis': 3,
#   'Thomaz Bellucci': 4,
#   'Andy Roddick': 3,
#   'Peter Luczak': 0,
#   'Robin Haase': 3,
#   'Evgeny Korolev': 0,
#   'Wayne Odesnik': 1,
#   'Jarkko Nieminen': 4,
#   'Ryan Sweeting': 1,
#   'Michael Russell': 2,
#   'Ernests Gulbis': 3,
#   'Olivier Rochus': 3,
#   'Florent Serra': 3,
#   'Fernando Verdasco': 7,
#   'Viktor Troicki': 7,
#   'Rafael Nadal': 1,
#   'Thiemo De Bakker': 3,
#   'Horacio Zeballos': 1,
#   'Roger Federer': 5,
#   'Robin Soderling': 1,
#   'Feliciano Lopez': 4,
#   'Richard Gasquet': 9,
#   'Marcel Granollers': 4,
#   'Stan Wawrinka': 1,
#   'Kevin Krawietz': 1,
#   'Pere Riba': 1,
#   'Philipp Petzschner': 1,
#   'John Isner': 7,
#   'Nicolas Almagro': 7,
#   'Carsten Ball': 1,
#   'Jorge Aguilar': 1,
#   'Edouard Roger Vasselin': 3,
#   'Andy Murray': 5,
#   'Mikhail Youzhny': 2,
#   'Andrey Golubev': 2,
#   'Benjamin Becker': 3,
#   'Denis Istomin': 6,
#   'Daniel Brands': 2,
#   'Novak Djokovic': 3,
#   'Dmitry Tursunov': 6,
#   'Xavier Malisse': 0,
#   'Sergiy Stakhovsky': 7,
#   'Alexandr Dolgopolov': 4,
#   'Paul Henri Mathieu': 1,
#   'Michael Llodra': 1,
#   'Janko Tipsarevic': 3,
#   'David Ferrer': 6,
#   'Michael Berrer': 0,
#   'Tommy Robredo': 4,
#   'Guillermo Garcia Lopez': 4,
#   'Tobias Kamke': 2,
#   'Nikolay Davydenko': 3,
#   'Frederico Gil': 1,
#   'Ivan Dodig': 2,
#   'Blaz Kavcic': 3,
#   'Marco Crugnola': 1,
#   'Philipp Kohlschreiber': 5,
#   'Jo-Wilfried Tsonga': 8,
#   'Marin Cilic': 4,
#   'Jeremy Chardy': 4,
#   'Mikhail Kukushkin': 2,
#   'Lukasz Kubot': 2,
#   'Ruben Ramirez Hidalgo': 1,
#   'Carlos Berlocq': 4,
#   'Florian Mayer': 2,
#   'Ivan Ljubicic': 0,
#   'Juan Monaco': 5,
#   'Adrian Mannarino': 5,
#   'Stephane Robert': 1,
#   'Ruben Bemelmans': 1,
#   'Jan Hernych': 1,
#   'Filippo Volandri': 1,
#   'Julien Benneteau': 3,
#   'Alex Bogomolov Jr': 2,
#   'Mardy Fish': 0,
#   'Teymuraz Gabashvili': 2,
#   'Ivo Karlovic': 2,
#   'Romain Jouan': 1,
#   'Fabio Fognini': 3,
#   'Victor Crivoi': 1,
#   'Jurgen Melzer': 4,
#   'Radek Stepanek': 2,
#   'Kei Nishikori': 1,
#   'Albert Ramos': 2,
#   'Kevin Anderson': 12,
#   'Nicolas Mahut': 4,
#   'Gael Monfils': 5,
#   'Simone Bolelli': 2,
#   'Lukas Rosol': 3,
#   'Andreas Seppi': 7,
#   'Juan Martin del Potro': 3,
#   'Lukas Lacko': 1,
#   'Grigor Dimitrov': 3,
#   'Go Soeda': 1,
#   'Dudi Sela': 1,
#   'Tommy Haas': 1,
#   'Steve Darcis': 2,
#   'Yen Hsun Lu': 3,
#   'Milos Raonic': 3,
#   'Sam Querrey': 4,
#   'David Goffin': 2,
#   'Jurgen Zopp': 2,
#   'Benoit Paire': 4,
#   'Alejandro Falla': 3,
#   'Gilles Simon': 6,
#   'Somdev Devvarman': 2,
#   'Roberto Bautista Agut': 4,
#   'Guillaume Rufin': 1,
#   'Henri Laaksonen': 1,
#   'Jerzy Janowicz': 3,
#   'Rajeev Ram': 2,
#   'Mischa Zverev': 3,
#   'Daniel Gimeno Traver': 1,
#   'Grega Zemlja': 1,
#   'Martin Klizan': 4,
#   'Bernard Tomic': 5,
#   'Martin Alund': 1,
#   'Vasek Pospisil': 1,
#   'Paolo Lorenzi': 2,
#   'Denis Kudla': 1,
#   'Leonardo Mayer': 2,
#   'Pablo Andujar': 3,
#   'Dusan Lajovic': 1,
#   'Aleksandr Nedovyesov': 2,
#   'Kenny De Schepper': 1,
#   'Damir Dzumhur': 3,
#   'Igor Sijsling': 1,
#   'Marius Copil': 3,
#   'Joao Sousa': 3,
#   'Victor Hanescu': 2,
#   'Peter Polansky': 1,
#   'James Duckworth': 1,
#   'Robby Ginepri': 1,
#   'Lleyton Hewitt': 1,
#   'Dominic Thiem': 2,
#   'Dustin Brown': 1,
#   'Matthias Bachinger': 2,
#   'Steve Johnson': 2,
#   'Hyeon Chung': 2,
#   'Matteo Donati': 1,
#   'Yoshihito Nishioka': 2,
#   'Victor Estrella': 1,
#   'Borna Coric': 3,
#   'Donald Young': 0,
#   'Bjorn Fratangelo': 2,
#   'Austin Krajicek': 1,
#   'Jiri Vesely': 4,
#   'Pablo Cuevas': 1,
#   'Jack Sock': 2,
#   'Alexander Zverev': 4,
#   'Kyle Edmund': 2,
#   'Yuki Bhambri': 1,
#   'Mirza Basic': 1,
#   'Nick Kyrgios': 1,
#   'Thomas Fabbiano': 1,
#   'Malek Jaziri': 1,
#   'Lucas Pouille': 1,
#   'Ryan Harrison': 4,
#   'Andrey Kuznetsov': 2,
#   'Gilles Muller': 1,
#   'Nikoloz Basilashvili': 0,
#   'Alessandro Giannessi': 1,
#   'Luca Vanni': 1,
#   'Andrey Rublev': 1,
#   'Jan Lennard Struff': 1,
#   'Karen Khachanov': 0,
#   'Denis Shapovalov': 1,
#   'Akira Santillan': 1,
#   'Thanasi Kokkinakis': 0,
#   'Jared Donaldson': 1,
#   'Alex De Minaur': 1,
#   'Stefano Travaglia': 1,
#   'Maximilian Marterer': 1,
#   'Frances Tiafoe': 0,
#   'Marco Cecchinato': 1,
#   'Pierre Hugues Herbert': 1,
#   'Diego Schwartzman': 1,
#   'Filip Krajinovic': 1,
#   'Ilya Ivashka': 1,
#   'Taylor Fritz': 0,
#   'Jenson Brooksby': 0},
#  'Nick Lindahl': {'Tomas Berdych': 0,
#   'Marcos Baghdatis': 0,
#   'Jarkko Nieminen': 0,
#   'Florian Mayer': 0,
#   'Xavier Malisse': 0,
#   'Robby Ginepri': 0},
#  'Marcos Baghdatis': {'Mardy Fish': 2,
#   'Tomas Berdych': 2,
#   'Nick Lindahl': 1,
#   'Viktor Troicki': 5,
#   'Lleyton Hewitt': 1,
#   'Richard Gasquet': 3,
#   'Paolo Lorenzi': 1,
#   'David Ferrer': 2,
#   'James Blake': 2,
#   'Nikolay Davydenko': 0,
#   'Daniel Brands': 1,
#   'Michael Llodra': 0,
#   'Gilles Simon': 2,
#   'Somdev Devvarman': 3,
#   'Michael Berrer': 1,
#   'Novak Djokovic': 0,
#   'Sherif Sabry': 1,
#   'Mohamed Safwat': 2,
#   'Arnaud Clement': 2,
#   'Roger Federer': 1,
#   'Tommy Robredo': 0,
#   'Juan Ignacio Chela': 3,
#   'Marin Cilic': 1,
#   'Albert Montanes': 1,
#   'Ernests Gulbis': 1,
#   'Peter Gojowczyk': 2,
#   'Marco Chiudinelli': 2,
#   'Philipp Kohlschreiber': 2,
#   'Laurent Recouderc': 1,
#   'Simon Greul': 1,
#   'Leonardo Mayer': 1,
#   'Jesse Witten': 1,
#   'Marcel Granollers': 2,
#   'Andy Murray': 1,
#   'Philipp Petzschner': 0,
#   'Peter Luczak': 0,
#   'Lukas Lacko': 2,
#   'Ryan Sweeting': 3,
#   'Janko Tipsarevic': 0,
#   'Horacio Zeballos': 2,
#   'Illya Marchenko': 1,
#   'Fernando Verdasco': 3,
#   'Xavier Malisse': 1,
#   'David Nalbandian': 0,
#   'Jeremy Chardy': 1,
#   'Thomaz Bellucci': 2,
#   'Rafael Nadal': 1,
#   'Igor Andreev': 1,
#   'Sergiy Stakhovsky': 1,
#   'Kei Nishikori': 3,
#   'Santiago Giraldo': 2,
#   'Mikhail Youzhny': 3,
#   'Alexandr Dolgopolov': 1,
#   'Potito Starace': 1,
#   'Denis Istomin': 1,
#   'Bjorn Phau': 1,
#   'Florent Serra': 1,
#   'Lukasz Kubot': 2,
#   'Andy Roddick': 0,
#   'Grega Zemlja': 1,
#   'Juan Martin del Potro': 2,
#   'Jurgen Melzer': 1,
#   'Feliciano Lopez': 3,
#   'Ivan Ljubicic': 0,
#   'Andrey Golubev': 0,
#   'Olivier Rochus': 0,
#   'Andrey Kuznetsov': 0,
#   'Radek Stepanek': 0,
#   'Julien Benneteau': 1,
#   'Grigor Dimitrov': 1,
#   'Alejandro Falla': 3,
#   'Jo-Wilfried Tsonga': 0,
#   'Frederico Gil': 2,
#   'Robin Haase': 1,
#   'Denis Gremelmayr': 1,
#   'Ivan Dodig': 1,
#   'Andreas Seppi': 1,
#   'Yen Hsun Lu': 1,
#   'Donald Young': 2,
#   'John Isner': 0,
#   'Steve Darcis': 2,
#   'Matthias Bachinger': 3,
#   'Alex Bogomolov Jr': 1,
#   'Milos Raonic': 1,
#   'Kevin Anderson': 1,
#   'Michael Lammer': 1,
#   'Ryan Harrison': 3,
#   'Dmitry Tursunov': 2,
#   'Matthew Ebden': 1,
#   'Benjamin Becker': 3,
#   'Stan Wawrinka': 0,
#   'Lukas Rosol': 2,
#   'Younes Rachidi': 1,
#   'Yassine Idmbarek': 1,
#   'Fabio Fognini': 1,
#   'Tobias Kamke': 2,
#   'Dustin Brown': 4,
#   'Tommy Haas': 0,
#   'Guillermo Garcia Lopez': 0,
#   'Nicolas Almagro': 1,
#   'Pablo Andujar': 1,
#   'Go Soeda': 2,
#   'Carlos Berlocq': 3,
#   'Juan Monaco': 1,
#   'David Goffin': 4,
#   'Ricardas Berankis': 2,
#   'Benjamin Mitchell': 1,
#   'Florian Mayer': 1,
#   'Albert Ramos': 1,
#   'Tatsuma Ito': 1,
#   'Blaz Kavcic': 0,
#   'Benoit Paire': 3,
#   'Jean Segodo': 1,
#   'Evgeny Korolev': 0,
#   'Evgeny Donskoy': 1,
#   'Steve Johnson': 0,
#   'Rajeev Ram': 1,
#   'Jiri Vesely': 4,
#   'Rhyne Williams': 0,
#   'Miguel Angel Reyes Varela': 1,
#   'Alejandro Gonzalez': 0,
#   'Bradley Klahn': 1,
#   'Adrian Mannarino': 2,
#   'Teymuraz Gabashvili': 1,
#   'Toni Androic': 1,
#   'Ivo Karlovic': 2,
#   'Borna Coric': 0,
#   'Simone Bolelli': 1,
#   'Damir Dzumhur': 0,
#   'Victor Estrella': 1,
#   'Alexander Zverev': 1,
#   'John Millman': 2,
#   'Alejandro Gomez Gb42': 0,
#   'Austin Krajicek': 1,
#   'Sam Groth': 1,
#   'Vasek Pospisil': 4,
#   'Gilles Muller': 3,
#   'Pierre Hugues Herbert': 0,
#   'Sam Querrey': 2,
#   'Bernard Tomic': 1,
#   'Taro Daniel': 1,
#   'Martin Klizan': 0,
#   'Roberto Bautista Agut': 1,
#   'Nick Kyrgios': 0,
#   'Diego Schwartzman': 2,
#   'Jack Sock': 0,
#   'Marco Cecchinato': 0,
#   'Jan Lennard Struff': 0,
#   'Pablo Cuevas': 0,
#   'Brian Baker': 1,
#   'Dudi Sela': 2,
#   'Gael Monfils': 0,
#   'Facundo Bagnis': 1,
#   'Pablo Carreno Busta': 1,
#   'Paul Henri Mathieu': 1,
#   'Joao Sousa': 0,
#   'Nikoloz Basilashvili': 1,
#   'Ramkumar Ramanathan': 1,
#   'Yuichi Sugita': 0,
#   'James Ward': 1,
#   'Kyle Edmund': 0,
#   'Edan Leshem': 1,
#   'Taylor Fritz': 0,
#   'Guido Pella': 1,
#   'Norbert Gombos': 1,
#   'Yuki Bhambri': 1,
#   'Andrey Rublev': 0,
#   'Salvatore Caruso': 1,
#   'Jozef Kovalik': 0,
#   'Filip Krajinovic': 0,
#   'Yoshihito Nishioka': 1,
#   'Jared Donaldson': 0,
#   'Yannick Hanfmann': 0,
#   'Noah Rubin': 0,
#   'Dominic Thiem': 1,
#   'Karen Khachanov': 0,
#   'Alex Bolt': 1,
#   'Frances Tiafoe': 1,
#   'Hyeon Chung': 0,
#   'Lucas Pouille': 1,
#   'Malek Jaziri': 0,
#   'Radu Albot': 0,
#   'Ruben Bemelmans': 1,
#   'Brayden Schnur': 1,
#   'Matteo Berrettini': 0},
#  'Mardy Fish': {'Marcos Baghdatis': 0,
#   'Carsten Ball': 1,
#   'Evgeny Korolev': 1,
#   'Peter Luczak': 1,
#   'Andrey Golubev': 1,
#   'Leonardo Mayer': 1,
#   'Christophe Rochus': 1,
#   'Mischa Zverev': 1,
#   'Jeremy Chardy': 1,
#   'Ivo Karlovic': 0,
#   'Michael Berrer': 2,
#   'Novak Djokovic': 0,
#   'Andy Murray': 3,
#   'Feliciano Lopez': 4,
#   'Mikhail Youzhny': 0,
#   'Michael Russell': 2,
#   'Jurgen Melzer': 0,
#   'Ivan Ljubicic': 1,
#   'Somdev Devvarman': 3,
#   'Santiago Giraldo': 3,
#   'Michael Llodra': 1,
#   'Sam Querrey': 1,
#   'Bernard Tomic': 2,
#   'Florian Mayer': 1,
#   'Frank Dancevic': 2,
#   'Richard Bloomfield': 1,
#   'Olivier Rochus': 1,
#   'James Ward': 2,
#   'Robby Ginepri': 1,
#   'Taylor Dent': 1,
#   'Andy Roddick': 2,
#   'John Isner': 2,
#   'Viktor Troicki': 2,
#   'Marin Cilic': 0,
#   'Gilles Simon': 2,
#   'Fernando Verdasco': 1,
#   'Richard Gasquet': 3,
#   'Roger Federer': 0,
#   'Jan Hajek': 1,
#   'Pablo Cuevas': 1,
#   'Arnaud Clement': 1,
#   'Alejandro Falla': 2,
#   'Janko Tipsarevic': 2,
#   'Adrian Mannarino': 1,
#   'Radek Stepanek': 1,
#   'Victor Hanescu': 1,
#   'Tommy Robredo': 0,
#   'Teymuraz Gabashvili': 1,
#   'Lukas Lacko': 1,
#   'Milos Raonic': 0,
#   'Bjorn Phau': 2,
#   'Ricardo Mello': 2,
#   'Juan Martin del Potro': 1,
#   'Julien Benneteau': 2,
#   'David Ferrer': 1,
#   'Albert Ramos': 1,
#   'Kei Nishikori': 0,
#   'Juan Monaco': 1,
#   'Robin Haase': 2,
#   'Marcel Granollers': 1,
#   'Denis Istomin': 1,
#   'Tomas Berdych': 1,
#   'Rafael Nadal': 1,
#   'Nicolas Mahut': 1,
#   'Ryan Harrison': 3,
#   'Gilles Muller': 2,
#   'Igor Kunitsyn': 1,
#   'Ernests Gulbis': 2,
#   'Stan Wawrinka': 2,
#   'Nikolay Davydenko': 2,
#   'Tobias Kamke': 1,
#   'Malek Jaziri': 1,
#   'Kevin Anderson': 2,
#   'Jo-Wilfried Tsonga': 0,
#   'James Blake': 0,
#   'Albano Olivetti': 0,
#   'Andreas Beck': 1,
#   'Andreas Seppi': 1,
#   'Matthew Ebden': 2,
#   'Nicolas Almagro': 1,
#   'Ruben Ramirez Hidalgo': 1,
#   'David Goffin': 1,
#   'Ricardas Berankis': 1,
#   'Xavier Malisse': 1,
#   'Tommy Haas': 0,
#   'Carlos Berlocq': 1,
#   'Go Soeda': 1,
#   'Bobby Reynolds': 1,
#   'Philipp Kohlschreiber': 0,
#   'Evgeny Donskoy': 1,
#   'Jarkko Nieminen': 0,
#   'Dudi Sela': 0,
#   'Marco Cecchinato': 1},
#  'Harel Levy': {'Michael Llodra': 1,
#   'Thomaz Bellucci': 0,
#   'Josselin Ouanna': 0,
#   'Fernando Gonzalez': 0,
#   'Jorge Aguilar': 0,
#   'Jurgen Melzer': 0,
#   'Martin Fischer': 0},
#  'Michael Llodra': {'Harel Levy': 0,
#   'Pablo Cuevas': 0,
#   'Martin Vassallo Arguello': 1,
#   'Juan Monaco': 1,
#   'Marco Chiudinelli': 1,
#   'Edouard Roger Vasselin': 1,
#   'Marcos Baghdatis': 1,
#   'Robin Soderling': 1,
#   'Mischa Zverev': 1,
#   'Julien Benneteau': 3,
#   'Jo-Wilfried Tsonga': 1,
#   'Marinko Matosevic': 0,
#   'Ryan Harrison': 1,
#   'David Ferrer': 0,
#   'Fabio Fognini': 1,
#   'Ivan Ljubicic': 0,
#   'Andreas Beck': 1,
#   'Santiago Giraldo': 2,
#   'Thomaz Bellucci': 0,
#   'Andrey Golubev': 1,
#   'Jesse Levine': 1,
#   'Marin Cilic': 1,
#   'Mardy Fish': 0,
#   'Martin Emmrich': 1,
#   'Stephane Robert': 1,
#   'Gilles Simon': 1,
#   'Alexandr Dolgopolov': 2,
#   'Guillermo Garcia Lopez': 2,
#   'Jesse Witten': 1,
#   'Andy Roddick': 0,
#   'Fernando Verdasco': 1,
#   'Ryan Sweeting': 0,
#   'Nicolas Almagro': 1,
#   'Roger Federer': 0,
#   'Tomas Berdych': 1,
#   'Victor Hanescu': 2,
#   'Tommy Robredo': 0,
#   'Olivier Rochus': 1,
#   'Albert Montanes': 0,
#   'John Isner': 2,
#   'Potito Starace': 1,
#   'Novak Djokovic': 1,
#   'Nikolay Davydenko': 2,
#   'Viktor Troicki': 0,
#   'Juan Ignacio Chela': 1,
#   'Milos Raonic': 0,
#   'Tobias Kamke': 1,
#   'Xavier Malisse': 1,
#   'Marcel Granollers': 0,
#   'Sam Querrey': 2,
#   'Flavio Cipolla': 1,
#   'Daniel Gimeno Traver': 3,
#   'Rafael Nadal': 0,
#   'Feliciano Lopez': 0,
#   'Steve Darcis': 1,
#   'Jaroslav Pospisil': 1,
#   'James Ward': 1,
#   'Ricardo Mello': 1,
#   'Yen Hsun Lu': 1,
#   'Philipp Petzschner': 0,
#   'Grigor Dimitrov': 0,
#   'Mikhail Youzhny': 2,
#   'Ernests Gulbis': 2,
#   'Kevin Anderson': 0,
#   'Arnaud Clement': 0,
#   'Alex Bogomolov Jr': 1,
#   'Andy Murray': 0,
#   'Juan Martin del Potro': 1,
#   'Albano Olivetti': 1,
#   'Janko Tipsarevic': 2,
#   'Lukas Rosol': 0,
#   'Andreas Seppi': 1,
#   'Denis Istomin': 0,
#   'Philipp Kohlschreiber': 0,
#   'Noam Okun': 1,
#   'Kenny De Schepper': 1,
#   'Jan Hajek': 1,
#   'Benoit Paire': 2,
#   'David Goffin': 1,
#   'Dmitry Tursunov': 0,
#   'Daniel Munoz de la Nava': 1,
#   'Pablo Andujar': 1,
#   'Jan Hernych': 0,
#   'Jarkko Nieminen': 1,
#   'Radek Stepanek': 0,
#   'Richard Gasquet': 1,
#   'Paul Henri Mathieu': 0,
#   'Michael Berrer': 0,
#   'Marc Gicquel': 0,
#   'Lukas Lacko': 1,
#   'Jan Lennard Struff': 0,
#   'Jerzy Janowicz': 1},
#  'Thomaz Bellucci': {'Juan Ignacio Chela': 1,
#   'Harel Levy': 1,
#   'Tomas Berdych': 1,
#   'Marco Chiudinelli': 1,
#   'Philipp Kohlschreiber': 2,
#   'Teymuraz Gabashvili': 3,
#   'Andy Roddick': 0,
#   'Nicolas Lapentti': 1,
#   'Paul Capdeville': 1,
#   'Eduardo Schwank': 1,
#   'Fernando Gonzalez': 1,
#   'Juan Monaco': 2,
#   'Thiago Alves': 1,
#   'Daniel Gimeno Traver': 1,
#   'Ricardo Mello': 3,
#   'Oscar Hernandez': 1,
#   'David Ferrer': 1,
#   'Carlos Moya': 1,
#   'Guillermo Garcia Lopez': 1,
#   'James Blake': 1,
#   'Olivier Rochus': 1,
#   'Nicolas Almagro': 0,
#   'Jarkko Nieminen': 1,
#   'Victor Hanescu': 1,
#   'Leonardo Mayer': 2,
#   'John Isner': 2,
#   'Novak Djokovic': 0,
#   'Martin Cuevas': 2,
#   'Marcel Felder': 1,
#   'Pere Riba': 1,
#   'Michael Llodra': 1,
#   'Pablo Andujar': 4,
#   'Ivan Ljubicic': 1,
#   'Rafael Nadal': 0,
#   'Martin Fischer': 1,
#   'Robin Soderling': 0,
#   'Simone Bolelli': 1,
#   'Andreas Seppi': 1,
#   'Ernests Gulbis': 0,
#   'Benjamin Becker': 3,
#   'Marcos Baghdatis': 2,
#   'Lukas Lacko': 0,
#   'Tim Smyczek': 1,
#   'Kevin Anderson': 1,
#   'Rohan Bopanna': 1,
#   'Somdev Devvarman': 0,
#   'Marin Cilic': 0,
#   'Marsel Ilhan': 2,
#   'Nikolay Davydenko': 1,
#   'Michael Russell': 1,
#   'Tommy Robredo': 1,
#   'Santiago Giraldo': 4,
#   'Jan Hernych': 0,
#   'Filippo Volandri': 1,
#   'Rui Machado': 2,
#   'Fabio Fognini': 0,
#   'Carlos Berlocq': 1,
#   'Fernando Verdasco': 1,
#   'Ivan Navarro': 1,
#   'Lukasz Kubot': 1,
#   'Gilles Simon': 0,
#   'Frederik Nielsen': 1,
#   'Edouard Roger Vasselin': 1,
#   'Pablo Cuevas': 3,
#   'Florian Mayer': 1,
#   'Andy Murray': 1,
#   'Paolo Lorenzi': 1,
#   'Andrey Golubev': 2,
#   'Richard Gasquet': 0,
#   'Grigor Dimitrov': 2,
#   'Rainer Schuettler': 0,
#   'Alejandro Falla': 2,
#   'Alex Bogomolov Jr': 1,
#   'Tommy Haas': 1,
#   'Dudi Sela': 1,
#   'Igor Andreev': 1,
#   'Mikhail Youzhny': 4,
#   'Juan Carlos Ferrero': 1,
#   'Dmitry Tursunov': 1,
#   'Gael Monfils': 1,
#   'Federico Delbonis': 2,
#   'Marcel Granollers': 0,
#   'Lukas Rosol': 2,
#   'Jurgen Melzer': 1,
#   'Roger Federer': 0,
#   'Frederico Gil': 0,
#   'Robin Haase': 0,
#   'Donald Young': 1,
#   'Viktor Troicki': 0,
#   'Robin Kern': 1,
#   'Bernard Tomic': 2,
#   'Cedrik Marcel Stebe': 1,
#   'Janko Tipsarevic': 2,
#   'Blaz Kavcic': 1,
#   'Feliciano Lopez': 2,
#   'Jo-Wilfried Tsonga': 0,
#   'Martin Klizan': 1,
#   'Flavio Cipolla': 1,
#   'Jerzy Janowicz': 2,
#   'Ivo Karlovic': 1,
#   'Go Soeda': 1,
#   'David Goffin': 2,
#   'Sam Querrey': 1,
#   'Guilherme Clezar': 1,
#   'Diego Schwartzman': 1,
#   'Andrey Kuznetsov': 1,
#   'Daniel Brands': 1,
#   'Pablo Carreno Busta': 2,
#   'Roberto Bautista Agut': 3,
#   'Julian Reister': 1,
#   'Taro Daniel': 0,
#   'Andreas Haider Maurer': 1,
#   'Denis Istomin': 2,
#   'Ivan Dodig': 1,
#   'Gerald Melzer': 1,
#   'Frank Dancevic': 0,
#   'Nicolas Mahut': 2,
#   'Stan Wawrinka': 0,
#   'Paul Henri Mathieu': 1,
#   'Jiri Vesely': 2,
#   'Giovanni Lapentti': 1,
#   'Horacio Zeballos': 1,
#   'Albert Montanes': 2,
#   'Victor Estrella': 0,
#   'Lleyton Hewitt': 1,
#   'Alexandr Dolgopolov': 1,
#   'Yuichi Sugita': 1,
#   'Jeremy Chardy': 1,
#   'Albert Ramos': 1,
#   'Joao Sousa': 1,
#   'Marinko Matosevic': 1,
#   'Kei Nishikori': 1,
#   'Alexander Zverev': 0,
#   'Elias Ymer': 1,
#   'Christian Lindell': 1,
#   'Kimmer Coppejans': 1,
#   'Stephane Robert': 2,
#   'Sam Groth': 0,
#   'Frances Tiafoe': 2,
#   'Malek Jaziri': 0,
#   'James Ward': 1,
#   'Yoshihito Nishioka': 1,
#   'Mate Delic': 1,
#   'Borna Coric': 0,
#   'Milos Raonic': 0,
#   'Mischa Zverev': 0,
#   'Jordan Thompson': 1,
#   'Steve Johnson': 0,
#   'Roberto Carballes Baena': 0,
#   'Mikhail Kukushkin': 2,
#   'John Millman': 0,
#   'Ruben Bemelmans': 1,
#   'Roberto Quiroz': 1,
#   'Emilio Gomez': 2,
#   'Dustin Brown': 1,
#   'Steve Darcis': 0,
#   'Joris De Loore': 0,
#   'Gastao Elias': 1,
#   'Thomas Fabbiano': 1,
#   'Cem Ilkel': 1,
#   'Renzo Olivo': 1,
#   'Thiago Monteiro': 0,
#   'Pierre Hugues Herbert': 0,
#   'Ivan Endara': 1,
#   'Maximo Gonzalez': 1,
#   'Ernesto Escobedo': 1,
#   'Karen Khachanov': 0,
#   'Yannick Hanfmann': 0,
#   'Dusan Lajovic': 1,
#   'Lucas Pouille': 0,
#   'Sebastian Ofner': 0,
#   'Henri Laaksonen': 0,
#   'Jan Lennard Struff': 1,
#   'Pedro Cachin': 1,
#   'Sebastian Baez': 0},
#  'Juan Ignacio Chela': {'Thomaz Bellucci': 1,
#   'Benjamin Becker': 0,
#   'Victor Hanescu': 0,
#   'Jorge Aguilar': 2,
#   'Juan Monaco': 0,
#   'Peter Luczak': 2,
#   'Carlos Berlocq': 0,
#   'Richard Gasquet': 1,
#   'Paolo Lorenzi': 1,
#   'Marcos Baghdatis': 0,
#   'Rajeev Ram': 1,
#   'Eduardo Schwank': 2,
#   'Lleyton Hewitt': 1,
#   'Horacio Zeballos': 3,
#   'Sam Querrey': 1,
#   'Filip Krajinovic': 1,
#   'Robin Soderling': 0,
#   'Guillermo Garcia Lopez': 0,
#   'Alejandro Falla': 2,
#   'Pablo Cuevas': 1,
#   'Andy Murray': 0,
#   'Ryan Sweeting': 1,
#   'Taylor Dent': 0,
#   'Albert Montanes': 2,
#   'Sergiy Stakhovsky': 1,
#   'Philipp Kohlschreiber': 2,
#   'Ruben Ramirez Hidalgo': 1,
#   'Simone Bolelli': 1,
#   'Nikolay Davydenko': 1,
#   'Potito Starace': 0,
#   'Roger Federer': 0,
#   'Donald Young': 1,
#   'Yen Hsun Lu': 1,
#   'Stan Wawrinka': 1,
#   'Simon Greul': 1,
#   'Bjorn Phau': 1,
#   'Pablo Andujar': 2,
#   'Andrej Martin': 1,
#   'Grega Zemlja': 1,
#   'Nicolas Almagro': 0,
#   'Ernests Gulbis': 0,
#   'Radek Stepanek': 1,
#   'Viktor Troicki': 0,
#   'Michael Llodra': 0,
#   'Caio Zampieri': 1,
#   'Santiago Giraldo': 0,
#   'Rogerio Dutra Silva': 1,
#   'Lukasz Kubot': 1,
#   'Rui Machado': 1,
#   'Philipp Petzschner': 1,
#   'Feliciano Lopez': 0,
#   'Olivier Rochus': 0,
#   'Adrian Mannarino': 0,
#   'John Isner': 2,
#   'Gilles Simon': 1,
#   'Florian Mayer': 1,
#   'Mikhail Kukushkin': 1,
#   'Christian Lindell': 1,
#   'Tim Smyczek': 1,
#   'Kevin Anderson': 1,
#   'Lukas Rosol': 1,
#   'Marinko Matosevic': 2,
#   'Alex Bogomolov Jr': 0,
#   'Evgeny Korolev': 1,
#   'Tobias Kamke': 0,
#   'Daniel Gimeno Traver': 1,
#   'Marcel Granollers': 1,
#   'Vasek Pospisil': 0,
#   'Ryan Harrison': 0,
#   'Steve Darcis': 1,
#   'Florent Serra': 1,
#   'Andreas Seppi': 1,
#   'Grigor Dimitrov': 0,
#   'Tommy Haas': 0,
#   'Benoit Paire': 0,
#   'Michael Russell': 1,
#   'David Ferrer': 0,
#   'Joao Souza': 1,
#   'Albert Ramos': 0,
#   'Cesar Ramirez': 1,
#   'Fernando Verdasco': 0,
#   'Denis Istomin': 0,
#   'Alexandr Dolgopolov': 0,
#   'Martin Klizan': 0},
#  'James Blake': {'Sam Querrey': 1,
#   'Marc Gicquel': 1,
#   'Gael Monfils': 0,
#   'Arnaud Clement': 1,
#   'Juan Martin del Potro': 1,
#   'Marcos Baghdatis': 1,
#   'Andy Roddick': 0,
#   'Taylor Dent': 1,
#   'Robin Haase': 2,
#   'Ivo Karlovic': 0,
#   'Daniel Gimeno Traver': 1,
#   'David Ferrer': 1,
#   'Nicolas Almagro': 0,
#   'Filip Krajinovic': 1,
#   'Thomaz Bellucci': 2,
#   'Julien Benneteau': 1,
#   'Leonardo Mayer': 1,
#   'Benjamin Becker': 2,
#   'Feliciano Lopez': 0,
#   'Ryan Sweeting': 0,
#   'Denis Istomin': 0,
#   'Pere Riba': 1,
#   'Alexandr Dolgopolov': 0,
#   'Kristof Vliegen': 1,
#   'Peter Polansky': 1,
#   'Novak Djokovic': 0,
#   'Matthias Bachinger': 1,
#   'Jarkko Nieminen': 0,
#   'Lukasz Kubot': 0,
#   'Jesse Levine': 1,
#   'Milos Raonic': 0,
#   'Ricardo Mello': 1,
#   'Robert Kendrick': 0,
#   'Kei Nishikori': 0,
#   'Chris Guccione': 1,
#   'Michael Russell': 1,
#   'Carlos Berlocq': 1,
#   'Pablo Cuevas': 0,
#   'Ernests Gulbis': 1,
#   'John Isner': 0,
#   'Michael Berrer': 1,
#   'Tatsuma Ito': 1,
#   'David Nalbandian': 2,
#   'Fabio Fognini': 1,
#   'Roger Federer': 0,
#   'Mikhail Kukushkin': 1,
#   'Jesse Huta Galung': 1,
#   'Olivier Rochus': 1,
#   'Guillermo Garcia Lopez': 0,
#   'Mardy Fish': 1,
#   'Nikolay Davydenko': 0,
#   'Radek Stepanek': 0,
#   'Mikhail Youzhny': 0,
#   'Ryan Harrison': 2,
#   'Matthew Ebden': 0,
#   'Tobias Kamke': 0,
#   'Pablo Andujar': 1,
#   'Marco Chiudinelli': 1,
#   'Kevin Anderson': 1,
#   'Albert Ramos': 1,
#   'Lukas Lacko': 1,
#   'Marcel Granollers': 1,
#   'Albano Olivetti': 1,
#   'Florian Mayer': 1,
#   'Jack Sock': 0,
#   'Jo-Wilfried Tsonga': 0,
#   'Viktor Troicki': 0,
#   'Thiemo De Bakker': 1,
#   'Bernard Tomic': 0,
#   'Adrian Mannarino': 0,
#   'Tim Smyczek': 1,
#   'Evgeny Donskoy': 1,
#   'Marinko Matosevic': 0,
#   'Jerzy Janowicz': 1,
#   'Dmitry Tursunov': 0,
#   'Rhyne Williams': 1,
#   'Benoit Paire': 0},
#  'Sam Querrey': {'James Blake': 0,
#   'Evgeny Korolev': 1,
#   'Rainer Schuettler': 3,
#   'Teymuraz Gabashvili': 1,
#   'Taylor Dent': 1,
#   'Michael Russell': 4,
#   'Andy Roddick': 1,
#   'Rajeev Ram': 3,
#   'Leonardo Mayer': 1,
#   'Ernests Gulbis': 3,
#   'John Isner': 5,
#   'Fernando Gonzalez': 0,
#   'Novak Djokovic': 2,
#   'Viktor Troicki': 2,
#   'Jeremy Chardy': 2,
#   'Blaz Kavcic': 1,
#   'Nicolas Massu': 1,
#   'Wayne Odesnik': 1,
#   'Juan Ignacio Chela': 0,
#   'Julien Benneteau': 2,
#   'Igor Andreev': 2,
#   'Filip Krajinovic': 1,
#   'Daniel Munoz de la Nava': 1,
#   'Peter Luczak': 1,
#   'Daniel Gimeno Traver': 1,
#   'Jan Hajek': 2,
#   'Juan Monaco': 0,
#   'Robby Ginepri': 1,
#   'Marcel Granollers': 2,
#   'Xavier Malisse': 3,
#   'Mardy Fish': 1,
#   'Sergiy Stakhovsky': 4,
#   'Ivan Dodig': 2,
#   'Andy Murray': 2,
#   'Jesse Levine': 2,
#   'Dustin Brown': 2,
#   'Kevin Anderson': 6,
#   'Janko Tipsarevic': 3,
#   'Philipp Petzschner': 1,
#   'David Ferrer': 0,
#   'Bradley Klahn': 2,
#   'Nicolas Almagro': 1,
#   'Stan Wawrinka': 2,
#   'Santiago Giraldo': 3,
#   'Gilles Simon': 2,
#   'Michael Berrer': 1,
#   'Jo-Wilfried Tsonga': 4,
#   'Alexandr Dolgopolov': 4,
#   'Lukasz Kubot': 1,
#   'Lukas Lacko': 1,
#   'Denis Istomin': 3,
#   'Brian Dabul': 1,
#   'Ryan Sweeting': 0,
#   'Fernando Verdasco': 5,
#   'Tommy Robredo': 1,
#   'Mikhail Kukushkin': 2,
#   'Michael Llodra': 0,
#   'Robin Soderling': 0,
#   'Philipp Kohlschreiber': 1,
#   'Ivan Ljubicic': 0,
#   'Kei Nishikori': 4,
#   'James Ward': 0,
#   'Juan Martin del Potro': 1,
#   'Victor Hanescu': 0,
#   'Ryan Harrison': 0,
#   'Kenny De Schepper': 1,
#   'Bernard Tomic': 0,
#   'Alejandro Falla': 4,
#   'Radek Stepanek': 0,
#   'Tim Smyczek': 2,
#   'Matthew Ebden': 2,
#   'Eric Prodon': 1,
#   'Jarkko Nieminen': 2,
#   'Olivier Rochus': 2,
#   'Marin Cilic': 1,
#   'Vasek Pospisil': 1,
#   'Milos Raonic': 3,
#   'Alex Bogomolov Jr': 2,
#   'Dudi Sela': 3,
#   'Igor Sijsling': 2,
#   'Ricardas Berankis': 3,
#   'Benjamin Becker': 4,
#   'Jurgen Melzer': 2,
#   'Feliciano Lopez': 5,
#   'Tomas Berdych': 0,
#   'Yen Hsun Lu': 1,
#   'Ruben Ramirez Hidalgo': 1,
#   'Andreas Seppi': 1,
#   'Zhe Li': 1,
#   'Brian Baker': 1,
#   'Thomaz Bellucci': 2,
#   'Thiago Alves': 1,
#   'Lleyton Hewitt': 2,
#   'Marinko Matosevic': 2,
#   'Ivo Karlovic': 3,
#   'Jerzy Janowicz': 1,
#   'Richard Gasquet': 0,
#   'Edouard Roger Vasselin': 0,
#   'Aljaz Bedene': 2,
#   'Grigor Dimitrov': 1,
#   'Guillermo Garcia Lopez': 6,
#   'Guido Pella': 2,
#   'Adrian Mannarino': 4,
#   'Paul Henri Mathieu': 1,
#   'Mikhail Youzhny': 2,
#   'Tommy Haas': 0,
#   'Dmitry Tursunov': 1,
#   'Albert Ramos': 0,
#   'Fabio Fognini': 0,
#   'Tigre Hank': 1,
#   'Alex Kuznetsov': 1,
#   'Albert Montanes': 0,
#   'Filippo Volandri': 1,
#   'Denis Kudla': 1,
#   'Kyle Edmund': 2,
#   'Victor Estrella': 2,
#   'Steve Johnson': 3,
#   'Pere Riba': 1,
#   'Maximo Gonzalez': 1,
#   'Martin Klizan': 2,
#   'Norbert Gombos': 1,
#   'Jared Donaldson': 2,
#   'Alejandro Gonzalez': 0,
#   'Jack Sock': 0,
#   'Thanasi Kokkinakis': 2,
#   'Roberto Bautista Agut': 2,
#   'Ruben Bemelmans': 2,
#   'Borna Coric': 1,
#   'Pablo Cuevas': 1,
#   'Roger Federer': 0,
#   'Go Soeda': 1,
#   'David Goffin': 1,
#   'Simone Bolelli': 0,
#   'Nicolas Mahut': 1,
#   'Marcos Baghdatis': 0,
#   'Dusan Lajovic': 1,
#   'Henri Laaksonen': 2,
#   'Yoshihito Nishioka': 1,
#   'Thiemo De Bakker': 2,
#   'Austin Krajicek': 1,
#   'Taylor Fritz': 2,
#   'Dominic Thiem': 2,
#   'Reilly Opelka': 1,
#   'Pierre Hugues Herbert': 2,
#   'Lucas Pouille': 2,
#   'Rafael Nadal': 1,
#   'Bjorn Fratangelo': 2,
#   'Tatsuma Ito': 1,
#   'Stefan Kozlov': 2,
#   'Ernesto Escobedo': 1,
#   'Lukas Rosol': 1,
#   'Gael Monfils': 0,
#   'Frank Dancevic': 1,
#   'Nick Kyrgios': 1,
#   'Diego Schwartzman': 3,
#   'Quentin Halys': 1,
#   'Alex De Minaur': 1,
#   'Adrien Bossel': 1,
#   'Donald Young': 0,
#   'Horacio Zeballos': 1,
#   'Jan Lennard Struff': 1,
#   'Daniel Altmaier': 1,
#   'Franko Skugor': 1,
#   'Hyeon Chung': 0,
#   'Cameron Norrie': 1,
#   'Jordan Thompson': 2,
#   'Gilles Muller': 0,
#   'Daniil Medvedev': 0,
#   'Thomas Fabbiano': 2,
#   'Nikoloz Basilashvili': 2,
#   'Evan King': 1,
#   'Vincent Millot': 2,
#   'Damir Dzumhur': 1,
#   'Radu Albot': 3,
#   'Mischa Zverev': 2,
#   'Yuichi Sugita': 1,
#   'Frances Tiafoe': 2,
#   'Alexander Zverev': 0,
#   'Jiri Vesely': 0,
#   'Marton Fucsovics': 0,
#   'Laslo Djere': 1,
#   'Yuki Bhambri': 1,
#   'Denis Shapovalov': 0,
#   'Peter Gojowczyk': 0,
# ...
#   'Adrian Mannarino': 1,
#   'Jaume Munar': 0,
#   'Vasek Pospisil': 1,
#   'Alexander Bublik': 1,
#   'Daniil Medvedev': 0,
#   'Thanasi Kokkinakis': 0,
#   'Soon Woo Kwon': 1,
#   'Benjamin Bonzi': 1,
#   'Corentin Moutet': 1,
#   'Lorenzo Musetti': 0,
#   'Roman Safiullin': 0,
#   'James Duckworth': 1,
#   'Daniel Evans': 1,
#   'Daniel Altmaier': 1,
#   'Federico Delbonis': 0,
#   'Nick Kyrgios': 0,
#   'Sebastian Korda': 1,
#   'Aslan Karatsev': 2,
#   'Andy Murray': 1,
#   'Marc Andrea Huesler': 0,
#   'Federico Coria': 1,
#   'Jason Kubler': 0,
#   'Stan Wawrinka': 0,
#   'Gregoire Barrere': 1,
#   'J J Wolf': 0,
#   'Tim Van Rijthoven': 1,
#   'Quentin Halys': 1,
#   'Diego Schwartzman': 1,
#   'Borna Coric': 0,
#   'Mackenzie Mcdonald': 1,
#   'Yoshihito Nishioka': 0,
#   'Tallon Griekspoor': 0,
#   'David Goffin': 1,
#   'Radu Albot': 1,
#   'Botic Van De Zandschulp': 1,
#   'Francesco Passaro': 1,
#   'Rinky Hijikata': 0,
#   'Alexei Popyrin': 0,
#   'Arthur Fils': 0,
#   'Brandon Nakashima': 0,
#   'Liam Broady': 1,
#   'Alex Molcan': 1,
#   'Taylor Fritz': 1,
#   'Mirza Basic': 1,
#   'Damir Dzumhur': 1},
#  'Lucas Miedler': {'Ernests Gulbis': 0,
#   'Damir Dzumhur': 0,
#   'Sebastian Ofner': 0},
#  'Rodrigo Arus': {'Darian King': 0,
#   'Juan Pablo Varillas': 0,
#   'Rafael Eduardo Gonzalez Retana': 1},
#  'Nicolas Xiviller': {'Russell Moseley': 1},
#  'Oliver Anderson': {'Ivan Dodig': 0},
#  'Jozef Kovalik': {'Thomas Fabbiano': 0,
#   'Marco Trungelliti': 0,
#   'Albert Montanes': 0,
#   'Pierre Hugues Herbert': 1,
#   'Dominic Thiem': 0,
#   'Igor Sijsling': 1,
#   'Fabio Fognini': 0,
#   'Marton Fucsovics': 1,
#   'Henri Laaksonen': 0,
#   'Vasek Pospisil': 0,
#   'Bernard Tomic': 0,
#   'Guillermo Garcia Lopez': 2,
#   'Pablo Cuevas': 0,
#   'Gastao Elias': 1,
#   'Marin Cilic': 1,
#   'Daniil Medvedev': 0,
#   'Carlos Berlocq': 0,
#   'Federico Delbonis': 0,
#   'Jeremy Chardy': 0,
#   'Stan Wawrinka': 0,
#   'Radu Albot': 1,
#   'Lukas Lacko': 1,
#   'Marcos Baghdatis': 1,
#   'Marius Copil': 0,
#   'Mirza Basic': 0,
#   'Guido Pella': 1,
#   'Pablo Carreno Busta': 0,
#   'Damir Dzumhur': 1,
#   'Rudolf Molleker': 1,
#   'Thiago Monteiro': 1,
#   'Leonardo Mayer': 0,
#   'Gilles Simon': 0,
#   'Viktor Troicki': 0,
#   'Robin Haase': 0,
#   'Joao Sousa': 0,
#   'Fernando Verdasco': 0,
#   'Aljaz Bedene': 0,
#   'Ugo Humbert': 0,
#   'Pedro Sousa': 0,
#   'Corentin Moutet': 1,
#   'Salvatore Caruso': 0,
#   'Maxime Cressy': 0,
#   'Pablo Andujar': 0,
#   'Jiri Vesely': 1,
#   'Benoit Paire': 0,
#   'Jaume Munar': 1,
#   'Pedro Martinez': 1,
#   'Peter Gojowczyk': 1,
#   'Arthur Rinderknech': 0,
#   'Alejandro Tabilo': 0,
#   'Daniel Elahi Galan': 1,
#   'Tomas Barrios Vera': 1,
#   'Facundo Bagnis': 0,
#   'Sumit Nagal': 1,
#   'Nikoloz Basilashvili': 0,
#   'Yuki Bhambri': 0,
#   'Alexander Bublik': 0,
#   'Alejandro Davidovich Fokina': 1,
#   'Max Hans Rehberg': 1,
#   'Denis Shapovalov': 0,
#   'Filip Misolic': 0,
#   'Lorenzo Musetti': 0,
#   'Thiago Seyboth Wild': 1,
#   'Matwe Middelkoop': 0},
#  'Mubarak Shannan Zayid': {'Jeremy Chardy': 0,
#   'Karen Khachanov': 0,
#   'Guillermo Garcia Lopez': 0,
#   'Aslan Karatsev': 0},
#  'Finn Tearney': {'Donald Young': 0,
#   'Robin Haase': 0,
#   'Yuki Bhambri': 0,
#   'Ramkumar Ramanathan': 0,
#   'Jordi Munoz Abreu': 1},
#  'Matthew Barton': {'Steve Johnson': 1,
#   'David Ferrer': 0,
#   'Frances Tiafoe': 1,
#   'Jack Sock': 0,
#   'Albano Olivetti': 1,
#   'John Isner': 0,
#   'Kyle Edmund': 1,
#   'Gilles Muller': 0},
#  'Michael Mmoh': {'Taylor Fritz': 0,
#   'Alexander Zverev': 1,
#   'Jeremy Chardy': 0,
#   'Dustin Brown': 0,
#   'Gilles Simon': 0,
#   'Nicolas Mahut': 0,
#   'Akira Santillan': 0,
#   'Federico Delbonis': 1,
#   'Mischa Zverev': 1,
#   'Alex De Minaur': 0,
#   'Christopher Eubanks': 1,
#   'Roberto Bautista Agut': 1,
#   'Hyeon Chung': 0,
#   'Gilles Muller': 0,
#   'Ernesto Escobedo': 1,
#   'Peter Polansky': 1,
#   'Damir Dzumhur': 0,
#   'Leonardo Mayer': 0,
#   'Fabio Fognini': 0,
#   'Steve Darcis': 0,
#   'Prajnesh Gunneswaran': 1,
#   'Radu Albot': 0,
#   'John Millman': 0,
#   'Pablo Andujar': 1,
#   'Joao Sousa': 1,
#   'Jan Lennard Struff': 0,
#   'Pierre Hugues Herbert': 0,
#   'Lorenzo Musetti': 0,
#   'Viktor Troicki': 1,
#   'Rafael Nadal': 0,
#   'Marcos Giron': 2,
#   'Yoshihito Nishioka': 0,
#   'Nick Kyrgios': 0,
#   'Sam Querrey': 1,
#   'Manuel Guinard': 0,
#   'Bernabe Zapata Miralles': 0,
#   'Denis Kudla': 0,
#   'Filip Krajinovic': 0,
#   'Manas Dhamne': 1,
#   'Laurent Lokoli': 1,
#   'J J Wolf': 0,
#   'Yibing Wu': 0,
#   'Mackenzie Mcdonald': 0,
#   'Denis Shapovalov': 1,
#   'Aleksandar Kovacevic': 1,
#   'Tommy Paul': 0,
#   'Felix Auger Aliassime': 1,
#   'Maximilian Marterer': 0,
#   'Hubert Hurkacz': 1,
#   'Bradley Klahn': 1,
#   'Borna Coric': 0,
#   'Darian King': 1,
#   'Karen Khachanov': 1,
#   'John Isner': 1,
#   'Jack Draper': 0},
#  'Thiago Monteiro': {'Jo-Wilfried Tsonga': 1,
#   'Pablo Cuevas': 0,
#   'Nicolas Almagro': 1,
#   'Daniel Munoz de la Nava': 1,
#   'Mischa Zverev': 1,
#   'Antoine Bellier': 1,
#   'Gilles Simon': 2,
#   'Robin Haase': 0,
#   'Tim Smyczek': 0,
#   'Dusan Lajovic': 1,
#   'David Goffin': 0,
#   'Daniil Medvedev': 0,
#   'Daniel Evans': 0,
#   'Giovanni Lapentti': 0,
#   'Victor Estrella': 1,
#   'Tommy Robredo': 1,
#   'Carlos Berlocq': 0,
#   'Gastao Elias': 1,
#   'Thomaz Bellucci': 2,
#   'Casper Ruud': 0,
#   'Martin Klizan': 0,
#   'Viktor Troicki': 0,
#   'Roberto Quiroz': 1,
#   'Gonzalo Escobar': 1,
#   'Donald Young': 1,
#   'Ernesto Escobedo': 0,
#   'Marius Copil': 0,
#   'Florian Mayer': 0,
#   'Kyle Edmund': 0,
#   'Alexandre Muller': 1,
#   'Gael Monfils': 2,
#   'Andrew Whittington': 1,
#   'Karen Khachanov': 0,
#   'Albert Ramos': 2,
#   'Alexandr Dolgopolov': 2,
#   'Renzo Olivo': 0,
#   'Paolo Lorenzi': 0,
#   'Malek Jaziri': 0,
#   'Go Soeda': 0,
#   'Yuichi Sugita': 0,
#   'Yibing Wu': 1,
#   'Ruben Bemelmans': 1,
#   'Kevin Anderson': 0,
#   'Roberto Cid': 1,
#   'Jose Hernandez': 0,
#   'Horacio Zeballos': 1,
#   'Alessandro Giannessi': 1,
#   'Fernando Verdasco': 1,
#   'Guilherme Clezar': 0,
#   'Santiago Giraldo': 1,
#   'Daniel Elahi Galan': 1,
#   'Gerald Melzer': 1,
#   'Jiri Vesely': 0,
#   'Elias Ymer': 1,
#   'Pablo Carreno Busta': 0,
#   'Jozef Kovalik': 0,
#   'Benoit Paire': 0,
#   'Aljaz Bedene': 0,
#   'Pedro Sousa': 1,
#   'Bernard Tomic': 0,
#   'Marton Fucsovics': 0,
#   'Jan Lennard Struff': 2,
#   'Kei Nishikori': 0,
#   'Alexei Popyrin': 0,
#   'Bradley Klahn': 0,
#   'Haydn Lewis': 1,
#   'Darian King': 1,
#   'Arthur De Greef': 1,
#   'Kimmer Coppejans': 0,
#   'Cameron Norrie': 1,
#   'John Isner': 0,
#   'Corentin Moutet': 0,
#   'Borna Coric': 1,
#   'Jaume Munar': 1,
#   'Attila Balazs': 0,
#   'Guido Pella': 1,
#   'Roberto Carballes Baena': 3,
#   'Leonardo Mayer': 1,
#   'Felix Auger Aliassime': 0,
#   'Nikoloz Basilashvili': 2,
#   'Marcos Giron': 1,
#   'Jordan Thompson': 1,
#   'John Millman': 0,
#   'Yannick Hanfmann': 0,
#   'Laslo Djere': 0,
#   'Tennys Sandgren': 0,
#   'Miomir Kecmanovic': 0,
#   'Francisco Cerundolo': 1,
#   'Steve Johnson': 0,
#   'Andrej Martin': 1,
#   'Andrey Rublev': 0,
#   'James Duckworth': 1,
#   'Eduardo Nava': 1,
#   'Frances Tiafoe': 0,
#   'Thomas Fancutt': 1,
#   'Matthew Ebden': 1,
#   'Carlos Alcaraz': 1,
#   'Stefano Travaglia': 0,
#   'Joao Menezes': 1,
#   'Juan Manuel Cerundolo': 0,
#   'Radu Albot': 1,
#   'Federico Delbonis': 1,
#   'Marin Cilic': 0,
#   'Daniel Altmaier': 1,
#   'Yoshihito Nishioka': 1,
#   'Pedro Martinez': 0,
#   'Matteo Berrettini': 0,
#   'Sebastian Baez': 1,
#   'Nicolas Jarry': 1,
#   'Filip Krajinovic': 1,
#   'Joao Sousa': 1,
#   'Taylor Fritz': 0,
#   'Ugo Humbert': 1,
#   'Jiri Lehecka': 0,
#   'Benjamin Bonzi': 1,
#   'Denis Kudla': 1,
#   'Alex Molcan': 1,
#   'Pablo Andujar': 0,
#   'Holger Rune': 1,
#   'Grigor Dimitrov': 0,
#   'Alexander Zverev': 0,
#   'Nuno Borges': 0,
#   'Constant Lestienne': 0,
#   'Federico Coria': 0,
#   'Pedro Cachin': 0,
#   'Dominic Thiem': 1,
#   'Marco Cecchinato': 1,
#   'Jason Kubler': 1,
#   'Borna Gojo': 1,
#   'Adrian Mannarino': 1,
#   'Christopher Eubanks': 0},
#  'Luis Patino': {'Robin Haase': 0,
#   'Mauricio Echazu': 0,
#   'Nicolas Alvarez': 0,
#   'Wilfredo Gonzalez': 0,
#   'Alex Diaz': 1,
#   'Ignacio Garcia': 1,
#   'Juan Pablo Varillas': 1,
#   'Pablo Cuevas': 0,
#   'Dimitar Kuzmanov': 0},
#  'Adam Hornby': {'Emilio Gomez': 0,
#   'Ivan Endara': 0,
#   'Christopher Diaz Figueroa': 0},
#  'Manuel Castellanos': {'Cristian Garin': 0},
#  'Daniel Windahl': {'Teymuraz Gabashvili': 0, 'Konstantin Kravchuk': 0},
#  'Alexandar Lazarov': {'Marsel Ilhan': 0,
#   'Altug Celikbilek': 1,
#   'Radu Albot': 0,
#   'Fernando Verdasco': 0,
#   'Lloyd Harris': 0,
#   'Jesse Flores': 1,
#   'Filip Krajinovic': 0,
#   'Lorenzo Musetti': 0,
#   'Jiri Lehecka': 1,
#   'Philip Henning': 1,
#   'Alexander Bublik': 0,
#   'Pavel Kotov': 0},
#  'Altug Celikbilek': {'Alexandar Lazarov': 0,
#   'Nicholas Campbell': 1,
#   'Elias Ymer': 0,
#   'Benjamin Lock': 0,
#   'Damir Dzumhur': 0,
#   'Ernests Gulbis': 1,
#   'Holger Rune': 1,
#   'Christian Sigsgaard': 1,
#   'Ben Patael': 1,
#   'Sam Querrey': 0,
#   'Kacper Zuk': 1,
#   'Nikoloz Basilashvili': 0,
#   'Shintaro Mochizuki': 1,
#   'Alexander Bublik': 0,
#   'Robert Strombachs': 1,
#   'Brandon Nakashima': 0,
#   'Giulio Zeppieri': 1,
#   'Nicolas Mejia': 0,
#   'Sergey Fomin': 1,
#   'Sanjar Fayziev': 1},
#  'Ilya Ivashka': {'Mohamed Safwat': 1,
#   'Martins Podzus': 1,
#   'Janis Podzus': 1,
#   'Pablo Carreno Busta': 1,
#   'Andreas Bjerrehus': 1,
#   'Frederik Nielsen': 1,
#   'Adrian Ungur': 0,
#   'Marius Copil': 0,
#   'Jurgen Melzer': 1,
#   'Gerald Melzer': 1,
#   'Sumit Nagal': 1,
#   'Ricardo Ojeda Lara': 0,
#   'Dominic Thiem': 0,
#   'Laslo Djere': 2,
#   'Stan Wawrinka': 1,
#   'Nicolas Mahut': 1,
#   'Lucas Pouille': 0,
#   'Yuichi Sugita': 1,
#   'Pablo Andujar': 1,
#   'Fabio Fognini': 0,
#   'Gilles Simon': 0,
#   'Hubert Hurkacz': 2,
#   'Ryan Harrison': 1,
#   'Kevin Anderson': 0,
#   'Guido Pella': 1,
#   'Denis Shapovalov': 1,
#   'Robin Haase': 1,
#   'Salvatore Caruso': 1,
#   'Kyle Edmund': 0,
#   'Malek Jaziri': 1,
#   'Pierre Hugues Herbert': 0,
#   'Thomas Fabbiano': 2,
#   'Tomas Berdych': 0,
#   'Guido Andreozzi': 0,
#   'Ugo Humbert': 0,
#   'Christopher Eubanks': 1,
#   'Bernard Tomic': 1,
#   'Adrian Mannarino': 2,
#   'Gael Monfils': 1,
#   'Soon Woo Kwon': 2,
#   'Thanasi Kokkinakis': 0,
#   'Andrey Rublev': 0,
#   'Joao Sousa': 0,
#   'Pedro Sousa': 1,
#   'Jiri Vesely': 0,
#   'Stefano Travaglia': 2,
#   'Evgeny Donskoy': 1,
#   'Marin Cilic': 1,
#   'Jan Lennard Struff': 2,
#   'Mikhail Kukushkin': 1,
#   'Kei Nishikori': 0,
#   'Emil Ruusuvuori': 5,
#   'Mackenzie Mcdonald': 3,
#   'Alexander Zverev': 1,
#   'Peter Gojowczyk': 1,
#   'Fernando Verdasco': 1,
#   'Grigor Dimitrov': 2,
#   'Albert Ramos': 1,
#   'Daniil Medvedev': 0,
#   'Egor Gerasimov': 1,
#   'Tallon Griekspoor': 1,
#   'Rafael Nadal': 0,
#   'Roger Federer': 0,
#   'Alastair Gray': 1,
#   'Alexei Popyrin': 1,
#   'Jaume Munar': 1,
#   'Jeremy Chardy': 1,
#   'Jordan Thompson': 1,
#   'Matteo Berrettini': 0,
#   'Tennys Sandgren': 1,
#   'Vasek Pospisil': 1,
#   'Roman Safiullin': 1,
#   'Andreas Seppi': 1,
#   'Mikael Ymer': 2,
#   'Elias Ymer': 1,
#   'Timofey Skatov': 1,
#   'James Duckworth': 0,
#   'Pedro Martinez': 2,
#   'Alejandro Davidovich Fokina': 1,
#   'Stefanos Tsitsipas': 0,
#   'Lloyd Harris': 1,
#   'Felix Auger Aliassime': 0,
#   'Norbert Gombos': 1,
#   'Lorenzo Sonego': 0,
#   'Nikoloz Basilashvili': 0,
#   'Lorenzo Musetti': 1,
#   'Marcos Giron': 1,
#   'Benoit Paire': 1,
#   'Cristian Garin': 0,
#   'Alex De Minaur': 0,
#   'Tommy Paul': 1,
#   'Steve Johnson': 1,
#   'Quentin Halys': 1,
#   'Sebastian Korda': 0,
#   'Marc Andrea Huesler': 0,
#   'Sam Querrey': 1,
#   'Jannik Sinner': 0,
#   'Holger Rune': 0,
#   'Feliciano Lopez': 1,
#   'Maxime Cressy': 0,
#   'Botic Van De Zandschulp': 1,
#   'Jack Sock': 0,
#   'J J Wolf': 0,
#   'Casper Ruud': 0,
#   'Daniel Altmaier': 1,
#   'Karen Khachanov': 0,
#   'Daniel Evans': 1,
#   'Nuno Borges': 0,
#   'Taylor Fritz': 0,
#   'Roberto Carballes Baena': 0,
#   'Federico Coria': 1,
#   'Borna Coric': 0,
#   'Borna Gojo': 1,
#   'Beibit Zhukayev': 1,
#   'Zhizhen Zhang': 0,
#   'Juan Manuel Cerundolo': 0},
#  'Casper Ruud': {'Ricardas Berankis': 0,
#   'Lukas Mugevicius': 1,
#   'Viktor Troicki': 0,
#   'Renzo Olivo': 0,
#   'Martins Podzus': 1,
#   'Rogerio Dutra Silva': 1,
#   'Roberto Carballes Baena': 5,
#   'Thiago Monteiro': 3,
#   'Pablo Carreno Busta': 2,
#   'Akira Santillan': 1,
#   'Federico Delbonis': 2,
#   'Yen Hsun Lu': 0,
#   'Soren Hess Olesen': 1,
#   'Frederik Nielsen': 0,
#   'Jan Lennard Struff': 1,
#   'Radu Albot': 2,
#   'Albert Ramos': 3,
#   'Philipp Kohlschreiber': 0,
#   'Tommy Paul': 3,
#   'Robin Haase': 1,
#   'Quentin Halys': 2,
#   'Diego Schwartzman': 4,
#   'Carlos Berlocq': 2,
#   'Gael Monfils': 0,
#   'Marius Copil': 1,
#   'Roberto Bautista Agut': 1,
#   'Jordan Thompson': 2,
#   'Jaume Munar': 2,
#   'David Ferrer': 1,
#   'Richard Gasquet': 1,
#   'Guido Pella': 0,
#   'Laslo Djere': 1,
#   'Joao Sousa': 4,
#   'Cristian Garin': 2,
#   'Hugo Dellien': 2,
#   'Felix Auger Aliassime': 3,
#   'Daniel Elahi Galan': 2,
#   'Marcel Granollers': 1,
#   'Reilly Opelka': 4,
#   'Juan Martin del Potro': 0,
#   'Nick Kyrgios': 1,
#   'Daniel Evans': 1,
#   'Ernests Gulbis': 1,
#   'Matteo Berrettini': 4,
#   'Roger Federer': 0,
#   'John Isner': 1,
#   'Damir Dzumhur': 0,
#   'Andrey Rublev': 2,
#   'Pablo Cuevas': 2,
#   'Matthias Bachinger': 1,
#   'Steve Johnson': 0,
#   'Lloyd Harris': 3,
#   'Borna Coric': 0,
#   'Salvatore Caruso': 1,
#   'Alexander Bublik': 6,
#   'Miomir Kecmanovic': 1,
#   'Filip Krajinovic': 0,
#   'Adrian Mannarino': 0,
#   'George Tsivadze': 1,
#   'Aleksandre Metreveli': 1,
#   'Alex De Minaur': 0,
#   'Alejandro Davidovich Fokina': 1,
#   'Daniil Medvedev': 0,
#   'Fabio Fognini': 3,
#   'Ugo Humbert': 1,
#   'Egor Gerasimov': 0,
#   'Pedro Sousa': 1,
#   'Juan Ignacio Londero': 1,
#   'Dusan Lajovic': 3,
#   'Pablo Andujar': 2,
#   'Gianluca Mager': 1,
#   'Thiago Seyboth Wild': 0,
#   'Alejandro Tabilo': 1,
#   'Mackenzie Mcdonald': 1,
#   'Emil Ruusuvuori': 3,
#   'Novak Djokovic': 0,
#   'Marin Cilic': 3,
#   'Lorenzo Sonego': 4,
#   'Karen Khachanov': 2,
#   'Benoit Paire': 4,
#   'Yuichi Sugita': 2,
#   'Dominic Thiem': 0,
#   'Yannick Hanfmann': 0,
#   'Jannik Sinner': 0,
#   'Haydn Lewis': 1,
#   'John Millman': 1,
#   'Nikoloz Basilashvili': 0,
#   'Dennis Novak': 1,
#   'Vit Kopriva': 1,
#   'Hugo Gaston': 1,
#   'Holger Rune': 5,
#   'Henri Laaksonen': 2,
#   'Federico Coria': 2,
#   'Mario Vilella Martinez': 1,
#   'Mikael Ymer': 1,
#   'Arthur Rinderknech': 2,
#   'Pedro Martinez': 1,
#   'Tennys Sandgren': 2,
#   'Dominik Koepfer': 1,
#   'Denis Shapovalov': 2,
#   'Marcos Giron': 1,
#   'Alexander Zverev': 2,
#   'Stefanos Tsitsipas': 1,
#   'Cameron Norrie': 3,
#   'Tallon Griekspoor': 1,
#   'Yoshihito Nishioka': 2,
#   'Kamil Majchrzak': 1,
#   'Botic Van De Zandschulp': 2,
#   'Gilles Simon': 1,
#   'Jiri Vesely': 0,
#   'Carlos Alcaraz': 0,
#   'Andy Murray': 1,
#   'Grigor Dimitrov': 1,
#   'Vitaliy Sachko': 1,
#   'Sergiy Stakhovsky': 1,
#   'Khumoun Sultanov': 1,
#   'Sanjar Fayziev': 1,
#   'Christopher Eubanks': 2,
#   'Francisco Cerundolo': 2,
#   'Brandon Nakashima': 1,
#   'Alex Molcan': 2,
#   'Jenson Brooksby': 1,
#   'Thanasi Kokkinakis': 1,
#   'Jo-Wilfried Tsonga': 1,
#   'Hubert Hurkacz': 1,
#   'Rafael Nadal': 0,
#   'Ryan Peniston': 0,
#   'Jiri Lehecka': 2,
#   'Ben Shelton': 1,
#   'Kyle Edmund': 1,
#   'Tim Van Rijthoven': 1,
#   'Corentin Moutet': 1,
#   'Jack Sock': 1,
#   'Nicolas Jarry': 2,
#   'Stan Wawrinka': 0,
#   'Lorenzo Musetti': 1,
#   'Taylor Fritz': 1,
#   'Mikhail Kukushkin': 1,
#   'Prajnesh Gunneswaran': 1,
#   'Tomas Machac': 1,
#   'Taro Daniel': 0,
#   'Guido Andreozzi': 1,
#   'Ilya Ivashka': 1,
#   'Sebastian Baez': 2,
#   'Matteo Arnaldi': 0,
#   'J J Wolf': 1,
#   'Elias Ymer': 1,
#   'Giulio Zeppieri': 1,
#   'Zhizhen Zhang': 1,
#   'Laurent Lokoli': 1,
#   'Liam Broady': 0,
#   'Sebastian Ofner': 1,
#   'Alexander Shevchenko': 1,
#   'Arthur Fils': 0,
#   'Max Purcell': 0,
#   'Emilio Nava': 1,
#   'Tomas Martin Etcheverry': 1,
#   'Fabian Marozsan': 0,
#   'Yosuke Watanuki': 1,
#   'Dominic Stricker': 0},
#  'Hans Hach Verdugo': {'Christopher Diaz Figueroa': 1, 'Wilfredo Gonzalez': 0},
#  'Lucas Catarina': {'Rudolfs Mednis': 1,
#   'Blaz Kavcic': 0,
#   'Grega Zemlja': 0,
#   'Milos Raonic': 0,
#   'Jaume Munar': 0,
#   'Salvatore Caruso': 0,
#   'Taylor Fritz': 0,
#   'Benjamin Hassan': 0,
#   'Emilio Gomez': 1},
#  'Bruno Britez': {'Ricardo Rodriguez': 0,
#   'Darian King': 0,
#   'Seanon Williams': 1},
#  'Ayed Zatar': {'Luis David Martinez': 0,
#   'Haydn Lewis': 1,
#   'Darian King': 0,
#   'Manuel Sanchez': 0,
#   'Lucas Gomez': 0},
#  'Francisco Yim Kim': {'Ricardo Rodriguez': 0},
#  'Hernando Jose Escurra Isnardi': {'Miguel Angel Este': 0,
#   'Sebastian Dominko': 1},
#  'Abdulrahman Alawadhi': {'Jeson Patrombon': 0},
#  ...}

# %%
matches_data = pd.DataFrame(games_played).T.fillna(0)

# %%
pd.DataFrame(win_percentages).T.fillna(0)
# Out:
#                            Peter Luczak  Carsten Ball  Richard Gasquet  \
# Andy Roddick                        1.0           1.0             0.50
# Peter Luczak                        0.0           0.0             0.00
# Carsten Ball                        0.0           0.0             0.00
# Mischa Zverev                       0.0           0.0             0.25
# Richard Gasquet                     0.0           0.0             0.00
# ...                                 ...           ...              ...
# Daniel Azar                         0.0           0.0             0.00
# Fajing Sun                          0.0           0.0             0.00
# Alvaro Guillen Meza                 0.0           0.0             0.00
# Chris Rodesch                       0.0           0.0             0.00
# Joaquin  Aguilar Cardozo            0.0           0.0             0.00
#
#                            Tomas Berdych  Radek Stepanek  Thiemo De Bakker  \
# Andy Roddick                         0.5             1.0               1.0
# Peter Luczak                         1.0             0.0               0.0
# Carsten Ball                         0.0             0.0               0.0
# Mischa Zverev                        0.0             0.0               0.0
# Richard Gasquet                      0.4             0.5               1.0
# ...                                  ...             ...               ...
# Daniel Azar                          0.0             0.0               0.0
# Fajing Sun                           0.0             0.0               0.0
# Alvaro Guillen Meza                  0.0             0.0               0.0
# Chris Rodesch                        0.0             0.0               0.0
# Joaquin  Aguilar Cardozo             0.0             0.0               0.0
#
#                            Thomaz Bellucci  Feliciano Lopez  \
# Andy Roddick                           1.0         0.666667
# Peter Luczak                           0.0         0.000000
# Carsten Ball                           0.0         0.000000
# Mischa Zverev                          1.0         0.000000
# Richard Gasquet                        1.0         0.750000
# ...                                    ...              ...
# Daniel Azar                            0.0         0.000000
# Fajing Sun                             0.0         0.000000
# Alvaro Guillen Meza                    0.0         0.000000
# Chris Rodesch                          0.0         0.000000
# Joaquin  Aguilar Cardozo               0.0         0.000000
#
#                            Fernando Gonzalez  Marin Cilic  ...  Conor Gannon  \
# Andy Roddick                             1.0          0.0  ...           0.0
# Peter Luczak                             0.0          0.0  ...           0.0
# Carsten Ball                             0.0          0.0  ...           0.0
# Mischa Zverev                            0.0          0.0  ...           0.0
# Richard Gasquet                          0.0          0.5  ...           0.0
# ...                                      ...          ...  ...           ...
# Daniel Azar                              0.0          0.0  ...           0.0
# Fajing Sun                               0.0          0.0  ...           0.0
# Alvaro Guillen Meza                      0.0          0.0  ...           0.0
# Chris Rodesch                            0.0          0.0  ...           0.0
# Joaquin  Aguilar Cardozo                 0.0          0.0  ...           0.0
#
#                            Alvaro Guillen Meza  Lucky Candra Kurniawan  \
# Andy Roddick                               0.0                     0.0
# Peter Luczak                               0.0                     0.0
# Carsten Ball                               0.0                     0.0
# Mischa Zverev                              0.0                     0.0
# Richard Gasquet                            0.0                     0.0
# ...                                        ...                     ...
# Daniel Azar                                0.0                     0.0
# Fajing Sun                                 0.0                     0.0
# Alvaro Guillen Meza                        0.0                     0.0
# Chris Rodesch                              0.0                     0.0
# Joaquin  Aguilar Cardozo                   0.0                     0.0
#
#                            Ignacio Buse  Jose  Flores  Freddy Murray  \
# Andy Roddick                        0.0           0.0            0.0
# Peter Luczak                        0.0           0.0            0.0
# Carsten Ball                        0.0           0.0            0.0
# Mischa Zverev                       0.0           0.0            0.0
# Richard Gasquet                     0.0           0.0            0.0
# ...                                 ...           ...            ...
# Daniel Azar                         0.0           0.0            0.0
# Fajing Sun                          0.0           0.0            0.0
# Alvaro Guillen Meza                 0.0           0.0            0.0
# Chris Rodesch                       0.0           0.0            0.0
# Joaquin  Aguilar Cardozo            0.0           0.0            0.0
#
#                            Walid Ahouda  Digvijaypratap Singh  Daniel Azar  \
# Andy Roddick                        0.0                   0.0          0.0
# Peter Luczak                        0.0                   0.0          0.0
# Carsten Ball                        0.0                   0.0          0.0
# Mischa Zverev                       0.0                   0.0          0.0
# Richard Gasquet                     0.0                   0.0          0.0
# ...                                 ...                   ...          ...
# Daniel Azar                         0.0                   0.0          0.0
# Fajing Sun                          0.0                   0.0          0.0
# Alvaro Guillen Meza                 0.0                   0.0          0.0
# Chris Rodesch                       0.0                   0.0          0.0
# Joaquin  Aguilar Cardozo            0.0                   0.0          0.0
#
#                            Mustapha El Natour
# Andy Roddick                              0.0
# Peter Luczak                              0.0
# Carsten Ball                              0.0
# Mischa Zverev                             0.0
# Richard Gasquet                           0.0
# ...                                       ...
# Daniel Azar                               0.0
# Fajing Sun                                0.0
# Alvaro Guillen Meza                       0.0
# Chris Rodesch                             0.0
# Joaquin  Aguilar Cardozo                  0.0
#
# [1533 rows x 1533 columns]

# %%
matches_data.loc['Andy Roddick'].sum()
# Out:
# 155.0

# %%
data[(data['winner_name'] == 'Andy Roddick') & (data['loser_name'] == 'Thiemo De Bakker')]
# Out:
#               tourney_name surface  draw_size tourney_level  best_of  \
# 179        Australian Open    Hard        128             G        5
# 837   Indian Wells Masters    Hard         96             M        3
# 2260    Cincinnati Masters    Hard         56             M        3
#
#        winner_name  winner_age        loser_name  loser_age  Year
# 179   Andy Roddick        27.3  Thiemo De Bakker       21.3  2010
# 837   Andy Roddick        27.5  Thiemo De Bakker       21.4  2010
# 2260  Andy Roddick        27.9  Thiemo De Bakker       21.9  2010

# %%
data[(data['winner_name'] == 'Feliciano Lopez') & (data['loser_name'] == 'Andy Roddick')]
# Out:
#      tourney_name surface  draw_size tourney_level  best_of      winner_name  \
# 4755    Wimbledon   Grass        128             G        5  Feliciano Lopez
#
#       winner_age    loser_name  loser_age  Year
# 4755        29.7  Andy Roddick       28.8  2011

# %%
games_played_df
# Out:
#                            Peter Luczak  Carsten Ball  Richard Gasquet  \
# Andy Roddick                        1.0           1.0              2.0
# Peter Luczak                        0.0           0.0              0.0
# Carsten Ball                        0.0           0.0              0.0
# Mischa Zverev                       0.0           1.0              4.0
# Richard Gasquet                     0.0           0.0              0.0
# ...                                 ...           ...              ...
# Daniel Azar                         0.0           0.0              0.0
# Fajing Sun                          0.0           0.0              0.0
# Alvaro Guillen Meza                 0.0           0.0              0.0
# Chris Rodesch                       0.0           0.0              0.0
# Joaquin  Aguilar Cardozo            0.0           0.0              0.0
#
#                            Tomas Berdych  Radek Stepanek  Thiemo De Bakker  \
# Andy Roddick                         6.0             2.0               3.0
# Peter Luczak                         1.0             0.0               0.0
# Carsten Ball                         1.0             0.0               0.0
# Mischa Zverev                        3.0             0.0               0.0
# Richard Gasquet                     15.0             2.0               2.0
# ...                                  ...             ...               ...
# Daniel Azar                          0.0             0.0               0.0
# Fajing Sun                           0.0             0.0               0.0
# Alvaro Guillen Meza                  0.0             0.0               0.0
# Chris Rodesch                        0.0             0.0               0.0
# Joaquin  Aguilar Cardozo             0.0             0.0               0.0
#
#                            Thomaz Bellucci  Feliciano Lopez  \
# Andy Roddick                           1.0              3.0
# Peter Luczak                           0.0              0.0
# Carsten Ball                           0.0              0.0
# Mischa Zverev                          1.0              3.0
# Richard Gasquet                        4.0              4.0
# ...                                    ...              ...
# Daniel Azar                            0.0              0.0
# Fajing Sun                             0.0              0.0
# Alvaro Guillen Meza                    0.0              0.0
# Chris Rodesch                          0.0              0.0
# Joaquin  Aguilar Cardozo               0.0              0.0
#
#                            Fernando Gonzalez  Marin Cilic  ...  Conor Gannon  \
# Andy Roddick                             1.0          1.0  ...           0.0
# Peter Luczak                             0.0          0.0  ...           0.0
# Carsten Ball                             0.0          0.0  ...           0.0
# Mischa Zverev                            0.0          3.0  ...           0.0
# Richard Gasquet                          0.0          4.0  ...           0.0
# ...                                      ...          ...  ...           ...
# Daniel Azar                              0.0          0.0  ...           0.0
# Fajing Sun                               0.0          0.0  ...           0.0
# Alvaro Guillen Meza                      0.0          0.0  ...           0.0
# Chris Rodesch                            0.0          0.0  ...           0.0
# Joaquin  Aguilar Cardozo                 0.0          0.0  ...           0.0
#
#                            Alvaro Guillen Meza  Lucky Candra Kurniawan  \
# Andy Roddick                               0.0                     0.0
# Peter Luczak                               0.0                     0.0
# Carsten Ball                               0.0                     0.0
# Mischa Zverev                              0.0                     0.0
# Richard Gasquet                            0.0                     0.0
# ...                                        ...                     ...
# Daniel Azar                                0.0                     0.0
# Fajing Sun                                 0.0                     0.0
# Alvaro Guillen Meza                        0.0                     0.0
# Chris Rodesch                              0.0                     0.0
# Joaquin  Aguilar Cardozo                   0.0                     0.0
#
#                            Ignacio Buse  Jose  Flores  Freddy Murray  \
# Andy Roddick                        0.0           0.0            0.0
# Peter Luczak                        0.0           0.0            0.0
# Carsten Ball                        0.0           0.0            0.0
# Mischa Zverev                       0.0           0.0            0.0
# Richard Gasquet                     0.0           0.0            0.0
# ...                                 ...           ...            ...
# Daniel Azar                         0.0           0.0            0.0
# Fajing Sun                          0.0           0.0            0.0
# Alvaro Guillen Meza                 0.0           0.0            0.0
# Chris Rodesch                       0.0           0.0            0.0
# Joaquin  Aguilar Cardozo            0.0           0.0            0.0
#
#                            Walid Ahouda  Digvijaypratap Singh  Daniel Azar  \
# Andy Roddick                        0.0                   0.0          0.0
# Peter Luczak                        0.0                   0.0          0.0
# Carsten Ball                        0.0                   0.0          0.0
# Mischa Zverev                       0.0                   0.0          0.0
# Richard Gasquet                     0.0                   0.0          0.0
# ...                                 ...                   ...          ...
# Daniel Azar                         0.0                   0.0          0.0
# Fajing Sun                          0.0                   0.0          0.0
# Alvaro Guillen Meza                 0.0                   0.0          0.0
# Chris Rodesch                       0.0                   0.0          0.0
# Joaquin  Aguilar Cardozo            0.0                   0.0          0.0
#
#                            Mustapha El Natour
# Andy Roddick                              0.0
# Peter Luczak                              0.0
# Carsten Ball                              0.0
# Mischa Zverev                             0.0
# Richard Gasquet                           0.0
# ...                                       ...
# Daniel Azar                               1.0
# Fajing Sun                                0.0
# Alvaro Guillen Meza                       0.0
# Chris Rodesch                             0.0
# Joaquin  Aguilar Cardozo                  0.0
#
# [1533 rows x 1533 columns]

# %%
win_percentage_df.loc['Feliciano Lopez']['Andy Roddick']
# Out:
# 0.3333333333333333

# %%
win_percentage_df
# Out:
#                            Peter Luczak  Carsten Ball  Richard Gasquet  \
# Andy Roddick                        1.0           1.0             0.50
# Peter Luczak                        0.0           0.0             0.00
# Carsten Ball                        0.0           0.0             0.00
# Mischa Zverev                       0.0           0.0             0.25
# Richard Gasquet                     0.0           0.0             0.00
# ...                                 ...           ...              ...
# Daniel Azar                         0.0           0.0             0.00
# Fajing Sun                          0.0           0.0             0.00
# Alvaro Guillen Meza                 0.0           0.0             0.00
# Chris Rodesch                       0.0           0.0             0.00
# Joaquin  Aguilar Cardozo            0.0           0.0             0.00
#
#                            Tomas Berdych  Radek Stepanek  Thiemo De Bakker  \
# Andy Roddick                         0.5             1.0               1.0
# Peter Luczak                         1.0             0.0               0.0
# Carsten Ball                         0.0             0.0               0.0
# Mischa Zverev                        0.0             0.0               0.0
# Richard Gasquet                      0.4             0.5               1.0
# ...                                  ...             ...               ...
# Daniel Azar                          0.0             0.0               0.0
# Fajing Sun                           0.0             0.0               0.0
# Alvaro Guillen Meza                  0.0             0.0               0.0
# Chris Rodesch                        0.0             0.0               0.0
# Joaquin  Aguilar Cardozo             0.0             0.0               0.0
#
#                            Thomaz Bellucci  Feliciano Lopez  \
# Andy Roddick                           1.0         0.666667
# Peter Luczak                           0.0         0.000000
# Carsten Ball                           0.0         0.000000
# Mischa Zverev                          1.0         0.000000
# Richard Gasquet                        1.0         0.750000
# ...                                    ...              ...
# Daniel Azar                            0.0         0.000000
# Fajing Sun                             0.0         0.000000
# Alvaro Guillen Meza                    0.0         0.000000
# Chris Rodesch                          0.0         0.000000
# Joaquin  Aguilar Cardozo               0.0         0.000000
#
#                            Fernando Gonzalez  Marin Cilic  ...  Conor Gannon  \
# Andy Roddick                             1.0          0.0  ...           0.0
# Peter Luczak                             0.0          0.0  ...           0.0
# Carsten Ball                             0.0          0.0  ...           0.0
# Mischa Zverev                            0.0          0.0  ...           0.0
# Richard Gasquet                          0.0          0.5  ...           0.0
# ...                                      ...          ...  ...           ...
# Daniel Azar                              0.0          0.0  ...           0.0
# Fajing Sun                               0.0          0.0  ...           0.0
# Alvaro Guillen Meza                      0.0          0.0  ...           0.0
# Chris Rodesch                            0.0          0.0  ...           0.0
# Joaquin  Aguilar Cardozo                 0.0          0.0  ...           0.0
#
#                            Alvaro Guillen Meza  Lucky Candra Kurniawan  \
# Andy Roddick                               0.0                     0.0
# Peter Luczak                               0.0                     0.0
# Carsten Ball                               0.0                     0.0
# Mischa Zverev                              0.0                     0.0
# Richard Gasquet                            0.0                     0.0
# ...                                        ...                     ...
# Daniel Azar                                0.0                     0.0
# Fajing Sun                                 0.0                     0.0
# Alvaro Guillen Meza                        0.0                     0.0
# Chris Rodesch                              0.0                     0.0
# Joaquin  Aguilar Cardozo                   0.0                     0.0
#
#                            Ignacio Buse  Jose  Flores  Freddy Murray  \
# Andy Roddick                        0.0           0.0            0.0
# Peter Luczak                        0.0           0.0            0.0
# Carsten Ball                        0.0           0.0            0.0
# Mischa Zverev                       0.0           0.0            0.0
# Richard Gasquet                     0.0           0.0            0.0
# ...                                 ...           ...            ...
# Daniel Azar                         0.0           0.0            0.0
# Fajing Sun                          0.0           0.0            0.0
# Alvaro Guillen Meza                 0.0           0.0            0.0
# Chris Rodesch                       0.0           0.0            0.0
# Joaquin  Aguilar Cardozo            0.0           0.0            0.0
#
#                            Walid Ahouda  Digvijaypratap Singh  Daniel Azar  \
# Andy Roddick                        0.0                   0.0          0.0
# Peter Luczak                        0.0                   0.0          0.0
# Carsten Ball                        0.0                   0.0          0.0
# Mischa Zverev                       0.0                   0.0          0.0
# Richard Gasquet                     0.0                   0.0          0.0
# ...                                 ...                   ...          ...
# Daniel Azar                         0.0                   0.0          0.0
# Fajing Sun                          0.0                   0.0          0.0
# Alvaro Guillen Meza                 0.0                   0.0          0.0
# Chris Rodesch                       0.0                   0.0          0.0
# Joaquin  Aguilar Cardozo            0.0                   0.0          0.0
#
#                            Mustapha El Natour
# Andy Roddick                              0.0
# Peter Luczak                              0.0
# Carsten Ball                              0.0
# Mischa Zverev                             0.0
# Richard Gasquet                           0.0
# ...                                       ...
# Daniel Azar                               0.0
# Fajing Sun                                0.0
# Alvaro Guillen Meza                       0.0
# Chris Rodesch                             0.0
# Joaquin  Aguilar Cardozo                  0.0
#
# [1533 rows x 1533 columns]

# %%
for _, row in data.iterrows():
    winner = row['winner_name']
    loser = row['loser_name']

# %%
data[(data['Year'] == 2023) & (data['tourney_name'] == 'Roland Garros')]
# Out:
#         tourney_name surface  draw_size tourney_level  best_of  \
# 25777  Roland Garros    Clay        128             G        5
# 25778  Roland Garros    Clay        128             G        5
# 25779  Roland Garros    Clay        128             G        5
# 25780  Roland Garros    Clay        128             G        5
# 25781  Roland Garros    Clay        128             G        5
# ...              ...     ...        ...           ...      ...
# 25899  Roland Garros    Clay        128             G        5
# 25900  Roland Garros    Clay        128             G        5
# 25901  Roland Garros    Clay        128             G        5
# 25902  Roland Garros    Clay        128             G        5
# 25903  Roland Garros    Clay        128             G        5
#
#             winner_name  winner_age               loser_name  loser_age  Year
# 25777    Carlos Alcaraz        20.0           Flavio Cobolli       21.0  2023
# 25778       Taro Daniel        30.3     Christopher Oconnell       28.9  2023
# 25779    Matteo Arnaldi        22.2       Daniel Elahi Galan       26.9  2023
# 25780  Denis Shapovalov        24.1        Brandon Nakashima       21.8  2023
# 25781   Lorenzo Musetti        21.2              Mikael Ymer       24.7  2023
# ...                 ...         ...                      ...        ...   ...
# 25899       Casper Ruud        24.4              Holger Rune       20.0  2023
# 25900  Alexander Zverev        26.1  Tomas Martin Etcheverry       23.8  2023
# 25901    Novak Djokovic        36.0           Carlos Alcaraz       20.0  2023
# 25902       Casper Ruud        24.4         Alexander Zverev       26.1  2023
# 25903    Novak Djokovic        36.0              Casper Ruud       24.4  2023
#
# [127 rows x 10 columns]

# %%
def logistic( x):
    """
    Creates logistic function used for ELO calculation.

    Args:
        x (float): number input for the log function

    Returns:
            Final calculation of log function with given number
    """
    return 1 / (1 + 10**(-x))

# %%
logistic((1500-1300)/400) + logistic((1300-1500)/400)
# Out:
# 1.0

# %%
logistic((1300-1500)/400)
# Out:
# 0.2402530733520421

# %%
data
# Out:
#                        tourney_name surface  draw_size tourney_level  best_of  \
# 0                          Brisbane    Hard         32             A        3
# 1                          Brisbane    Hard         32             A        3
# 2                          Brisbane    Hard         32             A        3
# 3                          Brisbane    Hard         32             A        3
# 4                          Brisbane    Hard         32             A        3
# ...                             ...     ...        ...           ...      ...
# 39361  Davis Cup WG2 R1: SLO vs LUX    Clay          4             D        3
# 39362  Davis Cup WG2 R1: SLO vs LUX    Clay          4             D        3
# 39363  Davis Cup WG2 R1: URU vs EGY    Clay          4             D        3
# 39364  Davis Cup WG2 R1: URU vs EGY    Clay          4             D        3
# 39365  Davis Cup WG2 R1: URU vs EGY    Clay          4             D        3
#
#                      winner_name  winner_age                       loser_name  \
# 0                   Andy Roddick        27.3                     Peter Luczak
# 1                   Carsten Ball        22.5                    Mischa Zverev
# 2                Richard Gasquet        23.5                  Jarkko Nieminen
# 3                  Matthew Ebden        22.1                    Jurgen Melzer
# 4                  Tomas Berdych        24.2                     Nick Lindahl
# ...                          ...         ...                              ...
# 39361                  Blaz Rola        32.9                       Alex Knaff
# 39362              Chris Rodesch        22.1                       Bor Artnak
# 39363             Mohamed Safwat        32.9                    Ignacio Carou
# 39364      Karim Mohamed Maamoun        32.4                Franco Roncadelli
# 39365  Joaquin  Aguilar Cardozo         18.4  Amr Elsayed Abdou Ahmed Mohamed
#
#        loser_age  Year
# 0           30.3  2010
# 1           22.3  2010
# 2           28.4  2010
# 3           28.6  2010
# 4           21.4  2010
# ...          ...   ...
# 39361       25.7  2023
# 39362       19.2  2023
# 39363       24.1  2023
# 39364       23.5  2023
# 39365       24.5  2023
#
# [39366 rows x 10 columns]

# %%
X_train_new = train_over.drop('Target', axis = 1)
y_train_new = train_over['Target']

# %%
#tennis_data = pd.read_csv('tennis_data.csv')
player_elos = pd.read_csv('../data/player_elos.csv', index_col='Player_Name')

# %%
player_elos
# Out:
#                                Hard_ELO     Clay_ELO    Grass_ELO  Player_age
# Player_Name
# Tristan Lamasine            1493.387818  1493.576646  1492.922151        29.8
# Sam Riffice                 1485.198991  1488.159193  1488.159193        24.4
# Mattia Bellucci             1500.000000  1500.000000  1500.000000        21.6
# Yannick Maden               1470.762620  1476.230963  1473.139722        34.2
# Andreas Haider Maurer       1437.895391  1437.229610  1441.228491        38.9
# ...                                 ...          ...          ...         ...
# Mehluli Don Ayanda Sibanda  1492.730124  1492.998100  1493.656989        24.0
# Nikoloz Basilashvili        1454.103588  1458.841098  1467.911592        30.9
# Nik Razborsek               1498.373420  1498.374707  1497.969671        34.4
# Yanki Erel                  1496.909013  1496.136266  1496.909013        22.9
# Ali Ghareeb                 1499.174840  1499.119908  1499.242110        36.9
#
# [1158 rows x 4 columns]

# %%
data[data['winner_name'] == 'Carlos Alcaraz']
# Out:
#              tourney_name surface  draw_size tourney_level  best_of  \
# 29871  ATP Rio de Janeiro    Clay         32             A        3
# 31082              Vienna    Hard         32             A        3
# 31095              Vienna    Hard         32             A        3
# 31101              Vienna    Hard         32             A        3
# 31139       Paris Masters    Hard         64             M        3
# ...                   ...     ...        ...           ...      ...
# 38806             Beijing    Hard         32             A        3
# 38837    Shanghai Masters    Hard        128             M        3
# 38853    Shanghai Masters    Hard        128             M        3
# 39182         Tour Finals    Hard          8             A        3
# 39183         Tour Finals    Hard          8             A        3
#
#           winner_name  winner_age             loser_name  loser_age  Year
# 29871  Carlos Alcaraz        16.7           Albert Ramos       32.0  2020
# 31082  Carlos Alcaraz        18.4           Daniel Evans       31.4  2021
# 31095  Carlos Alcaraz        18.4            Andy Murray       34.4  2021
# 31101  Carlos Alcaraz        18.4      Matteo Berrettini       25.5  2021
# 31139  Carlos Alcaraz        18.4  Pierre Hugues Herbert       30.6  2021
# ...               ...         ...                    ...        ...   ...
# 38806  Carlos Alcaraz        20.3       Yannick Hanfmann       31.8  2023
# 38837  Carlos Alcaraz        20.4           Daniel Evans       33.3  2023
# 38853  Carlos Alcaraz        20.4       Gregoire Barrere       29.6  2023
# 39182  Carlos Alcaraz        20.5        Daniil Medvedev       27.7  2023
# 39183  Carlos Alcaraz        20.5          Andrey Rublev       26.0  2023
#
# [155 rows x 10 columns]

# %%
from scipy.stats import norm

# %%
mean = 25
std_dev = 25

y = norm.pdf(37, mean, std_dev)
y_peak = norm.pdf(mean, mean, std_dev)
y_normalized = y / y_peak

# %%
y_normalized
# Out:
# 0.8911878885041845

# %%
import math

def age_decay_factor(age, decay_rate=0.005):
    """
    Calculate the exponential decay factor based on age.
    
    :param age: The player's age.
    :param decay_rate: The rate at which the decay occurs after age 25.
    :return: The decay factor for the given age.
    """
    # For ages 25 or younger, the factor is 1.
    if age <= 25:
        return 1.0
    # For ages above 25, apply the exponential decay.
    else:
        return math.exp(-decay_rate * (age - 25))

# Example usage
ages = [20, 25, 30, 35, 40]

# Calculate the decay factors for each age
for age in ages:
    factor = age_decay_factor(age)
    print(f"Decay factor for age {age}: {factor:.4f}")
# Out:
# Decay factor for age 20: 1.0000
# Decay factor for age 25: 1.0000
# Decay factor for age 30: 0.9753
# Decay factor for age 35: 0.9512
# Decay factor for age 40: 0.9277

# %%
player_elos.loc['Casper Ruud']
# Out:
# Hard_ELO      1773.280335
# Clay_ELO      1822.241403
# Grass_ELO     1739.887825
# Player_age      24.300000
# Name: Casper Ruud, dtype: float64

# %%
player_elos
# Out:
#                             Hard_ELO     Clay_ELO    Grass_ELO  Player_age
# Player_Name
# Nikola Cacic             1499.994673  1499.993341  1499.994673        32.6
# Marcel Granollers        1453.471439  1462.688900  1466.152219        37.0
# Thanasi Kokkinakis       1506.573337  1501.327748  1507.718537        26.9
# Chuhan Wang              1499.807405  1499.845924  1499.845924        32.0
# Jesse Huta Galung        1496.210037  1496.896130  1496.937675        38.3
# ...                              ...          ...          ...         ...
# Liam Caruana             1493.551790  1494.841432  1494.841432        25.7
# Salvador Andres Bolanos  1499.754087  1499.754067  1499.781402        24.8
# Juan Carlos Saez         1500.488380  1500.610475  1500.488380        32.1
# Cayetano March           1497.697743  1498.158194  1498.158194        25.6
# Laurent Lokoli           1493.217115  1492.870344  1493.816648        28.2
#
# [1158 rows x 4 columns]

# %%
player_elos
# Out:
#                       Hard_ELO     Clay_ELO    Grass_ELO  Player_age
# Player_Name
# Ryan Harrison      1544.432214  1439.728247  1434.772381        31.6
# Hugo Grenier       1477.609055  1480.897086  1494.095614        27.0
# Vladyslav Manafov  1496.178196  1498.089098  1498.089098        30.3
# Donald Young       1488.633000  1400.474508  1499.710461        36.4
# Salvatore Caruso   1424.361147  1396.579264  1404.963998        31.0
# ...                        ...          ...          ...         ...
# Gustavo Ramirez    1497.195775  1494.391549  1497.195775        37.2
# Yshai Oliel        1459.977304  1477.148882  1479.042062        23.6
# Skyler Butts       1505.000000  1502.500000  1502.500000        29.3
# Niels Desein       1448.624653  1468.085753  1455.632607        36.0
# Sheil Kotecha      1495.349066  1497.674533  1497.674533        22.9
#
# [1158 rows x 4 columns]

# %%
data

# %%
player_elos
# Out:
#                            Hard_ELO     Clay_ELO    Grass_ELO  Player_age  \
# Player_Name
# Jan Kroslak             1495.320324  1496.982564  1500.000000        50.3
# Michael Agwi            1500.000000  1500.000000  1500.000000        20.4
# Holger Rune             1757.131745  1992.396285  1889.735991        20.7
# Lamine Ouahab           1493.250216  1497.407999  1500.000000        39.1
# Micke Kontinen          1498.269066  1497.203684  1500.000000        33.2
# ...                             ...          ...          ...         ...
# Miguel Gallardo Valles  1500.684270  1495.065691  1500.000000        43.9
# Karim Mohamed Maamoun   1499.603797  1501.132900  1500.000000        33.4
# Phillip King            1487.447047  1500.000000  1500.000000        43.1
# Victor Ionita           1500.000000  1495.197985  1500.000000        43.3
# Carsten Ball            1492.179507  1500.308771  1494.481925        37.5
#
#                         Games_played
# Player_Name
# Jan Kroslak                       19
# Michael Agwi                       2
# Holger Rune                      187
# Lamine Ouahab                     38
# Micke Kontinen                     9
# ...                              ...
# Miguel Gallardo Valles            20
# Karim Mohamed Maamoun             13
# Phillip King                       9
# Victor Ionita                      4
# Carsten Ball                      26
#
# [2075 rows x 5 columns]

# %%
player_elos.loc['Abdelhak Hameurlaine']
# Out:
# Hard_ELO        1500.000000
# Clay_ELO        1499.013606
# Grass_ELO       1500.000000
# Player_age        53.000000
# Games_played       4.000000
# Name: Abdelhak Hameurlaine, dtype: float64

# %%
games_played_winner = pd.DataFrame(tennis_data['winner_name'].value_counts())
games_played_loser = pd.DataFrame(tennis_data['loser_name'].value_counts())
games_played = pd.concat([games_played_winner, games_played_loser])
games_played.groupby(games_played.index).sum()['count']
# Out:
# Abdelhak Hameurlaine     4
# Abdul Mumin Babalola     2
# Abdulhameed Alshatti     1
# Abdullah Maqdas         15
# Abedallah Shelbayh      14
#                         ..
# Zhizhen Zhang           84
# Zibusiso Ncube           1
# Zizou Bergs             33
# Zsombor Piros           14
# Zura Tkemaladze          2
# Name: count, Length: 2075, dtype: int64

# %%
# Out:
#                       count
# Abdelhak Hameurlaine      4
# Abdul Mumin Babalola      2
# Abdulhameed Alshatti      1
# Abdullah Maqdas          15
# Abedallah Shelbayh       14
# ...                     ...
# Zhizhen Zhang            84
# Zibusiso Ncube            1
# Zizou Bergs              33
# Zsombor Piros            14
# Zura Tkemaladze           2
#
# [2075 rows x 1 columns]

# %%
df_sorted = tennis_data.sort_values(by = 'Year', ascending=False)

        # Create a dataframe of each of the winners last ages in the dataset, keeping only the first in drop duplicates.
winner_ages = df_sorted[['winner_name', 'winner_age', 'Year']].drop_duplicates('winner_name', keep='first')

        # Renames columns for proper naming.
winner_ages.rename(columns={'winner_name': 'Player_name', 'winner_age': 'most_recent_age'}, inplace=True)
winner_ages['Result'] = 'Winner'

        # Create a dataframe of each of the losers last ages in the dataset, keeping only the first in drop duplicates.
loser_ages = df_sorted[['loser_name', 'loser_age', 'Year']].drop_duplicates('loser_name',keep='first')
        
        # Renames the columns similar to winners_ages for similar naming convention.
loser_ages.rename(columns={'loser_name': 'Player_name', 'loser_age': 'most_recent_age'}, inplace=True)
loser_ages['Result'] = 'Loser'

recent_ages = pd.concat([winner_ages, loser_ages])

        # Use pivot to create new dataframe using Player_name as the index, the column being if they won or lost a match, and the values
        # being their most recent age.
recent_ages = recent_ages.pivot(index ='Player_name', columns = 'Result', values = 'most_recent_age').reset_index()

recent_ages
# Out:
# Result           Player_name  Loser  Winner
# 0       Abdelhak Hameurlaine   35.0    34.3
# 1       Abdul Mumin Babalola   22.2     NaN
# 2       Abdulhameed Alshatti   18.6     NaN
# 3            Abdullah Maqdas   29.8    28.2
# 4         Abedallah Shelbayh   20.2    19.4
# ...                      ...    ...     ...
# 2070           Zhizhen Zhang   27.3    27.3
# 2071          Zibusiso Ncube   24.6     NaN
# 2072             Zizou Bergs   24.6    24.6
# 2073           Zsombor Piros   24.0    23.2
# 2074         Zura Tkemaladze   23.6     NaN
#
# [2075 rows x 3 columns]

# %%
player_elos['Player_age'].sort_values()
# Out:
# Player_Name
# Darwin Blanch           16.5
# Joao Fonseca            17.4
# Luca Preda              17.8
# Martin Landaluce        18.2
# Jakub Mensik            18.4
#                         ...
# Mark Woodforde          58.3
# Richey Reneberg         58.3
# Gianluca Pozzi          58.8
# Ronald Agenor           59.7
# Rafael Avalos Brenes    62.6
# Name: Player_age, Length: 2075, dtype: float64

# %%
tennis_data
# Out:
#                        tourney_name surface  draw_size tourney_level  best_of  \
# 0                          Auckland    Hard         32             A        3
# 1                          Auckland    Hard         32             A        3
# 2                          Auckland    Hard         32             A        3
# 3                          Auckland    Hard         32             A        3
# 4                          Auckland    Hard         32             A        3
# ...                             ...     ...        ...           ...      ...
# 69511  Davis Cup WG2 PO: URU vs MDA    Clay          4             D        3
# 69512  Davis Cup WG2 PO: URU vs MDA    Clay          4             D        3
# 69513  Davis Cup WG2 PO: URU vs MDA    Clay          4             D        3
# 69514  Davis Cup WG2 PO: VIE vs RSA    Hard          4             D        3
# 69515  Davis Cup WG2 PO: VIE vs RSA    Hard          4             D        3
#
#                      winner_name winner_hand  winner_age  \
# 0                     Tommy Haas           R        21.7
# 1                  Juan Balcells           R        24.5
# 2                 Alberto Martin           R        21.3
# 3            Juan Carlos Ferrero           R        19.9
# 4                   Michael Sell           R        27.3
# ...                          ...         ...         ...
# 69511                 Radu Albot           R        34.2
# 69512                 Radu Albot           R        34.2
# 69513  Joaquin  Aguilar Cardozo            U        18.8
# 69514               Nam Hoang Ly           R        26.9
# 69515               Nam Hoang Ly           R        26.9
#
#                       loser_name loser_hand  loser_age  winner_rank  \
# 0                   Jeff Tarango          L       31.1         11.0
# 1               Franco Squillari          L       24.3        211.0
# 2            Alberto Berasategui          R       26.5         48.0
# 3                  Roger Federer          R       18.4         45.0
# 4                 Nicolas Escude          R       23.7        167.0
# ...                          ...        ...        ...          ...
# 69511  Joaquin  Aguilar Cardozo           U       18.8        136.0
# 69512          Franco Roncadelli          L       23.9        136.0
# 69513               Ilya Snitari          U       21.8       1109.0
# 69514             Philip Henning          R       23.2        554.0
# 69515               Kris Van Wyk          U       27.3        554.0
#
#        winner_rank_points  loser_rank  loser_rank_points  Year
# 0                  1612.0        63.0              595.0  2000
# 1                   157.0        49.0              723.0  2000
# 2                   726.0        59.0              649.0  2000
# 3                   768.0        61.0              616.0  2000
# 4                   219.0        34.0              873.0  2000
# ...                   ...         ...                ...   ...
# 69511               489.0      1109.0                8.0  2024
# 69512               489.0       616.0               55.0  2024
# 69513                 8.0       740.0               34.0  2024
# 69514                67.0       748.0               32.0  2024
# 69515                67.0       416.0              109.0  2024
#
# [69516 rows x 16 columns]

# %%
import pandas as pd

# Load the dataset
df = tennis_data

# Sort the DataFrame by Year to ensure we get the most recent matches first
df_sorted = df.sort_values(by='Year', ascending=False)

# Get the most recent ages for winners
winner_ages = df_sorted[['winner_name', 'winner_age', 'Year']].drop_duplicates('winner_name', keep='first')
winner_ages.rename(columns={'winner_name': 'Player Name', 'winner_age': 'Most Recent Age'}, inplace=True)
winner_ages['Role'] = 'Winner'

# Get the most recent ages for losers
loser_ages = df_sorted[['loser_name', 'loser_age', 'Year']].drop_duplicates('loser_name', keep='first')
loser_ages.rename(columns={'loser_name': 'Player Name', 'loser_age': 'Most Recent Age'}, inplace=True)
loser_ages['Role'] = 'Loser'

# Combine both DataFrames
recent_ages = pd.concat([winner_ages, loser_ages], ignore_index=True)

# Pivot to have Player Names and ages in a single row
recent_ages_pivot = recent_ages.pivot(index='Player Name', columns='Role', values='Most Recent Age').reset_index()

# Fill NaN values with 0 or a placeholder if needed
recent_ages_pivot.fillna(0, inplace=True)

# Get the most recent year for each player
recent_years = pd.concat([winner_ages[['Player Name', 'Year']], loser_ages[['Player Name', 'Year']]])
#recent_years = recent_years.drop_duplicates(subset='Player Name', keep='first')
recent_years
# Out:
#            Player Name  Year
# 69515     Nam Hoang Ly  2024
# 68593   Alexei Popyrin  2024
# 68585     Jakub Mensik  2024
# 68586     Gael Monfils  2024
# 68588  Karen Khachanov  2024
# ...                ...   ...
# 1548     Jonas Froberg  2000
# 1545    Johan Ortegren  2000
# 1700    Javier Sanchez  2000
# 1638   Karsten Braasch  2000
# 2137        Igor Gaudi  2000
#
# [3472 rows x 2 columns]

# %%
recent_ages_pivot
# Out:
#                Player Name  Loser  Winner  Year  Current Winner Age  \
# 0     Abdelhak Hameurlaine   35.0    34.3  2006                52.3
# 1     Abdul Mumin Babalola   22.2     0.0  2007                17.0
# 2     Abdulhameed Alshatti   18.6     0.0  2014                10.0
# 3          Abdullah Maqdas   29.8    28.2  2015                37.2
# 4       Abedallah Shelbayh   20.2    19.4  2023                20.4
# ...                    ...    ...     ...   ...                 ...
# 2070         Zhizhen Zhang   27.3    27.3  2024                27.3
# 2071        Zibusiso Ncube   24.6     0.0  2003                21.0
# 2072           Zizou Bergs   24.6    24.6  2024                24.6
# 2073         Zsombor Piros   24.0    23.2  2023                24.2
# 2074       Zura Tkemaladze   23.6     0.0  2024                 0.0
#
#       Current Loser Age  Max Current Age
# 0                  53.0             53.0
# 1                  39.2             39.2
# 2                  28.6             28.6
# 3                  38.8             38.8
# 4                  21.2             21.2
# ...                 ...              ...
# 2070               27.3             27.3
# 2071               45.6             45.6
# 2072               24.6             24.6
# 2073               25.0             25.0
# 2074               23.6             23.6
#
# [2075 rows x 7 columns]

# %%
tennis_data
# Out:
#                        tourney_name surface  draw_size tourney_level  best_of  \
# 0                          Auckland    Hard         32             A        3
# 1                          Auckland    Hard         32             A        3
# 2                          Auckland    Hard         32             A        3
# 3                          Auckland    Hard         32             A        3
# 4                          Auckland    Hard         32             A        3
# ...                             ...     ...        ...           ...      ...
# 69511  Davis Cup WG2 PO: URU vs MDA    Clay          4             D        3
# 69512  Davis Cup WG2 PO: URU vs MDA    Clay          4             D        3
# 69513  Davis Cup WG2 PO: URU vs MDA    Clay          4             D        3
# 69514  Davis Cup WG2 PO: VIE vs RSA    Hard          4             D        3
# 69515  Davis Cup WG2 PO: VIE vs RSA    Hard          4             D        3
#
#                      winner_name winner_hand  winner_age  \
# 0                     Tommy Haas           R        21.7
# 1                  Juan Balcells           R        24.5
# 2                 Alberto Martin           R        21.3
# 3            Juan Carlos Ferrero           R        19.9
# 4                   Michael Sell           R        27.3
# ...                          ...         ...         ...
# 69511                 Radu Albot           R        34.2
# 69512                 Radu Albot           R        34.2
# 69513  Joaquin  Aguilar Cardozo            U        18.8
# 69514               Nam Hoang Ly           R        26.9
# 69515               Nam Hoang Ly           R        26.9
#
#                       loser_name loser_hand  loser_age  winner_rank  \
# 0                   Jeff Tarango          L       31.1         11.0
# 1               Franco Squillari          L       24.3        211.0
# 2            Alberto Berasategui          R       26.5         48.0
# 3                  Roger Federer          R       18.4         45.0
# 4                 Nicolas Escude          R       23.7        167.0
# ...                          ...        ...        ...          ...
# 69511  Joaquin  Aguilar Cardozo           U       18.8        136.0
# 69512          Franco Roncadelli          L       23.9        136.0
# 69513               Ilya Snitari          U       21.8       1109.0
# 69514             Philip Henning          R       23.2        554.0
# 69515               Kris Van Wyk          U       27.3        554.0
#
#        winner_rank_points  loser_rank  loser_rank_points  Year
# 0                  1612.0        63.0              595.0  2000
# 1                   157.0        49.0              723.0  2000
# 2                   726.0        59.0              649.0  2000
# 3                   768.0        61.0              616.0  2000
# 4                   219.0        34.0              873.0  2000
# ...                   ...         ...                ...   ...
# 69511               489.0      1109.0                8.0  2024
# 69512               489.0       616.0               55.0  2024
# 69513                 8.0       740.0               34.0  2024
# 69514                67.0       748.0               32.0  2024
# 69515                67.0       416.0              109.0  2024
#
# [69516 rows x 16 columns]

# %%
df_sorted = tennis_data.sort_values(by='Year', ascending=False)

        # Create a dataframe of each of the winners last ages in the dataset, keeping only the first in drop duplicates.
winner_ages = df_sorted[['winner_name', 'winner_age', 'Year']].drop_duplicates('winner_name', keep='first')

        # Renames columns for proper naming.
winner_ages.rename(columns={'winner_name': 'player_name', 'winner_age': 'most_recent_age'}, inplace=True)
winner_ages['Role'] = 'Winner'

        # Create a dataframe of each of the losers last ages in the dataset, keeping only the first in drop duplicates.
loser_ages = df_sorted[['loser_name', 'loser_age', 'Year']].drop_duplicates('loser_name', keep='first')
        
        # Renames the columns similar to winners_ages for similar naming convention.
loser_ages.rename(columns={'loser_name': 'player_name', 'loser_age': 'most_recent_age'}, inplace=True)
loser_ages['Role'] = 'Loser'

        # Combines the dataframe into one, with both the recent winners and loser ages.
recent_ages = pd.concat([winner_ages, loser_ages], ignore_index=True)

        # 
recent_ages_pivot = recent_ages.pivot(index='player_name', columns='Role', values='most_recent_age').reset_index()

recent_ages_pivot.fillna(0, inplace=True)

recent_years = pd.concat([winner_ages[['player_name', 'Year']], loser_ages[['player_name', 'Year']]], ignore_index=True)
recent_years = recent_years.drop_duplicates(subset='player_name', keep='first')

# %%
len(tennis_data[(tennis_data['tourney_name'] == 'Australian Open') & (tennis_data['Year'] == 2024)])
# Out:
# 99

# %%
import pandas as pd

# Load the dataset
df = tennis_data

# Sort the DataFrame by Year to ensure we get the most recent matches first
df_sorted = df.sort_values(by='Year', ascending=False)

# Get the most recent ages for winners
winner_ages = df_sorted[['winner_name', 'winner_age', 'Year']].drop_duplicates('winner_name', keep='first')
winner_ages.rename(columns={'winner_name': 'Player Name', 'winner_age': 'Most Recent Age'}, inplace=True)
winner_ages['Role'] = 'Winner'

# Get the most recent ages for losers
loser_ages = df_sorted[['loser_name', 'loser_age', 'Year']].drop_duplicates('loser_name', keep='first')
loser_ages.rename(columns={'loser_name': 'Player Name', 'loser_age': 'Most Recent Age'}, inplace=True)
loser_ages['Role'] = 'Loser'

# Combine both DataFrames
recent_ages = pd.concat([winner_ages, loser_ages], ignore_index=True)

# Pivot to have Player Names and ages in a single row
recent_ages_pivot = recent_ages.pivot(index='Player Name', columns='Role', values='Most Recent Age').reset_index()

# Fill NaN values with 0 or a placeholder if needed
recent_ages_pivot.fillna(0, inplace=True)

# Get the most recent year for each player
recent_years = pd.concat([winner_ages[['Player Name', 'Year']], loser_ages[['Player Name', 'Year']]], ignore_index=True)
recent_years = recent_years.drop_duplicates(subset='Player Name', keep='first')

# Merge to get the year with ages
recent_ages_pivot = recent_ages_pivot.merge(recent_years, on='Player Name')

recent_ages_pivot
# Out:
#                Player Name  Loser  Winner  Year
# 0     Abdelhak Hameurlaine   35.0    34.3  2006
# 1     Abdul Mumin Babalola   22.2     0.0  2007
# 2     Abdulhameed Alshatti   18.6     0.0  2014
# 3          Abdullah Maqdas   29.8    28.2  2015
# 4       Abedallah Shelbayh   20.2    19.4  2023
# ...                    ...    ...     ...   ...
# 2070         Zhizhen Zhang   27.3    27.3  2024
# 2071        Zibusiso Ncube   24.6     0.0  2003
# 2072           Zizou Bergs   24.6    24.6  2024
# 2073         Zsombor Piros   24.0    23.2  2023
# 2074       Zura Tkemaladze   23.6     0.0  2024
#
# [2075 rows x 4 columns]

# %%
loser_ages['']
# Out:
#             Player Name  most_recent_age  Year   Role
# 69515      Kris Van Wyk             27.3  2024  Loser
# 68593      Hugo Grenier             27.9  2024  Loser
# 68585     Andrey Rublev             26.3  2024  Loser
# 68586       Ugo Humbert             25.6  2024  Loser
# 68587  Alexander Bublik             26.6  2024  Loser
# ...                 ...              ...   ...    ...
# 1548      Jonas Froberg             19.6  2000  Loser
# 1545     Johan Ortegren             22.6  2000  Loser
# 1700     Javier Sanchez             31.9  2000  Loser
# 1638    Karsten Braasch             32.9  2000  Loser
# 2137         Igor Gaudi             25.2  2000  Loser
#
# [2035 rows x 4 columns]

# %%
player_elos
# Out:
#                                   Hard_ELO     Clay_ELO    Grass_ELO  \
# Player_Name
# Sho Shimabukuro                1374.452411  1500.000000  1415.158534
# Alejandro Davidovich Fokina    1780.705249  1690.746251  1575.393870
# Talal Ouahabi                  1500.000000  1497.739338  1500.000000
# Tomas Tenconi                  1500.000000  1496.685945  1500.000000
# Marco Mirnegg                  1500.000000  1498.243968  1500.000000
# ...                                    ...          ...          ...
# Luis Diego Chavez Villalpando  1500.000000  1500.653475  1500.000000
# Emanuel Couto                  1499.638268  1498.815605  1500.000000
# Tiago Sousa                    1500.000000  1498.448850  1500.000000
# Andre Agassi                   1687.831253  1539.392831  1530.758660
# Roman Borvanov                 1497.104774  1500.000000  1500.000000
#
#                                Player_age
# Player_Name
# Sho Shimabukuro                      27.2
# Alejandro Davidovich Fokina          24.7
# Talal Ouahabi                        46.1
# Tomas Tenconi                        45.7
# Marco Mirnegg                        41.8
# ...                                   ...
# Luis Diego Chavez Villalpando        28.2
# Emanuel Couto                        50.6
# Tiago Sousa                          45.4
# Andre Agassi                         53.8
# Roman Borvanov                       41.8
#
# [2075 rows x 4 columns]

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('tennis_data.csv')

# Sort the DataFrame by Year to ensure we get the most recent matches first
df_sorted = df.sort_values(by='Year', ascending=False)

# Get the most recent ages for winners
winner_ages = df_sorted[['winner_name', 'winner_age', 'Year']].drop_duplicates('winner_name', keep='first')
winner_ages.rename(columns={'winner_name': 'Player Name', 'winner_age': 'Most Recent Age'}, inplace=True)
winner_ages['Role'] = 'Winner'

# Get the most recent ages for losers
loser_ages = df_sorted[['loser_name', 'loser_age', 'Year']].drop_duplicates('loser_name', keep='first')
loser_ages.rename(columns={'loser_name': 'Player Name', 'loser_age': 'Most Recent Age'}, inplace=True)
loser_ages['Role'] = 'Loser'

# Combine both DataFrames
recent_ages = pd.concat([winner_ages, loser_ages], ignore_index=True)

# Pivot to have Player Names and ages in a single row
recent_ages_pivot = recent_ages.pivot(index='Player Name', columns='Role', values='Most Recent Age').reset_index()

# Fill NaN values with 0 or a placeholder if needed
recent_ages_pivot.fillna(0, inplace=True)

# Get the most recent year for each player
recent_years = pd.concat([winner_ages[['Player Name', 'Year']], loser_ages[['Player Name', 'Year']]], ignore_index=True)
recent_years = recent_years.drop_duplicates(subset='Player Name', keep='first')

# Merge to get the year with ages
recent_ages_pivot = recent_ages_pivot.merge(recent_years, on='Player Name')

# Calculate the current age based on the most recent year
current_year = 2023  # or use datetime.datetime.now().year for dynamic current year
recent_ages_pivot['Max Current Age'] = recent_ages_pivot[['Winner', 'Loser']].max(axis=1) + (current_year - recent_ages_pivot['Year'])

# Count occurrences (games played) for each player in the dataset
games_played_winner = df['winner_name'].value_counts().reset_index()
games_played_winner.columns = ['Player Name', 'Games Played']
games_played_loser = df['loser_name'].value_counts().reset_index()
games_played_loser.columns = ['Player Name', 'Games Played']

# Combine games played for both winners and losers
games_played = pd.concat([games_played_winner, games_played_loser], ignore_index=True)
games_played = games_played.groupby('Player Name').sum().reset_index()

# Merge games played with the ages DataFrame
final_df = recent_ages_pivot[['Player Name', 'Max Current Age']].merge(games_played, on='Player Name', how='left')

# Set Player Name as the index
final_df.set_index('Player Name', inplace=True)

# Print the resulting DataFrame
print(final_df[['Max Current Age', 'Games Played']])
# Out:
#                       Max Current Age  Games Played
# Player Name
# Abdelhak Hameurlaine             52.0             4
# Abdul Mumin Babalola             38.2             2
# Abdulhameed Alshatti             27.6             1
# Abdullah Maqdas                  37.8            15
# Abedallah Shelbayh               20.2            14
# ...                               ...           ...
# Zhizhen Zhang                    26.3            84
# Zibusiso Ncube                   44.6             1
# Zizou Bergs                      23.6            33
# Zsombor Piros                    24.0            14
# Zura Tkemaladze                  22.6             2
#
# [2075 rows x 2 columns]

# %%
final_df['Max Current Age'].sort_values()
# Out:
# Player Name
# Darwin Blanch           15.5
# Joao Fonseca            16.4
# Luca Preda              16.8
# Martin Landaluce        17.2
# Jakub Mensik            17.4
#                         ...
# Richey Reneberg         57.3
# Paul Haarhuis           57.3
# Gianluca Pozzi          57.8
# Ronald Agenor           58.7
# Rafael Avalos Brenes    61.6
# Name: Max Current Age, Length: 2075, dtype: float64

# %%
import pandas as pd

# Assuming player_elos and recent_ages_pivot are already defined and player_elos is indexed by player_name

# Ensure recent_ages_pivot is set up for joining
max_age_series = recent_ages_pivot.set_index('Player Name')['Max Current Age']

# Join the Max Current Age to player_elos
player_elos = player_elos.join(max_age_series, how='left', rsuffix='_Max_Age')

# %%
player_elos
# Out:
#                           Hard_ELO     Clay_ELO    Grass_ELO  Max Current Age  \
# Player_Name
# Febi Widhiyanto        1501.718611  1500.000000  1500.000000             42.9
# Lauri Kiiski           1500.000000  1499.448513  1500.000000             42.7
# Jean Claude Scherrer   1498.222592  1500.000000  1496.606843             45.1
# Aslan Karatsev         1823.866932  1670.048054  1520.608844             29.6
# Karan Rastogi          1494.571049  1498.801116  1500.000000             36.3
# ...                            ...          ...          ...              ...
# Albert Montanes        1432.781343  1539.354472  1477.929455             42.4
# Tomas Tenconi          1500.000000  1496.685945  1500.000000             44.7
# Andreas Haider Maurer  1467.193610  1468.219603  1481.229438             39.1
# Gvidas Sabeckis        1499.297675  1499.297625  1500.000000             38.9
# Matija Pecotic         1524.050086  1500.000000  1500.000000             33.6
#
#                        Max Current Age_Max_Age  Max Current Age_Max_Age
# Player_Name
# Febi Widhiyanto                           42.9                     42.9
# Lauri Kiiski                              42.7                     42.7
# Jean Claude Scherrer                      45.1                     45.1
# Aslan Karatsev                            29.6                     29.6
# Karan Rastogi                             36.3                     36.3
# ...                                        ...                      ...
# Albert Montanes                           42.4                     42.4
# Tomas Tenconi                             44.7                     44.7
# Andreas Haider Maurer                     39.1                     39.1
# Gvidas Sabeckis                           38.9                     38.9
# Matija Pecotic                            33.6                     33.6
#
# [2075 rows x 6 columns]

# %%
import pandas as pd

# Assuming final_df and elo_df are already defined
# Make sure elo_df has 'Player Name' as its index

# Join the two DataFrames on their indices (player names)
combined_df = final_df.join(player_elos, how='left')

# Print the resulting combined DataFrame
print(combined_df)

# %%
combined_df
# Out:
#                       Max Current Age  Games Played     Hard_ELO     Clay_ELO  \
# Player Name
# Abdelhak Hameurlaine             52.0             4  1500.000000  1499.013606
# Abdul Mumin Babalola             38.2             2  1498.801900  1500.000000
# Abdulhameed Alshatti             27.6             1  1499.050000  1500.000000
# Abdullah Maqdas                  37.8            15  1499.037636  1500.995503
# Abedallah Shelbayh               20.2            14  1474.214171  1489.753049
# ...                               ...           ...          ...          ...
# Zhizhen Zhang                    26.3            84  1772.127728  1678.443025
# Zibusiso Ncube                   44.6             1  1499.586096  1500.000000
# Zizou Bergs                      23.6            33  1238.572061  1508.288841
# Zsombor Piros                    24.0            14  1485.794678  1488.298390
# Zura Tkemaladze                  22.6             2  1500.000000  1500.000000
#
#                         Grass_ELO
# Player Name
# Abdelhak Hameurlaine  1500.000000
# Abdul Mumin Babalola  1500.000000
# Abdulhameed Alshatti  1500.000000
# Abdullah Maqdas       1500.000000
# Abedallah Shelbayh    1385.713953
# ...                           ...
# Zhizhen Zhang         1402.399456
# Zibusiso Ncube        1500.000000
# Zizou Bergs           1469.286456
# Zsombor Piros         1500.000000
# Zura Tkemaladze       1500.000000
#
# [2075 rows x 5 columns]

# %%
final_df['Max Current Age']
# Out:
# Player Name
# Abdelhak Hameurlaine    52.0
# Abdul Mumin Babalola    38.2
# Abdulhameed Alshatti    27.6
# Abdullah Maqdas         37.8
# Abedallah Shelbayh      20.2
#                         ...
# Zhizhen Zhang           26.3
# Zibusiso Ncube          44.6
# Zizou Bergs             23.6
# Zsombor Piros           24.0
# Zura Tkemaladze         22.6
# Name: Max Current Age, Length: 2075, dtype: float64

# %%
player_elos
# Out:
#                           Hard_ELO     Clay_ELO    Grass_ELO
# Player_Name
# Febi Widhiyanto        1501.718611  1500.000000  1500.000000
# Lauri Kiiski           1500.000000  1499.448513  1500.000000
# Jean Claude Scherrer   1498.222592  1500.000000  1496.606843
# Aslan Karatsev         1823.866932  1670.048054  1520.608844
# Karan Rastogi          1494.571049  1498.801116  1500.000000
# ...                            ...          ...          ...
# Albert Montanes        1432.781343  1539.354472  1477.929455
# Tomas Tenconi          1500.000000  1496.685945  1500.000000
# Andreas Haider Maurer  1467.193610  1468.219603  1481.229438
# Gvidas Sabeckis        1499.297675  1499.297625  1500.000000
# Matija Pecotic         1524.050086  1500.000000  1500.000000
#
# [2075 rows x 3 columns]

# %%
df_sorted[['winner_name', 'winner_age', 'Year']].drop_duplicates('winner_name', keep='first')
# Out:
#                winner_name  winner_age  Year
# 69515         Nam Hoang Ly        26.9  2024
# 68593       Alexei Popyrin        24.5  2024
# 68585         Jakub Mensik        18.4  2024
# 68586         Gael Monfils        37.4  2024
# 68588      Karen Khachanov        27.7  2024
# ...                    ...         ...   ...
# 1624       Karsten Braasch        32.9  2000
# 1695      Andrei Cherkasov        29.4  2000
# 2229          Petr Kralert        20.8  2000
# 1994   Marcelo Charpentier        26.8  2000
# 1948          Mariano Hood        26.5  2000
#
# [1437 rows x 3 columns]

# %%
import pandas as pd

# Load the dataset
df = tennis_data

# Sort the DataFrame by Year to ensure we get the most recent matches first
df_sorted = df.sort_values(by='Year', ascending=False)

# Get the most recent ages for winners
winner_ages = df_sorted[['winner_name', 'winner_age', 'Year']].drop_duplicates('winner_name', keep='first')
winner_ages.rename(columns={'winner_name': 'Player Name', 'winner_age': 'Most Recent Age'}, inplace=True)
winner_ages['Role'] = 'Winner'

# Get the most recent ages for losers
loser_ages = df_sorted[['loser_name', 'loser_age', 'Year']].drop_duplicates('loser_name', keep='first')
loser_ages.rename(columns={'loser_name': 'Player Name', 'loser_age': 'Most Recent Age'}, inplace=True)
loser_ages['Role'] = 'Loser'

# Combine both DataFrames
recent_ages = pd.concat([winner_ages, loser_ages], ignore_index=True)

# Pivot to have Player Names and ages in a single row
recent_ages_pivot = recent_ages.pivot(index='Player Name', columns='Role', values='Most Recent Age').reset_index()

# Fill NaN values with 0 or a placeholder if needed
recent_ages_pivot.fillna(0, inplace=True)

# Get the most recent year for each player
recent_years = pd.concat([winner_ages[['Player Name', 'Year']], loser_ages[['Player Name', 'Year']]], ignore_index=True)
recent_years = recent_years.drop_duplicates(subset='Player Name', keep='first')

# Merge to get the year with ages
recent_ages_pivot = recent_ages_pivot.merge(recent_years, on='Player Name')

# Calculate the current age based on the most recent year
current_year = 2023  # or use datetime.datetime.now().year for dynamic current year
recent_ages_pivot['Max Current Age'] = recent_ages_pivot[['Winner', 'Loser']].max(axis=1) + (current_year - recent_ages_pivot['Year'])

# Count occurrences (games played) for each player in the dataset
games_played_winner = df['winner_name'].value_counts().reset_index()
games_played_winner.columns = ['Player Name', 'Games Played']
games_played_loser = df['loser_name'].value_counts().reset_index()
games_played_loser.columns = ['Player Name', 'Games Played']

# Combine games played for both winners and losers
games_played = pd.concat([games_played_winner, games_played_loser], ignore_index=True)
games_played = games_played.groupby('Player Name').sum().reset_index()

# Merge games played with the ages DataFrame
final_df = recent_ages_pivot[['Player Name', 'Max Current Age']].merge(games_played, on='Player Name', how='left')

# Set Player Name as the index
final_df.set_index('Player Name', inplace=True)

# Print the resulting DataFrame
print(final_df[['Max Current Age', 'Games Played']])

# %%
final_df
# Out:
#                       Max Current Age  Games Played
# Player Name
# Abdelhak Hameurlaine             52.0             4
# Abdul Mumin Babalola             38.2             2
# Abdulhameed Alshatti             27.6             1
# Abdullah Maqdas                  37.8            15
# Abedallah Shelbayh               20.2            14
# ...                               ...           ...
# Zhizhen Zhang                    26.3            84
# Zibusiso Ncube                   44.6             1
# Zizou Bergs                      23.6            33
# Zsombor Piros                    24.0            14
# Zura Tkemaladze                  22.6             2
#
# [2075 rows x 2 columns]

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('tennis_data.csv')

# Sort the DataFrame by Year to ensure we get the most recent matches first
df_sorted = df.sort_values(by='Year', ascending=False)

# Get the most recent ages for winners
winner_ages = df_sorted[['winner_name', 'winner_age', 'Year']].drop_duplicates('winner_name', keep='first')
winner_ages.rename(columns={'winner_name': 'Player Name', 'winner_age': 'Most Recent Age'}, inplace=True)
winner_ages['Role'] = 'Winner'

# Get the most recent ages for losers
loser_ages = df_sorted[['loser_name', 'loser_age', 'Year']].drop_duplicates('loser_name', keep='first')
loser_ages.rename(columns={'loser_name': 'Player Name', 'loser_age': 'Most Recent Age'}, inplace=True)
loser_ages['Role'] = 'Loser'

# Combine both DataFrames
recent_ages = pd.concat([winner_ages, loser_ages], ignore_index=True)

# Pivot to have Player Names and ages in a single row
recent_ages_pivot = recent_ages.pivot(index='Player Name', columns='Role', values='Most Recent Age').reset_index()

# Fill NaN values with 0 or a placeholder if needed
recent_ages_pivot.fillna(0, inplace=True)

# Get the most recent year for each player
recent_years = pd.concat([winner_ages[['Player Name', 'Year']], loser_ages[['Player Name', 'Year']]], ignore_index=True)
recent_years = recent_years.drop_duplicates(subset='Player Name', keep='first')

# Merge to get the year with ages
recent_ages_pivot = recent_ages_pivot.merge(recent_years, on='Player Name')

# Calculate the current age based on the most recent year
current_year = 2023  # or use datetime.datetime.now().year for dynamic current year
recent_ages_pivot['Current Winner Age'] = recent_ages_pivot['Winner'] + (current_year - recent_ages_pivot['Year'])
recent_ages_pivot['Current Loser Age'] = recent_ages_pivot['Loser'] + (current_year - recent_ages_pivot['Year'])

# Calculate the maximum current age for each player
recent_ages_pivot['Max Current Age'] = recent_ages_pivot[['Current Winner Age', 'Current Loser Age']].max(axis=1)

# Set Player Name as the index
recent_ages_pivot.set_index('Player Name', inplace=True)

# Print the resulting DataFrame
print(recent_ages_pivot[['Current Winner Age', 'Current Loser Age', 'Max Current Age']])

# %%
recent_ages_pivot
# Out:
#                       Loser  Winner  Year  Current Winner Age  \
# Player Name
# Abdelhak Hameurlaine   35.0    34.3  2006                51.3
# Abdul Mumin Babalola   22.2     0.0  2007                16.0
# Abdulhameed Alshatti   18.6     0.0  2014                 9.0
# Abdullah Maqdas        29.8    28.2  2015                36.2
# Abedallah Shelbayh     20.2    19.4  2023                19.4
# ...                     ...     ...   ...                 ...
# Zhizhen Zhang          27.3    27.3  2024                26.3
# Zibusiso Ncube         24.6     0.0  2003                20.0
# Zizou Bergs            24.6    24.6  2024                23.6
# Zsombor Piros          24.0    23.2  2023                23.2
# Zura Tkemaladze        23.6     0.0  2024                -1.0
#
#                       Current Loser Age  Max Current Age
# Player Name
# Abdelhak Hameurlaine               52.0             52.0
# Abdul Mumin Babalola               38.2             38.2
# Abdulhameed Alshatti               27.6             27.6
# Abdullah Maqdas                    37.8             37.8
# Abedallah Shelbayh                 20.2             20.2
# ...                                 ...              ...
# Zhizhen Zhang                      26.3             26.3
# Zibusiso Ncube                     44.6             44.6
# Zizou Bergs                        23.6             23.6
# Zsombor Piros                      24.0             24.0
# Zura Tkemaladze                    22.6             22.6
#
# [2075 rows x 6 columns]

# %%
287+255
# Out:
# 542

# %%
player_elos["Age"] = final_df['Max Current Age']
player_elos["Games_Played"] = final_df['Games Played']

# %%
player_elos['Age'] = recent_ages_pivot['Max Current Age']

# %%
player_elos[(player_elos['Grass_ELO'] == 1500) & (player_elos['Hard_ELO'] == 1500) & (player_elos['Clay_ELO'] == 1500)]
# Out:
#                  Hard_ELO  Clay_ELO  Grass_ELO
# Player_Name
# Zura Tkemaladze    1500.0    1500.0     1500.0
# Michael Sell       1500.0    1500.0     1500.0

# %%
recent_ages_pivot['Max Age'].sort_values()
# Out:
# 659     16.5
# 887     17.2
# 43      17.6
# 773     17.7
# 589     17.9
#         ...
# 1167    39.8
# 1326    39.9
# 407     41.5
# 578     41.8
# 1291    43.8
# Name: Max Age, Length: 1423, dtype: float64

# %%
tennis_data
# Out:
#                        tourney_name surface  draw_size tourney_level  best_of  \
# 0                          Auckland    Hard         32             A        3
# 1                          Auckland    Hard         32             A        3
# 2                          Auckland    Hard         32             A        3
# 3                          Auckland    Hard         32             A        3
# 4                          Auckland    Hard         32             A        3
# ...                             ...     ...        ...           ...      ...
# 66165  Davis Cup WG2 R1: SLO vs LUX    Clay          4             D        3
# 66166  Davis Cup WG2 R1: SLO vs LUX    Clay          4             D        3
# 66167  Davis Cup WG2 R1: SLO vs LUX    Clay          4             D        3
# 66168  Davis Cup WG2 R1: URU vs EGY    Clay          4             D        3
# 66169  Davis Cup WG2 R1: URU vs EGY    Clay          4             D        3
#
#                  winner_name winner_hand  winner_ht  winner_age  \
# 0                 Tommy Haas           R      188.0        21.7
# 1              Juan Balcells           R      190.0        24.5
# 2             Alberto Martin           R      175.0        21.3
# 3        Juan Carlos Ferrero           R      183.0        19.9
# 4               Michael Sell           R      180.0        27.3
# ...                      ...         ...        ...         ...
# 66165              Blaz Rola           L      193.0        32.9
# 66166              Blaz Rola           L      193.0        32.9
# 66167          Chris Rodesch           R      198.0        22.1
# 66168         Mohamed Safwat           R      180.0        32.9
# 66169  Karim Mohamed Maamoun           R      175.0        32.4
#
#                 loser_name loser_hand  loser_ht  loser_age  winner_rank  \
# 0             Jeff Tarango          L     180.0       31.1         11.0
# 1         Franco Squillari          L     183.0       24.3        211.0
# 2      Alberto Berasategui          R     173.0       26.5         48.0
# 3            Roger Federer          R     185.0       18.4         45.0
# 4           Nicolas Escude          R     185.0       23.7        167.0
# ...                    ...        ...       ...        ...          ...
# 66165        Chris Rodesch          R     198.0       22.1        457.0
# 66166           Alex Knaff          R     193.0       25.7        457.0
# 66167           Bor Artnak          R     193.0       19.2        609.0
# 66168        Ignacio Carou          R     178.0       24.1        463.0
# 66169    Franco Roncadelli          L     185.0       23.5        721.0
#
#        winner_rank_points  loser_rank  loser_rank_points  Year
# 0                  1612.0        63.0              595.0  2000
# 1                   157.0        49.0              723.0  2000
# 2                   726.0        59.0              649.0  2000
# 3                   768.0        61.0              616.0  2000
# 4                   219.0        34.0              873.0  2000
# ...                   ...         ...                ...   ...
# 66165                94.0       609.0               54.0  2023
# 66166                94.0       486.0               85.0  2023
# 66167                54.0       616.0               54.0  2023
# 66168                93.0       828.0               24.0  2023
# 66169                37.0       674.0               44.0  2023
#
# [66170 rows x 18 columns]

# %%
player_elos.mean(axis=1).sort_values().tail(10)
# Out:
# Player_Name
# Rafael Nadal          1815.058659
# Stefanos Tsitsipas    1850.552545
# Holger Rune           1878.303056
# Grigor Dimitrov       1920.709157
# Andrey Rublev         1923.380562
# Alexander Zverev      1925.199319
# Daniil Medvedev       1964.241269
# Jannik Sinner         2006.830614
# Carlos Alcaraz        2173.114820
# Novak Djokovic        2379.110656
# dtype: float64

# %%
player_elos['Grass_ELO'].sort_values().tail(10)
# Out:
# Player_Name
# Alexander Bublik       1840.118497
# Matteo Berrettini      1846.138773
# Roman Safiullin        1871.839246
# Holger Rune            1889.906946
# Christopher Eubanks    1918.294123
# Andrey Rublev          1956.159546
# Jannik Sinner          2027.974551
# Daniil Medvedev        2044.097968
# Novak Djokovic         2171.019127
# Carlos Alcaraz         2406.120227
# Name: Grass_ELO, dtype: float64

# %%
url = "https://raw.githubusercontent.com/JeffSackmann/tennis_atp/master/atp_matches_2024.csv"
response = requests.get(url)

# %%
aus = tennis_data[(tennis_data['Year'] == 2024) & (tennis_data['tourney_name'] == 'Australian Open')]

# %%
df = pd.read_csv(StringIO(response.text))

# %%
australian_open = df[df['tourney_name'] == 'Australian Open']
australian_open = australian_open[['tourney_name', 'surface', 'draw_size', 'tourney_level', 'winner_name', 'winner_hand', 'winner_ht', 'winner_age', 'loser_name', 'loser_hand', 'loser_ht', 'loser_age', 'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points']]

# %%
australian_open.head(11)
# Out:
#         tourney_name surface  draw_size tourney_level  \
# 137  Australian Open    Hard        128             G
# 138  Australian Open    Hard        128             G
# 139  Australian Open    Hard        128             G
# 140  Australian Open    Hard        128             G
# 141  Australian Open    Hard        128             G
# 142  Australian Open    Hard        128             G
# 143  Australian Open    Hard        128             G
# 144  Australian Open    Hard        128             G
# 145  Australian Open    Hard        128             G
# 146  Australian Open    Hard        128             G
# 147  Australian Open    Hard        128             G
#
#                  winner_name winner_hand  winner_ht  winner_age  \
# 137           Novak Djokovic           R      188.0        36.6
# 138           Alexei Popyrin           R      196.0        24.4
# 139             Gael Monfils           R      193.0        37.3
# 140  Tomas Martin Etcheverry           R      196.0        24.4
# 141         Adrian Mannarino           L      183.0        35.5
# 142              Jaume Munar           R      183.0        26.6
# 143     Christopher Oconnell           R      183.0        29.6
# 144              Ben Shelton           L        NaN        21.2
# 145             Taylor Fritz           R      193.0        26.2
# 146              Hugo Gaston           L      173.0        23.3
# 147          Fabian Marozsan           R      191.0        24.2
#
#                   loser_name loser_hand  loser_ht  loser_age  winner_rank  \
# 137             Dino Prizmic          U       NaN       18.4          1.0
# 138             Marc Polmans          R     188.0       26.7         43.0
# 139         Yannick Hanfmann          R     193.0       32.1         76.0
# 140              Andy Murray          R     190.0       36.6         32.0
# 141            Stan Wawrinka          R     183.0       38.8         19.0
# 142     Alexander Shevchenko          R       NaN       23.1         82.0
# 143           Cristian Garin          R     185.0       27.6         68.0
# 144    Roberto Bautista Agut          R     183.0       35.7         16.0
# 145      Facundo Diaz Acosta          L     183.0       23.0         12.0
# 146  Roberto Carballes Baena          R     183.0       30.8         97.0
# 147              Marin Cilic          R     198.0       35.2         67.0
#
#      winner_rank_points  loser_rank  loser_rank_points
# 137             11055.0       187.0              321.0
# 138              1052.0       154.0              406.0
# 139               737.0        52.0              929.0
# 140              1375.0        44.0             1050.0
# 141              1765.0        56.0              907.0
# 142               706.0        48.0              975.0
# 143               814.0        86.0              680.0
# 144              2225.0        72.0              776.0
# 145              2840.0        90.0              661.0
# 146               626.0        63.0              846.0
# 147               823.0         NaN                NaN

# %%
aus.head(11)
# Out:
#           tourney_name surface  draw_size tourney_level  best_of  \
# 68263  Australian Open    Hard        128             G        5
# 68264  Australian Open    Hard        128             G        5
# 68265  Australian Open    Hard        128             G        5
# 68266  Australian Open    Hard        128             G        5
# 68267  Australian Open    Hard        128             G        5
# 68268  Australian Open    Hard        128             G        5
# 68269  Australian Open    Hard        128             G        5
# 68270  Australian Open    Hard        128             G        5
# 68271  Australian Open    Hard        128             G        5
# 68272  Australian Open    Hard        128             G        5
# 68273  Australian Open    Hard        128             G        5
#
#                    winner_name winner_hand  winner_age  \
# 68263           Novak Djokovic           R        36.6
# 68264           Alexei Popyrin           R        24.4
# 68265             Gael Monfils           R        37.3
# 68266  Tomas Martin Etcheverry           R        24.4
# 68267         Adrian Mannarino           L        35.5
# 68268              Jaume Munar           R        26.6
# 68269     Christopher Oconnell           R        29.6
# 68270              Ben Shelton           L        21.2
# 68271             Taylor Fritz           R        26.2
# 68272              Hugo Gaston           L        23.3
# 68273      Francisco Cerundolo           R        25.4
#
#                     loser_name loser_hand  loser_age  winner_rank  \
# 68263             Dino Prizmic          U       18.4          1.0
# 68264             Marc Polmans          R       26.7         43.0
# 68265         Yannick Hanfmann          R       32.1         76.0
# 68266              Andy Murray          R       36.6         32.0
# 68267            Stan Wawrinka          R       38.8         19.0
# 68268     Alexander Shevchenko          R       23.1         82.0
# 68269           Cristian Garin          R       27.6         68.0
# 68270    Roberto Bautista Agut          R       35.7         16.0
# 68271      Facundo Diaz Acosta          L       23.0         12.0
# 68272  Roberto Carballes Baena          R       30.8         97.0
# 68273              Dane Sweeny          R       22.9         21.0
#
#        winner_rank_points  loser_rank  loser_rank_points  Year
# 68263             11055.0       187.0              321.0  2024
# 68264              1052.0       154.0              406.0  2024
# 68265               737.0        52.0              929.0  2024
# 68266              1375.0        44.0             1050.0  2024
# 68267              1765.0        56.0              907.0  2024
# 68268               706.0        48.0              975.0  2024
# 68269               814.0        86.0              680.0  2024
# 68270              2225.0        72.0              776.0  2024
# 68271              2840.0        90.0              661.0  2024
# 68272               626.0        63.0              846.0  2024
# 68273              1760.0       257.0              228.0  2024

# %%
aus_open_first_round = aus.head(64).apply(lambda row: [row['winner_name'], row['loser_name']], axis=1).tolist()

# %%
aus_open_players = [name for sublist in aus_open_first_round for name in sublist]
missing_players = set(aus_open_players) - set(player_elos.index)

# %%
missing_players
# Out:
# set()

# %%
percentile05 = player_elos.quantile(0.05)
new_elos = list(percentile05)
missing_df= pd.DataFrame([new_elos, new_elos], index=list(missing_players), columns=player_elos.columns)
player_elos = pd.concat([player_elos, missing_df])

# %%
australian_open_elos = player_elos.loc[aus_open_players]

# %%
import numpy as np
import pandas as pd

def convert_elo_to_pair_probabilities(elo_df, surface='Grass', S=600):
    """
    Converts ELO scores from a DataFrame to a matrix of pairwise winning probabilities.

    Args:
    elo_df: A DataFrame containing ELO scores with player names as index and surfaces as columns.
    surface: The surface being played on ('Grass', 'Clay', 'Hard').
    S: The scaling factor for ELO scores.

    Returns:
    A DataFrame of pairwise winning probabilities with player names as both index and columns.
    """
    
    # Check if the surface column exists in the DataFrame, if not tell user it doesn't exist
    if f"{surface}_ELO" not in elo_df.columns:
        raise ValueError(f"Surface '{surface}' not found in DataFrame columns. Make sure the spelling is correct and capitalize the first letter.")

    # Extract ELO scores for the specified surface
    elo_scores = elo_df[f"{surface}_ELO"].values
    
    # Create an empty matrix to store the probabilities
    probabilities = np.zeros((len(elo_scores), len(elo_scores)))

    # Calculate the probability of each player winning against each other player
    for i in range(len(elo_scores)):
        probabilities[i, i] = 0.5  # Each player has a 50% chance against themselves
        
        for j in range(i + 1, len(elo_scores)):
            # Calculate the expected score difference
            expected_score_diff = (elo_scores[i] - elo_scores[j]) / S
            
            # Calculate the probability of player i winning
            probability_i = 1 / (1 + 10**(-expected_score_diff))
            
            # Set the probabilities for both i vs j and j vs i
            probabilities[i, j] = probability_i
            probabilities[j, i] = 1 - probability_i

    # Create a DataFrame for better visualization
    probability_df = pd.DataFrame(probabilities, index=elo_df.index, columns=elo_df.index)
    
    return probability_df

# %%
P = convert_elo_to_pair_probabilities(australian_open_elos, surface='Hard')

# %%
def matchups_gen(winners):
    match = []
    for i in range(0, len(winners), 2):
        match.append([winners[i], winners[i+1]])
    return match

# Simulates a round of the tournament with the matchups for the round, the results matrix,
# and the round number.
def simulate_round(matchups, results, round):
    winners = []
    for i,j in matchups:
        win_i = bool(np.random.uniform() < P.loc[i,j])
        if win_i:
            results.loc[j,round] += 1
            winners.append(i)
        else:
            results.loc[i,round] += 1
            winners.append(j)
    return winners

final_matrix = np.zeros((128, 8)) 

aus_open_players = [name for sublist in aus_open_first_round for name in sublist]

trials = 1000

# This is whats used for the tournament simulation. The end_matrix stores the matrix value for
# where each team ended, adding it to final_matrix.
for _ in range(trials):
    matchup_current = aus_open_first_round
    end_matrix = pd.DataFrame(np.zeros((128, 8)), index=aus_open_players[:128])
    for round in range(0, 6):
        winners = simulate_round(matchup_current, end_matrix, round)
        matchup_current = matchups_gen(winners)
    round += 1
    final_winner = simulate_round(matchup_current, end_matrix, round)
    end_matrix.loc[final_winner,7] += 1
    final_matrix = final_matrix + end_matrix


matrix_W = final_matrix/trials

# Creates the dataframe that I submit.
column_names = ["Round_64", "Round_32", "Round_16", "Round_8", "Round_4", "Round_2", "Runner_up", "Champion"]
W_data = pd.DataFrame(matrix_W, columns=column_names)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/v2/5xt7prm10w1bkb7j4lrt_42m0000gn/T/ipykernel_4060/119043603.py in ?()
#      29 for _ in range(trials):
#      30     matchup_current = aus_open_first_round
#      31     end_matrix = pd.DataFrame(np.zeros((128, 8)), index=aus_open_players[:128])
#      32     for round in range(0, 6):
# ---> 33         winners = simulate_round(matchup_current, end_matrix, round)
#      34         matchup_current = matchups_gen(winners)
#      35     round += 1
#      36     final_winner = simulate_round(matchup_current, end_matrix, round)
#
# /var/folders/v2/5xt7prm10w1bkb7j4lrt_42m0000gn/T/ipykernel_4060/119043603.py in ?(matchups, results, round)
#       9 def simulate_round(matchups, results, round):
#      10     winners = []
#      11     for i,j in matchups:
# ---> 12         win_i = bool(np.random.uniform() < P.loc[i,j])
#      13         if win_i:
#      14             results.loc[j,round] += 1
#      15             winners.append(i)
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ### Probability to win tournament, without Yiming match calculations as of today

# %%
matrix_W[7].sort_values().tail(10)
# Out:
# Andrey Rublev       0.006
# Hubert Hurkacz      0.007
# Ben Shelton         0.013
# Carlos Alcaraz      0.031
# Alexander Zverev    0.041
# Daniil Medvedev     0.049
# Grigor Dimitrov     0.063
# Jannik Sinner       0.272
# Novak Djokovic      0.487
# Novak Djokovic      0.487
# Name: 7, dtype: float64

# %%
import numpy as np

def logistic(x):
    return 1 / (1 + 10**(-x))

def compute_prob_using_ELO(R_A, R_B):
    return logistic((R_A-R_B)/800)

#calculating the decayed winning probability in each set due to age factor
#we use Hill function to model the decay of winning probability in the last set due to age factor
#and we let the decay to be linear among 5 sets
def compute_prob_in_sets(winning_prob, age, age_threshold1, age_threshold2):
    if age <= age_threshold1:
        return [winning_prob for i in range(5)]
    else:
        return [winning_prob * (1 - (age - age_threshold1)**2 / ((age_threshold2 - age_threshold1)**2 + (age - age_threshold1)**2) * i/5) for i in range(5)]

def simulating_game(player_1, player_1_elo, player_1_age, player_2, player_2_elo, player_2_age):
    set_winner = []
    
    winning_prob_1 = compute_prob_using_ELO(player_1_elo, player_2_elo)
    winning_prob_2 = compute_prob_using_ELO(player_2_elo, player_1_elo)
    
    age_threshold1 = 27 #age from which endurance starts to fall
    age_threshold2 = 34 #age at which winning probability decay 50% in the last set
    
    winning_prob_1_in_sets = compute_prob_in_sets(winning_prob_1, player_1_age, age_threshold1, age_threshold2)
    winning_prob_2_in_sets = compute_prob_in_sets(winning_prob_2, player_2_age, age_threshold1, age_threshold2)
        
    for i in range(5):
        winning_prob_1_inthisset = winning_prob_1_in_sets[i] / (winning_prob_1_in_sets[i] + winning_prob_2_in_sets[i])
        if bool(np.random.uniform() < winning_prob_1_inthisset):
            set_winner.append(player_1)
        else:
            set_winner.append(player_2)
            
    if set_winner.count(player_1) >= 3:
        return player_1
    elif set_winner.count(player_2) >= 3:
        return player_2

# %%
player_elos['Grass_ELO'].sort_values().tail(10)
# Out:
# Player_Name
# Alexander Bublik       1840.118497
# Matteo Berrettini      1846.138773
# Roman Safiullin        1871.839246
# Holger Rune            1889.906946
# Christopher Eubanks    1918.294123
# Andrey Rublev          1956.159546
# Jannik Sinner          2027.974551
# Daniil Medvedev        2044.097968
# Novak Djokovic         2171.019127
# Carlos Alcaraz         2406.120227
# Name: Grass_ELO, dtype: float64

# %%
simulating_game('Carlos Alcaraz', 2406.120227, 23, 'Novak Djokovic', 2171.019127, 37)
# Out:
# 'Carlos Alcaraz'
