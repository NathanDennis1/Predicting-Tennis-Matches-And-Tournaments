# %%
import pandas as pd

# %%
players = pd.read_csv('player_elos.csv')
tennis = pd.read_csv('tennis_data.csv')

# %%
tennis
# Out:
#                        tourney_name surface  draw_size tourney_level  best_of  \
# 0                          Auckland    Hard         32             A        3
# 1                          Auckland    Hard         32             A        3
# 2                          Auckland    Hard         32             A        3
# 3                          Auckland    Hard         32             A        3
# 4                          Auckland    Hard         32             A        3
# ...                             ...     ...        ...           ...      ...
# 71134  Davis Cup WG2 PO: URU vs MDA    Clay          4             D        3
# 71135  Davis Cup WG2 PO: VIE vs RSA    Hard          4             D        3
# 71136  Davis Cup WG2 PO: VIE vs RSA    Hard          4             D        3
# 71137  Davis Cup WG2 PO: VIE vs RSA    Hard          4             D        3
# 71138  Davis Cup WG2 PO: VIE vs RSA    Hard          4             D        3
#
# ...

# %%
players
# Out:
#                 Player_Name     Hard_ELO     Clay_ELO    Grass_ELO  \
# 0           Carlos Palencia  1500.449854  1499.749119  1500.000000
# 1          Yasitha De Silva  1500.000000  1498.883319  1500.000000
# 2           Danai Udomchoke  1490.510481  1497.807468  1495.848787
# 3           Franco Ferreiro  1499.524339  1499.170112  1500.000000
# 4             Freddy Murray  1500.000000  1505.000000  1500.000000
# ...                     ...          ...          ...          ...
# 2543         Roko Karanusic  1490.177679  1495.533429  1497.578737
# 2544  Roberto Bautista Agut  1553.433845  1518.940975  1563.123954
# 2545        Suk Young Jeong  1499.309707  1500.000000  1500.000000
# 2546         John El Khoury  1500.000000  1499.749995  1500.000000
# 2547     Luis Manuel Flores  1500.126028  1500.000000  1500.000000
#
#       Player_age  Games_played
# 0           44.0             3
# 1           28.6             3
# 2           43.5           117
# 3           39.8             8
# ...

# %%
tennis_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 tennis_data
#
# NameError: name 'tennis_data' is not defined
